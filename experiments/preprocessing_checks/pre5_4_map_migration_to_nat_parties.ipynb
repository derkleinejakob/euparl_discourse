# %%
import os
if not os.environ.get("PREAMBLE_RUN", False): 
    # %run -i "../preamble.py" 2

# %%
import pandas as pd
import requests
import numpy as np

from src.constants import PATH_INTERMED_CHES_51_MIG_W_META, PATH_INTERMED_CHES_53_ENRICHED_MEMBER, PATH_INTERMED_CHES_54_MIG_W_CHES_META
from src.normalize_strings import normalize_list, normalize_str

# set display options for the notebook
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# Alright, now that we have our enriched migration dataset with EP's person IDs, the membership data with a mapping between EP's party IDs and CHES' party IDs. We can finally map the individual speeches (i.e. speakers at time of speech delivery) to the speakers national party affiliations and more importantly to the corresponding CHES party (if existing).

# %%
# first load the data on enriched migration and national memberships
original_migration_enriched_df = pd.read_parquet(PATH_INTERMED_CHES_51_MIG_W_META, engine='fastparquet')
display(original_migration_enriched_df.head())
# Out:
#    Unnamed: 0            speaker  \
# 0         492     Karen Melchior
# 1         844       Tineke Strik
# 2        1050  Anabela Rodrigues
# 3        1054        Beata Kempa
# 4        1056   Dorien Rookmaker
#
#                                                 text        date  \
# 0  Mr President, thank you very much to the Commi...  2024-04-24
# 1  Mr President, Commissioner. People who flee wa...  2024-04-23
# 2  Senhora Presidente, em 2024, o tráfico de sere...  2024-04-22
# 3  Pani Przewodnicząca! Pani Komisarz! Potrzebuje...  2024-04-22
# 4  Voorzitter, dank u wel, meneer Engerer, want u...  2024-04-22
#
#                                               agenda  speechnumber  \
# 0  22. Advance passenger information: enhancing a...             8
# 1  17. EU-Egypt strategic and comprehensive partn...             9
# 2  20. Amending Directive 2011/36/EU on preventin...            10
# 3  20. Amending Directive 2011/36/EU on preventin...            14
# 4  20. Amending Directive 2011/36/EU on preventin...            16
#
#                                         procedure_ID  partyfacts_ID  period  \
# 0   bill_26075_ID bill_26076_ID  bill_26075_ID bi...         6401.0       9
# 1                                                            6403.0       9
# 2                           bill_241_ID  bill_241_ID         6402.0       9
# 3                           bill_241_ID  bill_241_ID         6400.0       9
# 4                           bill_241_ID  bill_241_ID         6400.0       9
#
#    chair   MEP  commission  written  multispeaker  \
# 0  False  True       False    False         False
# 1  False  True       False    False         False
# 2  False  True       False    False         False
# 3  False  True       False    False         False
# 4  False  True       False    False         False
#
#                                                 link  \
# 0  https://www.europarl.europa.eu/doceo/document/...
# 1  https://www.europarl.europa.eu/doceo/document/...
# 2  https://www.europarl.europa.eu/doceo/document/...
# 3  https://www.europarl.europa.eu/doceo/document/...
# 4  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr President, thank you very much to the Commi...       original_gm  2024
# 1  Mr President, Commissioner. People who flee wa...       original_gm  2024
# 2  Madam President, in 2024, human trafficking co...        machine_gm  2024
# 3  Madam Commissioner! We need very specific, ver...        machine_gm  2024
# 4  Madam President, thank you, Mr Engerer, becaus...        machine_gm  2024
#
#              block            party  migration_prob ep_identifier  \
# 0          liberal  ELDR/ALDE/Renew        0.393282        197567
# 1            green       Greens/EFA        0.423501        197772
# 2             left     NGL/The Left        0.375925        254718
# 3  (extreme)_right              ECR        0.256493        197519
# 4  (extreme)_right              ECR        0.475315        204733
#
#             ep_label ep_citizenship ep_placeOfBirth     ep_bday ep_deathDate  \
# 0     Karen MELCHIOR            DNK        Gentofte  1980-10-15         None
# 1       Tineke STRIK            NLD       Appeltern  1961-09-28         None
# 2  Anabela RODRIGUES            PRT          Lisboa  1976-10-18         None
# 3        Beata KEMPA            POL           Syców  1966-02-11         None
# 4   Dorien ROOKMAKER            NLD           Zijpe  1964-07-30         None
#
#   ep_gender                                   ep_hasMembership
# 0    FEMALE  [{'id': 'membership/197567-f-161757', 'type': ...
# 1    FEMALE  [{'id': 'membership/197772-f-161044', 'type': ...
# 2    FEMALE  [{'id': 'membership/254718-f-169354', 'type': ...
# 3    FEMALE  [{'id': 'membership/197519-f-164917', 'type': ...
# 4    FEMALE  [{'id': 'membership/204733-f-161317', 'type': ...

# %%
original_nat_memberships_df = pd.read_parquet(PATH_INTERMED_CHES_53_ENRICHED_MEMBER, engine='fastparquet')
display(original_nat_memberships_df.head())
# Out:
#   person_id_memb        person_label_memb  \
# 0         103488  Sergio GUTIÉRREZ PRIETO
# 1         103488  Sergio GUTIÉRREZ PRIETO
# 2         103845         Virginie ROZIÈRE
# 3         103845         Virginie ROZIÈRE
# 4         111014       Josef WEIDENHOLZER
#
#                                   hasMembership_memb party_id_memb  \
# 0  [{'id': 'membership/103488-f-148559', 'type': ...          4025
# 1  [{'id': 'membership/103488-f-148559', 'type': ...          2714
# 2  [{'id': 'membership/103845-f-150436', 'type': ...          4277
# 3  [{'id': 'membership/103845-f-150436', 'type': ...          5040
# 4  [{'id': 'membership/111014-f-135825', 'type': ...          2659
#
#   member_startDate_memb member_endDate_memb member_role_memb  \
# 0            2014-07-01          2019-05-20           MEMBER
# 1            2010-07-19          2014-06-30           MEMBER
# 2            2014-07-01          2018-02-07           MEMBER
# 3            2018-02-08          2019-07-01           MEMBER
# 4            2011-12-01          2014-06-30           MEMBER
#
#            party_class_memb country_code_memb  \
# 0  NATIONAL_POLITICAL_GROUP               ESP
# 1  NATIONAL_POLITICAL_GROUP               ESP
# 2  NATIONAL_POLITICAL_GROUP               FRA
# 3  NATIONAL_POLITICAL_GROUP               FRA
# 4  NATIONAL_POLITICAL_GROUP               AUT
#
#                                  party_temporal_memb        party_label_memb  \
# 0  {'id': 'time-period/20140701-20190701', 'type'...                    PSOE
# 1  {'id': 'time-period/20090714-20140630', 'type'...                    PSOE
# 2  {'id': 'time-period/20140701-20190701', 'type'...                     PRG
# 3  {'id': 'time-period/20180208-20190701', 'type'...  Les radicaux de Gauche
# 4  {'id': 'time-period/20090714-20140630', 'type'...                     SPÖ
#
#       party_all_labels_memb                      party_all_names_memb  \
# 0                    [PSOE]       [Partido Socialista Obrero Español]
# 1                    [PSOE]       [Partido Socialista Obrero Español]
# 2                     [PRG]                 [Parti radical de gauche]
# 3  [Les radicaux de Gauche]                  [Les radicaux de Gauche]
# 4                     [SPÖ]  [Sozialdemokratische Partei Österreichs]
#
#   party_id_ches country_code_ches party_abbrev_ches  \
# 0           501               ESP            [PSOE]
# 1           501               ESP            [PSOE]
# 2           603               FRA             [PRG]
# 3           603               FRA             [PRG]
# 4          1301               AUT        [SPO, SPÖ]
#
#                             party_name_ches  \
# 0       [Partido Socialista Obrero Español]
# 1       [Partido Socialista Obrero Español]
# 2                 [Parti Radical de Gauche]
# 3                 [Parti Radical de Gauche]
# 4  [Sozialdemokratische Partei Österreichs]
#
#                      party_name_en_ches
# 0    [Spanish Socialist Workers’ Party]
# 1    [Spanish Socialist Workers’ Party]
# 2                  [Left Radical Party]
# 3                  [Left Radical Party]
# 4  [Social Democratic Party of Austria]

# %% [markdown]
# Apply some sanity checks beforehand, namely are there any overlaps in memberships for MEP's which would result in ambiguous mapping to CHES parties (what we do not want)?

# %%
# Work on copies
left_migration = original_migration_enriched_df.copy(deep=True)
right_membership = original_nat_memberships_df.copy(deep=True)
display(left_migration.head(3))
display(right_membership.head(3))
# Out:
#    Unnamed: 0            speaker  \
# 0         492     Karen Melchior
# 1         844       Tineke Strik
# 2        1050  Anabela Rodrigues
#
#                                                 text        date  \
# 0  Mr President, thank you very much to the Commi...  2024-04-24
# 1  Mr President, Commissioner. People who flee wa...  2024-04-23
# 2  Senhora Presidente, em 2024, o tráfico de sere...  2024-04-22
#
#                                               agenda  speechnumber  \
# 0  22. Advance passenger information: enhancing a...             8
# 1  17. EU-Egypt strategic and comprehensive partn...             9
# 2  20. Amending Directive 2011/36/EU on preventin...            10
#
#                                         procedure_ID  partyfacts_ID  period  \
# 0   bill_26075_ID bill_26076_ID  bill_26075_ID bi...         6401.0       9
# 1                                                            6403.0       9
# 2                           bill_241_ID  bill_241_ID         6402.0       9
#
#    chair   MEP  commission  written  multispeaker  \
# 0  False  True       False    False         False
# 1  False  True       False    False         False
# 2  False  True       False    False         False
#
#                                                 link  \
# 0  https://www.europarl.europa.eu/doceo/document/...
# 1  https://www.europarl.europa.eu/doceo/document/...
# 2  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr President, thank you very much to the Commi...       original_gm  2024
# 1  Mr President, Commissioner. People who flee wa...       original_gm  2024
# 2  Madam President, in 2024, human trafficking co...        machine_gm  2024
#
#      block            party  migration_prob ep_identifier           ep_label  \
# 0  liberal  ELDR/ALDE/Renew        0.393282        197567     Karen MELCHIOR
# 1    green       Greens/EFA        0.423501        197772       Tineke STRIK
# 2     left     NGL/The Left        0.375925        254718  Anabela RODRIGUES
#
#   ep_citizenship ep_placeOfBirth     ep_bday ep_deathDate ep_gender  \
# 0            DNK        Gentofte  1980-10-15         None    FEMALE
# 1            NLD       Appeltern  1961-09-28         None    FEMALE
# 2            PRT          Lisboa  1976-10-18         None    FEMALE
#
#                                     ep_hasMembership
# 0  [{'id': 'membership/197567-f-161757', 'type': ...
# 1  [{'id': 'membership/197772-f-161044', 'type': ...
# 2  [{'id': 'membership/254718-f-169354', 'type': ...
#   person_id_memb        person_label_memb  \
# 0         103488  Sergio GUTIÉRREZ PRIETO
# 1         103488  Sergio GUTIÉRREZ PRIETO
# 2         103845         Virginie ROZIÈRE
#
#                                   hasMembership_memb party_id_memb  \
# 0  [{'id': 'membership/103488-f-148559', 'type': ...          4025
# 1  [{'id': 'membership/103488-f-148559', 'type': ...          2714
# 2  [{'id': 'membership/103845-f-150436', 'type': ...          4277
#
#   member_startDate_memb member_endDate_memb member_role_memb  \
# 0            2014-07-01          2019-05-20           MEMBER
# 1            2010-07-19          2014-06-30           MEMBER
# 2            2014-07-01          2018-02-07           MEMBER
#
#            party_class_memb country_code_memb  \
# 0  NATIONAL_POLITICAL_GROUP               ESP
# 1  NATIONAL_POLITICAL_GROUP               ESP
# 2  NATIONAL_POLITICAL_GROUP               FRA
#
#                                  party_temporal_memb party_label_memb  \
# 0  {'id': 'time-period/20140701-20190701', 'type'...             PSOE
# 1  {'id': 'time-period/20090714-20140630', 'type'...             PSOE
# 2  {'id': 'time-period/20140701-20190701', 'type'...              PRG
#
#   party_all_labels_memb                 party_all_names_memb party_id_ches  \
# 0                [PSOE]  [Partido Socialista Obrero Español]           501
# 1                [PSOE]  [Partido Socialista Obrero Español]           501
# 2                 [PRG]            [Parti radical de gauche]           603
#
#   country_code_ches party_abbrev_ches                      party_name_ches  \
# 0               ESP            [PSOE]  [Partido Socialista Obrero Español]
# 1               ESP            [PSOE]  [Partido Socialista Obrero Español]
# 2               FRA             [PRG]            [Parti Radical de Gauche]
#
#                    party_name_en_ches
# 0  [Spanish Socialist Workers’ Party]
# 1  [Spanish Socialist Workers’ Party]
# 2                [Left Radical Party]

# %%
# look for overlaps in membership time periods (initial sanity check)

# Work on copies
left_migration = original_migration_enriched_df.copy(deep=True)
right_membership = original_nat_memberships_df.copy(deep=True)

# first check start <= end
relation_check = right_membership.dropna(subset=['member_endDate_memb'])
assert (relation_check["member_startDate_memb"] <= relation_check["member_endDate_memb"]).all()

# sort, keep track of previous end and check for overlaps
overlaps = (
    right_membership.sort_values(["person_id_memb", "member_startDate_memb"])
         .assign(prev_end=lambda d: d.groupby("person_id_memb")["member_endDate_memb"].shift())
         .query("prev_end >= member_startDate_memb")
)

if not overlaps.empty:
    raise ValueError(
        f"Overlapping intervals in 'memberships' detected:\n{overlaps}"
    )

# %%
# Work on copies
left_migration = original_migration_enriched_df.copy(deep=True)
right_membership = original_nat_memberships_df.copy(deep=True)

# Parse dates (YYYY-MM-DD)
left_migration["date"] = pd.to_datetime(left_migration["date"], format="%Y-%m-%d", errors="raise")
right_membership["member_startDate_memb"] = pd.to_datetime(right_membership["member_startDate_memb"], format="%Y-%m-%d", errors="raise")
right_membership["member_endDate_memb"] = pd.to_datetime(right_membership["member_endDate_memb"],   format="%Y-%m-%d", errors="raise")

# IMPORTANT for merge_asof: on-keys must be globally sorted ascending
left_migration  = left_migration.sort_values(["date", "ep_identifier"])
right_membership = right_membership.sort_values(["member_startDate_memb", "person_id_memb"])

# perform the merge
merged = pd.merge_asof(
    left_migration,
    right_membership,
    left_on="date",
    right_on="member_startDate_memb",
    left_by="ep_identifier",
    right_by="person_id_memb",
    direction="backward",
    allow_exact_matches=True,
)
print("FINISH MERGE AS OF")
# Out:
# FINISH MERGE AS OF

# %%
# Validate closed interval; keep all left rows, null out invalid matches (Important!)
rep_initial_size_left = left_migration.shape[0]
rep_init_amount_of_matches = merged.shape[0]
rep_init_amount_of_non_nans = merged["member_startDate_memb"].isna().sum()

valid = merged["member_startDate_memb"].notna() & (merged["date"] <= merged["member_endDate_memb"])
right_cols = right_membership.columns  # columns to blank when invalid
merged.loc[~valid, right_cols] = pd.NA

rep_after_amount_of_non_nans = merged["member_startDate_memb"].isna().sum()

print("Merge Report:")
print("Size of left dataframe:", rep_initial_size_left)
print("Size of merged df: ", rep_init_amount_of_matches)
print("Amount of not matched rows after merge_asof: ", merged.shape[0])
print("Amount of NaNs in column 'member_startDate' after invalidation: ", rep_after_amount_of_non_nans)

print("Result")
display(merged.sort_values(["date", "agenda", "speechnumber"]).head(10))
# Out:
# Merge Report:
# Size of left dataframe: 9705
# Size of merged df:  9705
# Amount of not matched rows after merge_asof:  9705
# Amount of NaNs in column 'member_startDate' after invalidation:  0
# Result
#     Unnamed: 0                        speaker  \
# 0       292003                   Amjad Bashir
# 1       292004            Miguel Arias Cañete
# 2       292025                Monika Smolková
# 3       291861               Kristina Winberg
# 4       291519  Ελισσάβετ Βόζεμπεργκ-Βρυωνίδη
# 5       291190                  Helga Stevens
# 7       290748                   Νότης Μαριάς
# 8       290785                       Tim Aker
# 6       290792                  Laura Ferrara
# 11      289949                   James Carver
#
#                                                  text       date  \
# 0   Mr Arias, we have heard about the injustice do... 2014-07-02
# 1   Sí, efectivamente, para luchar contra la inmig... 2014-07-02
# 2   – Taliansko predstavilo veľmi ambiciózny plán ... 2014-07-02
# 3   Fru talman! Schengenavtalet ingicks i en anda ... 2014-07-14
# 4   Αξιότιμε κύριε Juncker, στις προτεραιότητές σα... 2014-07-15
# 5   Ik denk inderdaad dat het een gedeelde verantw... 2014-07-16
# 7   Κύριε Πρόεδρε, οι οικονομικές σχέσεις της Ευρω... 2014-09-15
# 8   Mr President, on 16 August 2014, 35 migrants c... 2014-09-15
# 6   Signor Presidente, onorevoli colleghi, la cris... 2014-09-15
# 11  Does my colleague share the opinions of her co... 2014-09-17
#
#                                                agenda  speechnumber  \
# 0   12. Programme of activities of the Italian Pre...            41
# 1   12. Programme of activities of the Italian Pre...            42
# 2   12. Programme of activities of the Italian Pre...            63
# 3   13. One-minute speeches on matters of politica...            24
# 4   5. Statement by the candidate for President of...            25
# 5              8. Youth employment (debate)2014-07-16            52
# 7   19. Trade with Euromed countries (debate)2014-...             7
# 8        21. One-minute speeches (Rule 163)2014-09-15             9
# 6        21. One-minute speeches (Rule 163)2014-09-15            16
# 11  14. EU response to the Ebola outbreak (debate)...            15
#
#    procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                       6404.0       8  False  True       False    False
# 1                       6398.0       8  False  True       False    False
# 2                       6399.0       8  False  True       False     True
# 3                       6404.0       8  False  True       False    False
# 4                       6398.0       8  False  True       False     True
# 5                       6400.0       8  False  True       False    False
# 7                       6400.0       8  False  True       False    False
# 8                       6404.0       8  False  True       False    False
# 6                       6404.0       8  False  True       False    False
# 11                      6404.0       8  False  True       False    False
#
#     multispeaker                                               link  \
# 0          False  https://www.europarl.europa.eu/doceo/document/...
# 1          False  https://www.europarl.europa.eu/doceo/document/...
# 2          False  https://www.europarl.europa.eu/doceo/document/...
# 3          False  https://www.europarl.europa.eu/doceo/document/...
# 4          False  https://www.europarl.europa.eu/doceo/document/...
# 5          False  https://www.europarl.europa.eu/doceo/document/...
# 7          False  https://www.europarl.europa.eu/doceo/document/...
# 8          False  https://www.europarl.europa.eu/doceo/document/...
# 6          False  https://www.europarl.europa.eu/doceo/document/...
# 11         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                        translatedText translationSource  year  \
# 0   Mr Arias, we have heard about the injustice do...       original_pl  2014
# 1   Yes, indeed, to fight against immigration we m...        machine_pl  2014
# 2   - Italy presented a very ambitious plan for it...        machine_pl  2014
# 3   Fru talman! The Schengen Agreement was conclud...        machine_pl  2014
# 4   Dear Mr Juncker, in your priorities you refer ...        machine_pl  2014
# 5   I indeed think that it is a shared responsibil...        machine_pl  2014
# 7   Mr. President, the economic relations of the E...        machine_pl  2014
# 8   Mr President, on 16 August 2014, 35 migrants c...       original_pl  2014
# 6   Mr President, ladies and gentlemen, the Italia...        machine_pl  2014
# 11  Does my colleague share the opinions of her co...       original_pl  2014
#
#                      block           party  migration_prob ep_identifier  \
# 0          (extreme)_right  EDD/INDDEM/EFD        0.257913        124956
# 1   christian_conservative             PPE        0.494101          1351
# 2        social_democratic         PSE/S&D        0.323411         96655
# 3          (extreme)_right  EDD/INDDEM/EFD        0.700463        124995
# 4   christian_conservative             PPE        0.604105        125065
# 5          (extreme)_right             ECR        0.636441        125105
# 7          (extreme)_right             ECR        0.414057        125069
# 8          (extreme)_right  EDD/INDDEM/EFD        0.363552         99650
# 6          (extreme)_right  EDD/INDDEM/EFD        0.744003        124833
# 11         (extreme)_right  EDD/INDDEM/EFD        0.335978        124971
#
#                         ep_label ep_citizenship ep_placeOfBirth     ep_bday  \
# 0                   Amjad BASHIR            GBR     Jhelum (PK)  1952-09-17
# 1            Miguel ARIAS CAÑETE            ESP          Madrid  1950-02-24
# 2                Monika SMOLKOVÁ            SVK         Janovík  1956-10-06
# 3               Kristina WINBERG            SWE            None  1965-05-27
# 4   Elissavet VOZEMBERG-VRIONIDI            GRC          Athina  1956-09-14
# 5                  Helga STEVENS            BEL    Sint-Truiden  1968-08-09
# 7                   Notis MARIAS            GRC    Thessaloniki  1957-04-05
# 8                       Tim AKER            GBR          Orsett  1985-05-23
# 6                  Laura FERRARA            ITA          Napoli  1983-09-11
# 11                  James CARVER            GBR            None  1969-08-15
#
#    ep_deathDate ep_gender                                   ep_hasMembership  \
# 0          None      MALE  [{'id': 'membership/124956-f-143535', 'type': ...
# 1          None      MALE  [{'id': 'membership/1351-f-105362', 'type': 'M...
# 2          None    FEMALE  [{'id': 'membership/96655-m-15750', 'type': 'M...
# 3          None    FEMALE  [{'id': 'membership/124995-f-142235', 'type': ...
# 4          None    FEMALE  [{'id': 'membership/125065-f-151010', 'type': ...
# 5          None    FEMALE  [{'id': 'membership/125105-f-142627', 'type': ...
# 7          None      MALE  [{'id': 'membership/125069-f-146981', 'type': ...
# 8          None      MALE  [{'id': 'membership/99650-f-152990', 'type': '...
# 6          None    FEMALE  [{'id': 'membership/124833-m-15310', 'type': '...
# 11         None      MALE  [{'id': 'membership/124971-f-142125', 'type': ...
#
#    person_id_memb             person_label_memb  \
# 0          124956                  Amjad BASHIR
# 1            1351           Miguel ARIAS CAÑETE
# 2           96655               Monika SMOLKOVÁ
# 3          124995              Kristina WINBERG
# 4          125065  Elissavet VOZEMBERG-VRIONIDI
# 5          125105                 Helga STEVENS
# 7          125069                  Notis MARIAS
# 8           99650                      Tim AKER
# 6          124833                 Laura FERRARA
# 11         124971                  James CARVER
#
#                                    hasMembership_memb party_id_memb  \
# 0   [{'id': 'membership/124956-f-143535', 'type': ...          4051
# 1   [{'id': 'membership/1351-f-105362', 'type': 'M...          4024
# 2   [{'id': 'membership/96655-m-15750', 'type': 'M...          4159
# 3   [{'id': 'membership/124995-f-142235', 'type': ...          4253
# 4   [{'id': 'membership/125065-f-151010', 'type': ...          4055
# 5   [{'id': 'membership/125105-f-142627', 'type': ...          3986
# 7   [{'id': 'membership/125069-f-146981', 'type': ...          4269
# 8   [{'id': 'membership/99650-f-152990', 'type': '...          4051
# 6   [{'id': 'membership/124833-m-15310', 'type': '...          4083
# 11  [{'id': 'membership/124971-f-142125', 'type': ...          4051
#
#    member_startDate_memb member_endDate_memb member_role_memb  \
# 0             2014-07-01          2015-01-28           MEMBER
# 1             2014-07-01          2014-10-31           MEMBER
# 2             2014-07-01          2019-07-01           MEMBER
# 3             2014-07-01          2019-07-01           MEMBER
# 4             2014-07-01          2019-07-01           MEMBER
# 5             2014-07-01          2019-07-01           MEMBER
# 7             2014-07-01          2015-01-06           MEMBER
# 8             2014-07-01          2018-12-05           MEMBER
# 6             2014-07-01          2019-07-01           MEMBER
# 11            2014-07-01          2018-05-27           MEMBER
#
#             party_class_memb country_code_memb  \
# 0   NATIONAL_POLITICAL_GROUP               GBR
# 1   NATIONAL_POLITICAL_GROUP               ESP
# 2   NATIONAL_POLITICAL_GROUP               SVK
# 3   NATIONAL_POLITICAL_GROUP               SWE
# 4   NATIONAL_POLITICAL_GROUP               GRC
# 5   NATIONAL_POLITICAL_GROUP               BEL
# 7   NATIONAL_POLITICAL_GROUP               GRC
# 8   NATIONAL_POLITICAL_GROUP               GBR
# 6   NATIONAL_POLITICAL_GROUP               ITA
# 11  NATIONAL_POLITICAL_GROUP               GBR
#
#                                   party_temporal_memb     party_label_memb  \
# 0   {'id': 'time-period/20140701-20190701', 'type'...                 UKIP
# 1   {'id': 'time-period/20140701-20190701', 'type'...                   PP
# 2   {'id': 'time-period/20140701-20190701', 'type'...              SMER-SD
# 3   {'id': 'time-period/20140701-20190701', 'type'...  Sverigedemokraterna
# 4   {'id': 'time-period/20140701-20190701', 'type'...                 N.D.
# 5   {'id': 'time-period/20140701-20190701', 'type'...                 N-VA
# 7   {'id': 'time-period/20140701-20190701', 'type'...   Independent Greeks
# 8   {'id': 'time-period/20140701-20190701', 'type'...                 UKIP
# 6   {'id': 'time-period/20140701-20190701', 'type'...                  M5S
# 11  {'id': 'time-period/20140701-20190701', 'type'...                 UKIP
#
#                         party_all_labels_memb  \
# 0                                      [UKIP]
# 1                                        [PP]
# 2                                   [SMER-SD]
# 3                       [Sverigedemokraterna]
# 4                                [Ν.Δ., N.D.]
# 5                                      [N-VA]
# 7   [Ανεξάρτητοι Έλληνες, Independent Greeks]
# 8                                      [UKIP]
# 6                                       [M5S]
# 11                                     [UKIP]
#
#                          party_all_names_memb party_id_ches country_code_ches  \
# 0         [United Kingdom Independence Party]          1108               GBR
# 1                           [Partido Popular]           502               ESP
# 2                  [SMER-Sociálna demokracia]          2803               SVK
# 3                       [Sverigedemokraterna]          1610               SWE
# 4            [Νέα Δημοκρατία, Nea Demokratia]           402               GRC
# 5                   [Nieuw-Vlaamse Alliantie]           110               BEL
# 7   [Ανεξάρτητοι Έλληνες, Independent Greeks]           412               GRC
# 8         [United Kingdom Independence Party]          1108               GBR
# 6                        [Movimento 5 Stelle]           845               ITA
# 11        [United Kingdom Independence Party]          1108               GBR
#
#     party_abbrev_ches                                    party_name_ches  \
# 0              [UKIP]                [United Kingdom Independence Party]
# 1                [PP]         [Partido Popular, Alianza-Partido Popular]
# 2     [Smer, Smer-SD]  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
# 3                [SD]                              [Sverigedemokraterna]
# 4                [ND]                                   [Néa Dimokratía]
# 5   [NVA, VU, VU/NVA]               [Volksunie, Nieuw-Vlaamse Alliantie]
# 7              [ANEL]                              [Anexartitoi Ellines]
# 8              [UKIP]                [United Kingdom Independence Party]
# 6          [M5S, MS5]                          [MoVimento Cinque Stelle]
# 11             [UKIP]                [United Kingdom Independence Party]
#
#                                    party_name_en_ches
# 0                 [United Kingdom Independence Party]
# 1           [People’s Party, People’s Alliance Party]
# 2   [Direction–Third Way, Direction–Social Democracy]
# 3                                  [Sweden Democrats]
# 4                                     [New Democracy]
# 5              [People’s Union, New Flemish Alliance]
# 7                                [Independent Greeks]
# 8                 [United Kingdom Independence Party]
# 6                                [Five Star Movement]
# 11                [United Kingdom Independence Party]

# %% [markdown]
# Wonderful this looks good, so let's proceed with the original merge

# %%
# Work on copies
speeches = original_migration_enriched_df.copy(deep=True)
memb = original_nat_memberships_df.copy(deep=True)

# quick check we do not have any null speeches
assert speeches["date"].isna().sum() == 0

# Parse dates (YYYY-MM-DD)
speeches["date"] = pd.to_datetime(speeches["date"], format="%Y-%m-%d", errors="raise")
memb["member_startDate_memb"] = pd.to_datetime(memb["member_startDate_memb"], format="%Y-%m-%d", errors="raise")
memb["member_endDate_memb"] = pd.to_datetime(memb["member_endDate_memb"],   format="%Y-%m-%d", errors="raise")

# Required sorting for merge_asof
speeches = speeches.sort_values(["date", "ep_identifier"])
memb = memb.sort_values(["member_startDate_memb", "person_id_memb"])

# As-of join: latest membership start <= speech date, per person
merged = pd.merge_asof(
    speeches,
    memb,
    left_on="date",
    right_on="member_startDate_memb",
    left_by="ep_identifier",
    right_by="person_id_memb",
    direction="backward",
    allow_exact_matches=True,
)

# Closed-interval validity check
valid = (
    merged["person_id_memb"].notna() &
    (merged["date"] <= merged["member_endDate_memb"])
)

# Invalidate memberships that don't cover the speech date
membership_cols = memb.columns
merged.loc[~valid, membership_cols] = pd.NA

# %%
# work on copy
merged_copy = merged.copy(deep=True)

# %%
display(merged_copy.head())
# How many speeches have no membership?
print("Speeches without membership:",
      merged_copy["person_id_memb"].isna().sum())

# Should be true if memberships are clean
assert merged_copy.groupby("ep_identifier")["member_startDate_memb"].is_monotonic_increasing.any() is not None

print("Left monotonic:", speeches["date"].is_monotonic_increasing) # should be true
print("Right monotonic:", memb["member_startDate_memb"].is_monotonic_increasing) # should be true

# how many speeches do not have a ches score?
print("Amount of speeches in migration in total:", merged_copy.shape[0])
print(original_migration_enriched_df.shape[0])
print("Speeches without ches score:",
      merged_copy["party_id_ches"].isna().sum())
# Out:
#    Unnamed: 0                        speaker  \
# 0      292003                   Amjad Bashir
# 1      292004            Miguel Arias Cañete
# 2      292025                Monika Smolková
# 3      291861               Kristina Winberg
# 4      291519  Ελισσάβετ Βόζεμπεργκ-Βρυωνίδη
#
#                                                 text       date  \
# 0  Mr Arias, we have heard about the injustice do... 2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig... 2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ... 2014-07-02
# 3  Fru talman! Schengenavtalet ingicks i en anda ... 2014-07-14
# 4  Αξιότιμε κύριε Juncker, στις προτεραιότητές σα... 2014-07-15
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
# 3  13. One-minute speeches on matters of politica...            24
# 4  5. Statement by the candidate for President of...            25
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
# 3                      6404.0       8  False  True       False    False
# 4                      6398.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
# 3         False  https://www.europarl.europa.eu/doceo/document/...
# 4         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl  2014
# 1  Yes, indeed, to fight against immigration we m...        machine_pl  2014
# 2  - Italy presented a very ambitious plan for it...        machine_pl  2014
# 3  Fru talman! The Schengen Agreement was conclud...        machine_pl  2014
# 4  Dear Mr Juncker, in your priorities you refer ...        machine_pl  2014
#
#                     block           party  migration_prob ep_identifier  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913        124956
# 1  christian_conservative             PPE        0.494101          1351
# 2       social_democratic         PSE/S&D        0.323411         96655
# 3         (extreme)_right  EDD/INDDEM/EFD        0.700463        124995
# 4  christian_conservative             PPE        0.604105        125065
#
#                        ep_label ep_citizenship ep_placeOfBirth     ep_bday  \
# 0                  Amjad BASHIR            GBR     Jhelum (PK)  1952-09-17
# 1           Miguel ARIAS CAÑETE            ESP          Madrid  1950-02-24
# 2               Monika SMOLKOVÁ            SVK         Janovík  1956-10-06
# 3              Kristina WINBERG            SWE            None  1965-05-27
# 4  Elissavet VOZEMBERG-VRIONIDI            GRC          Athina  1956-09-14
#
#   ep_deathDate ep_gender                                   ep_hasMembership  \
# 0         None      MALE  [{'id': 'membership/124956-f-143535', 'type': ...
# 1         None      MALE  [{'id': 'membership/1351-f-105362', 'type': 'M...
# 2         None    FEMALE  [{'id': 'membership/96655-m-15750', 'type': 'M...
# 3         None    FEMALE  [{'id': 'membership/124995-f-142235', 'type': ...
# 4         None    FEMALE  [{'id': 'membership/125065-f-151010', 'type': ...
#
#   person_id_memb             person_label_memb  \
# 0         124956                  Amjad BASHIR
# 1           1351           Miguel ARIAS CAÑETE
# 2          96655               Monika SMOLKOVÁ
# 3         124995              Kristina WINBERG
# 4         125065  Elissavet VOZEMBERG-VRIONIDI
#
#                                   hasMembership_memb party_id_memb  \
# 0  [{'id': 'membership/124956-f-143535', 'type': ...          4051
# 1  [{'id': 'membership/1351-f-105362', 'type': 'M...          4024
# 2  [{'id': 'membership/96655-m-15750', 'type': 'M...          4159
# 3  [{'id': 'membership/124995-f-142235', 'type': ...          4253
# 4  [{'id': 'membership/125065-f-151010', 'type': ...          4055
#
#   member_startDate_memb member_endDate_memb member_role_memb  \
# 0            2014-07-01          2015-01-28           MEMBER
# 1            2014-07-01          2014-10-31           MEMBER
# 2            2014-07-01          2019-07-01           MEMBER
# 3            2014-07-01          2019-07-01           MEMBER
# 4            2014-07-01          2019-07-01           MEMBER
#
#            party_class_memb country_code_memb  \
# 0  NATIONAL_POLITICAL_GROUP               GBR
# 1  NATIONAL_POLITICAL_GROUP               ESP
# 2  NATIONAL_POLITICAL_GROUP               SVK
# 3  NATIONAL_POLITICAL_GROUP               SWE
# 4  NATIONAL_POLITICAL_GROUP               GRC
#
#                                  party_temporal_memb     party_label_memb  \
# 0  {'id': 'time-period/20140701-20190701', 'type'...                 UKIP
# 1  {'id': 'time-period/20140701-20190701', 'type'...                   PP
# 2  {'id': 'time-period/20140701-20190701', 'type'...              SMER-SD
# 3  {'id': 'time-period/20140701-20190701', 'type'...  Sverigedemokraterna
# 4  {'id': 'time-period/20140701-20190701', 'type'...                 N.D.
#
#    party_all_labels_memb                 party_all_names_memb party_id_ches  \
# 0                 [UKIP]  [United Kingdom Independence Party]          1108
# 1                   [PP]                    [Partido Popular]           502
# 2              [SMER-SD]           [SMER-Sociálna demokracia]          2803
# 3  [Sverigedemokraterna]                [Sverigedemokraterna]          1610
# 4           [Ν.Δ., N.D.]     [Νέα Δημοκρατία, Nea Demokratia]           402
#
#   country_code_ches party_abbrev_ches  \
# 0               GBR            [UKIP]
# 1               ESP              [PP]
# 2               SVK   [Smer, Smer-SD]
# 3               SWE              [SD]
# 4               GRC              [ND]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
# 3                              [Sverigedemokraterna]
# 4                                   [Néa Dimokratía]
#
#                                   party_name_en_ches
# 0                [United Kingdom Independence Party]
# 1          [People’s Party, People’s Alliance Party]
# 2  [Direction–Third Way, Direction–Social Democracy]
# 3                                 [Sweden Democrats]
# 4                                    [New Democracy]
# Speeches without membership: 0
# Left monotonic: True
# Right monotonic: True
# Amount of speeches in migration in total: 9705
# 9705
# Speeches without ches score: 848

# %%
test = merged.loc[merged["member_startDate_memb"] <= "2014-07-01"] #, ["date", "member_startDate", "member_endDate"]] # first speech in migration dataset on new term (beginning in 01.07.2014)
display(test.head())
# Out:
#    Unnamed: 0                        speaker  \
# 0      292003                   Amjad Bashir
# 1      292004            Miguel Arias Cañete
# 2      292025                Monika Smolková
# 3      291861               Kristina Winberg
# 4      291519  Ελισσάβετ Βόζεμπεργκ-Βρυωνίδη
#
#                                                 text       date  \
# 0  Mr Arias, we have heard about the injustice do... 2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig... 2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ... 2014-07-02
# 3  Fru talman! Schengenavtalet ingicks i en anda ... 2014-07-14
# 4  Αξιότιμε κύριε Juncker, στις προτεραιότητές σα... 2014-07-15
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
# 3  13. One-minute speeches on matters of politica...            24
# 4  5. Statement by the candidate for President of...            25
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
# 3                      6404.0       8  False  True       False    False
# 4                      6398.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
# 3         False  https://www.europarl.europa.eu/doceo/document/...
# 4         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl  2014
# 1  Yes, indeed, to fight against immigration we m...        machine_pl  2014
# 2  - Italy presented a very ambitious plan for it...        machine_pl  2014
# 3  Fru talman! The Schengen Agreement was conclud...        machine_pl  2014
# 4  Dear Mr Juncker, in your priorities you refer ...        machine_pl  2014
#
#                     block           party  migration_prob ep_identifier  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913        124956
# 1  christian_conservative             PPE        0.494101          1351
# 2       social_democratic         PSE/S&D        0.323411         96655
# 3         (extreme)_right  EDD/INDDEM/EFD        0.700463        124995
# 4  christian_conservative             PPE        0.604105        125065
#
#                        ep_label ep_citizenship ep_placeOfBirth     ep_bday  \
# 0                  Amjad BASHIR            GBR     Jhelum (PK)  1952-09-17
# 1           Miguel ARIAS CAÑETE            ESP          Madrid  1950-02-24
# 2               Monika SMOLKOVÁ            SVK         Janovík  1956-10-06
# 3              Kristina WINBERG            SWE            None  1965-05-27
# 4  Elissavet VOZEMBERG-VRIONIDI            GRC          Athina  1956-09-14
#
#   ep_deathDate ep_gender                                   ep_hasMembership  \
# 0         None      MALE  [{'id': 'membership/124956-f-143535', 'type': ...
# 1         None      MALE  [{'id': 'membership/1351-f-105362', 'type': 'M...
# 2         None    FEMALE  [{'id': 'membership/96655-m-15750', 'type': 'M...
# 3         None    FEMALE  [{'id': 'membership/124995-f-142235', 'type': ...
# 4         None    FEMALE  [{'id': 'membership/125065-f-151010', 'type': ...
#
#   person_id_memb             person_label_memb  \
# 0         124956                  Amjad BASHIR
# 1           1351           Miguel ARIAS CAÑETE
# 2          96655               Monika SMOLKOVÁ
# 3         124995              Kristina WINBERG
# 4         125065  Elissavet VOZEMBERG-VRIONIDI
#
#                                   hasMembership_memb party_id_memb  \
# 0  [{'id': 'membership/124956-f-143535', 'type': ...          4051
# 1  [{'id': 'membership/1351-f-105362', 'type': 'M...          4024
# 2  [{'id': 'membership/96655-m-15750', 'type': 'M...          4159
# 3  [{'id': 'membership/124995-f-142235', 'type': ...          4253
# 4  [{'id': 'membership/125065-f-151010', 'type': ...          4055
#
#   member_startDate_memb member_endDate_memb member_role_memb  \
# 0            2014-07-01          2015-01-28           MEMBER
# 1            2014-07-01          2014-10-31           MEMBER
# 2            2014-07-01          2019-07-01           MEMBER
# 3            2014-07-01          2019-07-01           MEMBER
# 4            2014-07-01          2019-07-01           MEMBER
#
#            party_class_memb country_code_memb  \
# 0  NATIONAL_POLITICAL_GROUP               GBR
# 1  NATIONAL_POLITICAL_GROUP               ESP
# 2  NATIONAL_POLITICAL_GROUP               SVK
# 3  NATIONAL_POLITICAL_GROUP               SWE
# 4  NATIONAL_POLITICAL_GROUP               GRC
#
#                                  party_temporal_memb     party_label_memb  \
# 0  {'id': 'time-period/20140701-20190701', 'type'...                 UKIP
# 1  {'id': 'time-period/20140701-20190701', 'type'...                   PP
# 2  {'id': 'time-period/20140701-20190701', 'type'...              SMER-SD
# 3  {'id': 'time-period/20140701-20190701', 'type'...  Sverigedemokraterna
# 4  {'id': 'time-period/20140701-20190701', 'type'...                 N.D.
#
#    party_all_labels_memb                 party_all_names_memb party_id_ches  \
# 0                 [UKIP]  [United Kingdom Independence Party]          1108
# 1                   [PP]                    [Partido Popular]           502
# 2              [SMER-SD]           [SMER-Sociálna demokracia]          2803
# 3  [Sverigedemokraterna]                [Sverigedemokraterna]          1610
# 4           [Ν.Δ., N.D.]     [Νέα Δημοκρατία, Nea Demokratia]           402
#
#   country_code_ches party_abbrev_ches  \
# 0               GBR            [UKIP]
# 1               ESP              [PP]
# 2               SVK   [Smer, Smer-SD]
# 3               SWE              [SD]
# 4               GRC              [ND]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
# 3                              [Sverigedemokraterna]
# 4                                   [Néa Dimokratía]
#
#                                   party_name_en_ches
# 0                [United Kingdom Independence Party]
# 1          [People’s Party, People’s Alliance Party]
# 2  [Direction–Third Way, Direction–Social Democracy]
# 3                                 [Sweden Democrats]
# 4                                    [New Democracy]

# %% [markdown]
# Alrighty, lets store this for the final merge/enrichment with the CHES survey scores/waves

# %%
# store as parquet file
#merged.to_parquet(PATH_INTERMED_CHES_54_MIG_W_CHES_META, engine='fastparquet')
