# %%
import os
if not os.environ.get("PREAMBLE_RUN", False): 
    # %run -i "../preamble.py" 2

# %%
import pandas as pd
import requests
import numpy as np

from src.constants import PATH_INTERMED_CHES_54_MIG_W_CHES_META, PATH_ORIGINAL_CHES_RAW_CSV, PATH_MIGRATION_SPEECHES, PATH_MIGRATION_CHES, PATH_MIGRATION_CHES_FALLBACK

# set display options for the notebook
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# Finally, now that we have it all togethet let's replace/enrich the CHES metadata of every row in our migration dataset with the actual CHES scores / survey data corresponding to the time of the speech. Since, for our migration dataset, we only have CHES datapoints for the years 2014, 2019 and 2024 we will do this in different ways/variants, namely:
# - **exact match only**: we only map the rows (i.e. the combinations of speech/speaker/national parties) of 2014, 2019 and 2024 to the corresponding CHES scores of that national party
# - **fallback match**: for each speech we match with the lastest CHES score available (i.e. if CHES score for 2014 exists for given speaker/party, map his '2015 speeches' also to this 2014 score)
# - **interpolated match**: for all speeches with missing CHES score after exact match, we check if there are CHES scores which "bracket" this speech, e.g. for a '2016 speech' the CHES sores of 2014 and 2019 would bracket, and we then perform a year-wise linear interpolation to infer the score (this assumes there is a somewhat smooth transition between the CHES scores over the years reflecting the position change of parties in the ideological space over time)
# -> see more in the dedicated script

# %% [markdown]
# Load the dataset we want to merge

# %%
# load the data
# 1) the migration dataset (pls) enriched with meta information about the speaker (i.e. national party affiliation and the corresponding [CHES] party id)
enriched_migration_df = pd.read_parquet(PATH_INTERMED_CHES_54_MIG_W_CHES_META, engine='fastparquet')
# (2) the raw CHES dataset to enrich the migration set with (i.e. replace the CHES meta information with the actual scorings / survey items)
raw_CHES_df = pd.read_parquet(PATH_ORIGINAL_CHES_RAW_CSV, engine='fastparquet')
# 3) the vanilla/plain migration (pls) dataset to get part of the desired output columns (i.e. drop the rest of cols)
plain_migration_df = pd.read_parquet(PATH_MIGRATION_SPEECHES, engine='fastparquet')

# %%
print("enriched migration data:")
display(enriched_migration_df.head(3))
print("raw CHES data:")
display(raw_CHES_df.head(3))
print("vanilla/plain migration data:")
display(plain_migration_df.head(3))
# Out:
# enriched migration data:
#    Unnamed: 0              speaker  \
# 0      292003         Amjad Bashir
# 1      292004  Miguel Arias Cañete
# 2      292025      Monika Smolková
#
#                                                 text       date  \
# 0  Mr Arias, we have heard about the injustice do... 2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig... 2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ... 2014-07-02
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl  2014
# 1  Yes, indeed, to fight against immigration we m...        machine_pl  2014
# 2  - Italy presented a very ambitious plan for it...        machine_pl  2014
#
#                     block           party  migration_prob ep_identifier  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913        124956
# 1  christian_conservative             PPE        0.494101          1351
# 2       social_democratic         PSE/S&D        0.323411         96655
#
#               ep_label ep_citizenship ep_placeOfBirth     ep_bday  \
# 0         Amjad BASHIR            GBR     Jhelum (PK)  1952-09-17
# 1  Miguel ARIAS CAÑETE            ESP          Madrid  1950-02-24
# 2      Monika SMOLKOVÁ            SVK         Janovík  1956-10-06
#
#   ep_deathDate ep_gender                                   ep_hasMembership  \
# 0         None      MALE  [{'id': 'membership/124956-f-143535', 'type': ...
# 1         None      MALE  [{'id': 'membership/1351-f-105362', 'type': 'M...
# 2         None    FEMALE  [{'id': 'membership/96655-m-15750', 'type': 'M...
#
#   person_id_memb    person_label_memb  \
# 0         124956         Amjad BASHIR
# 1           1351  Miguel ARIAS CAÑETE
# 2          96655      Monika SMOLKOVÁ
#
#                                   hasMembership_memb party_id_memb  \
# 0  [{'id': 'membership/124956-f-143535', 'type': ...          4051
# 1  [{'id': 'membership/1351-f-105362', 'type': 'M...          4024
# 2  [{'id': 'membership/96655-m-15750', 'type': 'M...          4159
#
#   member_startDate_memb member_endDate_memb member_role_memb  \
# 0            2014-07-01          2015-01-28           MEMBER
# 1            2014-07-01          2014-10-31           MEMBER
# 2            2014-07-01          2019-07-01           MEMBER
#
#            party_class_memb country_code_memb  \
# 0  NATIONAL_POLITICAL_GROUP               GBR
# 1  NATIONAL_POLITICAL_GROUP               ESP
# 2  NATIONAL_POLITICAL_GROUP               SVK
#
#                                  party_temporal_memb party_label_memb  \
# 0  {'id': 'time-period/20140701-20190701', 'type'...             UKIP
# 1  {'id': 'time-period/20140701-20190701', 'type'...               PP
# 2  {'id': 'time-period/20140701-20190701', 'type'...          SMER-SD
#
#   party_all_labels_memb                 party_all_names_memb party_id_ches  \
# 0                [UKIP]  [United Kingdom Independence Party]          1108
# 1                  [PP]                    [Partido Popular]           502
# 2             [SMER-SD]           [SMER-Sociálna demokracia]          2803
#
#   country_code_ches party_abbrev_ches  \
# 0               GBR            [UKIP]
# 1               ESP              [PP]
# 2               SVK   [Smer, Smer-SD]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
#
#                                   party_name_en_ches
# 0                [United Kingdom Independence Party]
# 1          [People’s Party, People’s Alliance Party]
# 2  [Direction–Third Way, Direction–Social Democracy]
# raw CHES data:
#    year  country  eastwest  eumember  party_id party   cmp_id  vote  \
# 0  1999        1         1         1       102    PS  21322.0  10.2
# 1  2002        1         1         1       102    PS  21322.0  10.2
# 2  2006        1         1         1       102    PS  21322.0  13.0
#
#         seat  electionyear  epvote  family  govt     lrgen  lrecon  \
# 0  12.700000          1999    9.59       5   1.0  3.111111   2.625
# 1  12.700000          1999    9.59       5   1.0  3.350000   2.500
# 2  16.700001          2003   13.50       5   1.0  3.500000   3.170
#
#    lrecon_salience  lrecon_dissent  lrecon_blur  galtan  galtan_salience  \
# 0              NaN             NaN          NaN   3.875              NaN
# 1              NaN             NaN          NaN   4.000              NaN
# 2              NaN             NaN          NaN   2.830              NaN
#
#    galtan_dissent  galtan_blur  eu_position  eu_salience  eu_dissent  eu_blur  \
# 0             NaN          NaN     6.666667     4.722222    1.388889      NaN
# 1             NaN          NaN     6.090000     4.533333    2.111111      NaN
# 2             NaN          NaN     5.710000     4.300000    3.430000      NaN
#
#    spendvtax  spendvtax_salience  deregulation  dereg_salience  \
# 0        NaN                 NaN           NaN             NaN
# 1        NaN                 NaN           NaN             NaN
# 2       2.67                 6.5          2.33            6.83
#
#    redistribution  redist_salience  econ_interven  civlib_laworder  \
# 0             NaN              NaN            NaN              NaN
# 1             NaN              NaN            NaN              NaN
# 2             2.0              8.0            NaN             3.67
#
#    civlib_salience  sociallifestyle  social_salience  womens_rights  \
# 0              NaN              NaN              NaN            NaN
# 1              NaN              NaN              NaN            NaN
# 2              6.5             2.33             5.67            NaN
#
#    lgbtq_rights  samesex_marriage  religious_principles  relig_salience  \
# 0           NaN               NaN                   NaN             NaN
# 1           NaN               NaN                   NaN             NaN
# 2           NaN               NaN                  1.33            5.67
#
#    immigrate_policy  immigrate_salience  immigrate_dissent  multiculturalism  \
# 0               NaN                 NaN                NaN               NaN
# 1               NaN                 NaN                NaN               NaN
# 2               2.5                6.33                NaN               4.2
#
#    multicult_salience  multicult_dissent  nationalism  nationalism_salience  \
# 0                 NaN                NaN          NaN                   NaN
# 1                 NaN                NaN          NaN                   NaN
# 2                 NaN                NaN         3.17                  4.33
#
#    ethnic_minorities  ethnic_salience  urban_rural  urban_salience  \
# 0                NaN              NaN          NaN             NaN
# 1                NaN              NaN          NaN             NaN
# 2               3.17             6.33          4.4             3.0
#
#    environment  enviro_salience  climate_change  climate_change_salience  \
# 0          NaN              NaN             NaN                      NaN
# 1          NaN              NaN             NaN                      NaN
# 2          NaN              NaN             NaN                      NaN
#
#    protectionism  regions  region_salience  international_security  \
# 0            NaN      NaN              NaN                     NaN
# 1            NaN      NaN              NaN                     NaN
# 2            NaN     6.17              7.0                     NaN
#
#    international_salience    us  us_salience  eu_benefit     eu_ep  eu_fiscal  \
# 0                     NaN   NaN          NaN         NaN  6.333333   6.666667
# 1                     NaN   NaN          NaN         NaN  6.000000        NaN
# 2                     NaN  2.67          3.5         NaN  6.500000        NaN
#
#    eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  eu_environ  \
# 0         NaN   6.555555         NaN      NaN        6.625    5.888889
# 1         4.1   6.550000         NaN     4.88        5.850    5.000000
# 2         4.0        NaN         NaN      NaN        6.670         NaN
#
#    eu_asylum  eu_foreign  eu_turkey  eu_russia  russian_interference  \
# 0   5.666667    6.555555        NaN        NaN                   NaN
# 1   6.300000    6.330000        NaN        NaN                   NaN
# 2        NaN    5.830000        6.0        NaN                   NaN
#
#    anti_islam_rhetoric  people_vs_elite  antielite_salience  corrupt_salience  \
# 0                  NaN              NaN                 NaN               NaN
# 1                  NaN              NaN                 NaN               NaN
# 2                  NaN              NaN                 NaN               NaN
#
#    members_vs_leadership  executive_power  judicial_independence  mip_one  \
# 0                    NaN              NaN                    NaN      NaN
# 1                    NaN              NaN                    NaN      NaN
# 2                    NaN              NaN                    NaN      NaN
#
#    mip_two  mip_three  chesversion
# 0      NaN        NaN       2025.1
# 1      NaN        NaN       2025.1
# 2      NaN        NaN       2025.1
# vanilla/plain migration data:
#                Unnamed: 0            speaker  \
# 1660703242768         492     Karen Melchior
# 1661057279072         844       Tineke Strik
# 1661377510144        1050  Anabela Rodrigues
#
#                                                             text        date  \
# 1660703242768  Mr President, thank you very much to the Commi...  2024-04-24
# 1661057279072  Mr President, Commissioner. People who flee wa...  2024-04-23
# 1661377510144  Senhora Presidente, em 2024, o tráfico de sere...  2024-04-22
#
#                                                           agenda  \
# 1660703242768  22. Advance passenger information: enhancing a...
# 1661057279072  17. EU-Egypt strategic and comprehensive partn...
# 1661377510144  20. Amending Directive 2011/36/EU on preventin...
#
#                speechnumber  \
# 1660703242768             8
# 1661057279072             9
# 1661377510144            10
#
#                                                     procedure_ID  \
# 1660703242768   bill_26075_ID bill_26076_ID  bill_26075_ID bi...
# 1661057279072
# 1661377510144                           bill_241_ID  bill_241_ID
#
#                partyfacts_ID  period  chair   MEP  commission  written  \
# 1660703242768         6401.0       9  False  True       False    False
# 1661057279072         6403.0       9  False  True       False    False
# 1661377510144         6402.0       9  False  True       False    False
#
#                multispeaker  \
# 1660703242768         False
# 1661057279072         False
# 1661377510144         False
#
#                                                             link  \
# 1660703242768  https://www.europarl.europa.eu/doceo/document/...
# 1661057279072  https://www.europarl.europa.eu/doceo/document/...
# 1661377510144  https://www.europarl.europa.eu/doceo/document/...
#
#                                                   translatedText  \
# 1660703242768  Mr President, thank you very much to the Commi...
# 1661057279072  Mr President, Commissioner. People who flee wa...
# 1661377510144  Madam President, in 2024, human trafficking co...
#
#               translationSource  year    block            party  \
# 1660703242768       original_gm  2024  liberal  ELDR/ALDE/Renew
# 1661057279072       original_gm  2024    green       Greens/EFA
# 1661377510144        machine_gm  2024     left     NGL/The Left
#
#                migration_prob
# 1660703242768        0.393282
# 1661057279072        0.423501
# 1661377510144        0.375925

# %% [markdown]
# Prepare the datasets for merging

# %%
# work on copies
minim_enriched_migration_df = enriched_migration_df.copy(deep=True)
harmonized_CHES_df = raw_CHES_df.copy(deep=True)

# %%
# only keep the relevant columns we also have in the original migration dataset (+ the ones we need for the final merge)
output_cols_migration = plain_migration_df.columns.tolist()
output_cols_merger = ["ep_identifier", "party_id_memb", "party_id_ches", "party_label_memb", "party_all_labels_memb", "party_all_names_memb", "party_name_ches", "party_name_en_ches"]
output_cols_minim_all = output_cols_migration + output_cols_merger
# unify column names for the merge process
minim_enriched_migration_df = minim_enriched_migration_df[output_cols_minim_all].rename(columns={"ep_identifier" : "person_id_ep", "party_id_memb" : "party_id_ep", "party_label_memb" : "party_label_ep", "party_all_labels_memb" : "party_all_labels_ep", "party_all_names_memb" : "party_all_names_ep"})
display(minim_enriched_migration_df.head(3))
# Out:
#    Unnamed: 0              speaker  \
# 0      292003         Amjad Bashir
# 1      292004  Miguel Arias Cañete
# 2      292025      Monika Smolková
#
#                                                 text       date  \
# 0  Mr Arias, we have heard about the injustice do... 2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig... 2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ... 2014-07-02
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl  2014
# 1  Yes, indeed, to fight against immigration we m...        machine_pl  2014
# 2  - Italy presented a very ambitious plan for it...        machine_pl  2014
#
#                     block           party  migration_prob person_id_ep  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913       124956
# 1  christian_conservative             PPE        0.494101         1351
# 2       social_democratic         PSE/S&D        0.323411        96655
#
#   party_id_ep party_id_ches party_label_ep party_all_labels_ep  \
# 0        4051          1108           UKIP              [UKIP]
# 1        4024           502             PP                [PP]
# 2        4159          2803        SMER-SD           [SMER-SD]
#
#                     party_all_names_ep  \
# 0  [United Kingdom Independence Party]
# 1                    [Partido Popular]
# 2           [SMER-Sociálna demokracia]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
#
#                                   party_name_en_ches
# 0                [United Kingdom Independence Party]
# 1          [People’s Party, People’s Alliance Party]
# 2  [Direction–Third Way, Direction–Social Democracy]

# %%
# harmonize the relevant migration and ches dataset/columns (for merging)
harmonized_CHES_df = harmonized_CHES_df
display(harmonized_CHES_df.info())

# convert "year" and "party_id" col dtype to (pandas) string type
harmonized_CHES_df["party_id"] = harmonized_CHES_df["party_id"].astype("string").str.strip()
harmonized_CHES_df["year"] = harmonized_CHES_df["year"].astype("string").str.strip()
display(harmonized_CHES_df.info())

# do same for migration dataset
#display(minim_enriched_migration_df.info())
minim_enriched_migration_df["party_id_ches"] = minim_enriched_migration_df["party_id_ches"].astype("string").str.strip()
minim_enriched_migration_df["year"] = minim_enriched_migration_df["year"].astype("string").str.strip()
minim_enriched_migration_df["date"] = minim_enriched_migration_df["date"].astype("string").str.strip()
display(minim_enriched_migration_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1441 entries, 0 to 1440
# Data columns (total 90 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     1441 non-null   int64
#  1   country                  1441 non-null   int64
#  2   eastwest                 1441 non-null   int64
#  3   eumember                 1441 non-null   int64
#  4   party_id                 1441 non-null   int64
#  5   party                    1437 non-null   object
#  6   cmp_id                   1134 non-null   float64
#  7   vote                     1377 non-null   float64
#  8   seat                     1372 non-null   float64
#  9   electionyear             1441 non-null   int64
#  10  epvote                   1221 non-null   float64
#  11  family                   1441 non-null   int64
#  12  govt                     1196 non-null   float64
#  13  lrgen                    1441 non-null   float64
#  14  lrecon                   1441 non-null   float64
#  15  lrecon_salience          737 non-null    float64
#  16  lrecon_dissent           490 non-null    float64
#  17  lrecon_blur              489 non-null    float64
#  18  galtan                   1440 non-null   float64
#  19  galtan_salience          737 non-null    float64
#  20  galtan_dissent           477 non-null    float64
#  21  galtan_blur              489 non-null    float64
#  22  eu_position              1441 non-null   float64
#  23  eu_salience              1437 non-null   float64
#  24  eu_dissent               1434 non-null   float64
#  25  eu_blur                  490 non-null    float64
#  26  spendvtax                1124 non-null   float64
#  27  spendvtax_salience       389 non-null    float64
#  28  deregulation             1125 non-null   float64
#  29  dereg_salience           389 non-null    float64
#  30  redistribution           1125 non-null   float64
#  31  redist_salience          879 non-null    float64
#  32  econ_interven            492 non-null    float64
#  33  civlib_laworder          1123 non-null   float64
#  34  civlib_salience          389 non-null    float64
#  35  sociallifestyle          880 non-null    float64
#  36  social_salience          388 non-null    float64
#  37  womens_rights            244 non-null    float64
#  38  lgbtq_rights             244 non-null    float64
#  39  samesex_marriage         245 non-null    float64
#  40  religious_principles     1123 non-null   float64
#  41  relig_salience           388 non-null    float64
#  42  immigrate_policy         1120 non-null   float64
#  43  immigrate_salience       879 non-null    float64
#  44  immigrate_dissent        491 non-null    float64
#  45  multiculturalism         1118 non-null   float64
#  46  multicult_salience       694 non-null    float64
#  47  multicult_dissent        246 non-null    float64
#  48  nationalism              919 non-null    float64
#  49  nationalism_salience     183 non-null    float64
#  50  ethnic_minorities        1124 non-null   float64
#  51  ethnic_salience          387 non-null    float64
#  52  urban_rural              1110 non-null   float64
#  53  urban_salience           384 non-null    float64
#  54  environment              939 non-null    float64
#  55  enviro_salience          695 non-null    float64
#  56  climate_change           244 non-null    float64
#  57  climate_change_salience  244 non-null    float64
#  58  protectionism            485 non-null    float64
#  59  regions                  1118 non-null   float64
#  60  region_salience          381 non-null    float64
#  61  international_security   448 non-null    float64
#  62  international_salience   203 non-null    float64
#  63  us                       186 non-null    float64
#  64  us_salience              186 non-null    float64
#  65  eu_benefit               448 non-null    float64
#  66  eu_ep                    942 non-null    float64
#  67  eu_fiscal                142 non-null    float64
#  68  eu_intmark               1295 non-null   float64
#  69  eu_employ                309 non-null    float64
#  70  eu_budgets               491 non-null    float64
#  71  eu_agri                  171 non-null    float64
#  72  eu_cohesion              1188 non-null   float64
#  73  eu_environ               312 non-null    float64
#  74  eu_asylum                559 non-null    float64
#  75  eu_foreign               1438 non-null   float64
#  76  eu_turkey                626 non-null    float64
#  77  eu_russia                243 non-null    float64
#  78  russian_interference     247 non-null    float64
#  79  anti_islam_rhetoric      487 non-null    float64
#  80  people_vs_elite          492 non-null    float64
#  81  antielite_salience       737 non-null    float64
#  82  corrupt_salience         727 non-null    float64
#  83  members_vs_leadership    246 non-null    float64
#  84  executive_power          244 non-null    float64
#  85  judicial_independence    240 non-null    float64
#  86  mip_one                  231 non-null    float64
#  87  mip_two                  229 non-null    float64
#  88  mip_three                227 non-null    float64
#  89  chesversion              1441 non-null   float64
# dtypes: float64(82), int64(7), object(1)
# memory usage: 1013.3+ KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 1441 entries, 0 to 1440
# Data columns (total 90 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     1441 non-null   string
#  1   country                  1441 non-null   int64
#  2   eastwest                 1441 non-null   int64
#  3   eumember                 1441 non-null   int64
#  4   party_id                 1441 non-null   string
#  5   party                    1437 non-null   object
#  6   cmp_id                   1134 non-null   float64
#  7   vote                     1377 non-null   float64
#  8   seat                     1372 non-null   float64
#  9   electionyear             1441 non-null   int64
#  10  epvote                   1221 non-null   float64
#  11  family                   1441 non-null   int64
#  12  govt                     1196 non-null   float64
#  13  lrgen                    1441 non-null   float64
#  14  lrecon                   1441 non-null   float64
#  15  lrecon_salience          737 non-null    float64
#  16  lrecon_dissent           490 non-null    float64
#  17  lrecon_blur              489 non-null    float64
#  18  galtan                   1440 non-null   float64
#  19  galtan_salience          737 non-null    float64
#  20  galtan_dissent           477 non-null    float64
#  21  galtan_blur              489 non-null    float64
#  22  eu_position              1441 non-null   float64
#  23  eu_salience              1437 non-null   float64
#  24  eu_dissent               1434 non-null   float64
#  25  eu_blur                  490 non-null    float64
#  26  spendvtax                1124 non-null   float64
#  27  spendvtax_salience       389 non-null    float64
#  28  deregulation             1125 non-null   float64
#  29  dereg_salience           389 non-null    float64
#  30  redistribution           1125 non-null   float64
#  31  redist_salience          879 non-null    float64
#  32  econ_interven            492 non-null    float64
#  33  civlib_laworder          1123 non-null   float64
#  34  civlib_salience          389 non-null    float64
#  35  sociallifestyle          880 non-null    float64
#  36  social_salience          388 non-null    float64
#  37  womens_rights            244 non-null    float64
#  38  lgbtq_rights             244 non-null    float64
#  39  samesex_marriage         245 non-null    float64
#  40  religious_principles     1123 non-null   float64
#  41  relig_salience           388 non-null    float64
#  42  immigrate_policy         1120 non-null   float64
#  43  immigrate_salience       879 non-null    float64
#  44  immigrate_dissent        491 non-null    float64
#  45  multiculturalism         1118 non-null   float64
#  46  multicult_salience       694 non-null    float64
#  47  multicult_dissent        246 non-null    float64
#  48  nationalism              919 non-null    float64
#  49  nationalism_salience     183 non-null    float64
#  50  ethnic_minorities        1124 non-null   float64
#  51  ethnic_salience          387 non-null    float64
#  52  urban_rural              1110 non-null   float64
#  53  urban_salience           384 non-null    float64
#  54  environment              939 non-null    float64
#  55  enviro_salience          695 non-null    float64
#  56  climate_change           244 non-null    float64
#  57  climate_change_salience  244 non-null    float64
#  58  protectionism            485 non-null    float64
#  59  regions                  1118 non-null   float64
#  60  region_salience          381 non-null    float64
#  61  international_security   448 non-null    float64
#  62  international_salience   203 non-null    float64
#  63  us                       186 non-null    float64
#  64  us_salience              186 non-null    float64
#  65  eu_benefit               448 non-null    float64
#  66  eu_ep                    942 non-null    float64
#  67  eu_fiscal                142 non-null    float64
#  68  eu_intmark               1295 non-null   float64
#  69  eu_employ                309 non-null    float64
#  70  eu_budgets               491 non-null    float64
#  71  eu_agri                  171 non-null    float64
#  72  eu_cohesion              1188 non-null   float64
#  73  eu_environ               312 non-null    float64
#  74  eu_asylum                559 non-null    float64
#  75  eu_foreign               1438 non-null   float64
#  76  eu_turkey                626 non-null    float64
#  77  eu_russia                243 non-null    float64
#  78  russian_interference     247 non-null    float64
#  79  anti_islam_rhetoric      487 non-null    float64
#  80  people_vs_elite          492 non-null    float64
#  81  antielite_salience       737 non-null    float64
#  82  corrupt_salience         727 non-null    float64
#  83  members_vs_leadership    246 non-null    float64
#  84  executive_power          244 non-null    float64
#  85  judicial_independence    240 non-null    float64
#  86  mip_one                  231 non-null    float64
#  87  mip_two                  229 non-null    float64
#  88  mip_three                227 non-null    float64
#  89  chesversion              1441 non-null   float64
# dtypes: float64(82), int64(5), object(1), string(2)
# memory usage: 1013.3+ KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 9705 entries, 0 to 9704
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           9705 non-null   int64
#  1   speaker              9705 non-null   object
#  2   text                 9705 non-null   object
#  3   date                 9705 non-null   string
#  4   agenda               9705 non-null   object
#  5   speechnumber         9705 non-null   int64
#  6   procedure_ID         9705 non-null   object
#  7   partyfacts_ID        8529 non-null   float64
#  8   period               9705 non-null   int64
#  9   chair                9705 non-null   bool
#  10  MEP                  9705 non-null   bool
#  11  commission           9705 non-null   bool
#  12  written              9705 non-null   bool
#  13  multispeaker         9705 non-null   bool
#  14  link                 9705 non-null   object
#  15  translatedText       9705 non-null   object
#  16  translationSource    9705 non-null   object
#  17  year                 9705 non-null   string
#  18  block                9705 non-null   object
#  19  party                9705 non-null   object
#  20  migration_prob       9705 non-null   float64
#  21  person_id_ep         9705 non-null   object
#  22  party_id_ep          9705 non-null   object
#  23  party_id_ches        8857 non-null   string
#  24  party_label_ep       9705 non-null   object
#  25  party_all_labels_ep  9705 non-null   object
#  26  party_all_names_ep   9705 non-null   object
#  27  party_name_ches      8857 non-null   object
#  28  party_name_en_ches   8857 non-null   object
# dtypes: bool(5), float64(2), int64(3), object(16), string(3)
# memory usage: 1.8+ MB
# None

# %% [markdown]
# Lets first make a plain/exact merge (i.e. only match rows where party IDs overlap and date of speech lies in the year of the corresponding CHES score/survey for that party)

# %%
# first parse date and extract year (as string to match right_df["year"])
minim_enriched_migration_df["year"] = pd.to_datetime(minim_enriched_migration_df["date"], errors="coerce").dt.year.astype("string").str.strip()

# %%
# perform a left join (enrich left with right columns)
migration_with_CHES_plain = minim_enriched_migration_df.merge(
    harmonized_CHES_df,
    how="left",
    left_on=["party_id_ches", "year"],
    right_on=["party_id", "year"],
    suffixes=("_mig", "_ches"),
    validate="m:1",   # should be a many-to-one merge
)
display(migration_with_CHES_plain.head(3))
# Out:
#    Unnamed: 0              speaker  \
# 0      292003         Amjad Bashir
# 1      292004  Miguel Arias Cañete
# 2      292025      Monika Smolková
#
#                                                 text        date  \
# 0  Mr Arias, we have heard about the injustice do...  2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig...  2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ...  2014-07-02
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl  2014
# 1  Yes, indeed, to fight against immigration we m...        machine_pl  2014
# 2  - Italy presented a very ambitious plan for it...        machine_pl  2014
#
#                     block       party_mig  migration_prob person_id_ep  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913       124956
# 1  christian_conservative             PPE        0.494101         1351
# 2       social_democratic         PSE/S&D        0.323411        96655
#
#   party_id_ep party_id_ches party_label_ep party_all_labels_ep  \
# 0        4051          1108           UKIP              [UKIP]
# 1        4024           502             PP                [PP]
# 2        4159          2803        SMER-SD           [SMER-SD]
#
#                     party_all_names_ep  \
# 0  [United Kingdom Independence Party]
# 1                    [Partido Popular]
# 2           [SMER-Sociálna demokracia]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
#
#                                   party_name_en_ches  country  eastwest  \
# 0                [United Kingdom Independence Party]     11.0       1.0
# 1          [People’s Party, People’s Alliance Party]      5.0       1.0
# 2  [Direction–Third Way, Direction–Social Democracy]     28.0       0.0
#
#    eumember party_id party_ches   cmp_id  vote       seat  electionyear  \
# 0       1.0     1108       UKIP  51951.0   3.1   0.000000        2010.0
# 1       1.0      502         PP  33610.0  41.9  53.099998        2011.0
# 2       1.0     2803    Smer-SD  96423.0  44.4  55.299999        2012.0
#
#    epvote  family  govt     lrgen    lrecon  lrecon_salience  lrecon_dissent  \
# 0    27.5     1.0   0.0  9.142858  8.571428         5.142857             NaN
# 1    26.1     2.0   1.0  7.300000  7.666667         8.777778             NaN
# 2    24.1     5.0   1.0  3.692308  2.571429         8.642858             NaN
#
#    lrecon_blur    galtan  galtan_salience  galtan_dissent  galtan_blur  \
# 0          NaN  9.285714         8.142858             NaN          NaN
# 1          NaN  8.000000         7.222222             NaN          NaN
# 2          NaN  6.928571         4.846154             NaN          NaN
#
#    eu_position  eu_salience  eu_dissent  eu_blur  spendvtax  \
# 0     1.142857     9.142858    0.714286      NaN   8.833333
# 1     6.800000     6.900000    0.600000      NaN   7.600000
# 2     6.142857     6.571429    1.454546      NaN   2.714286
#
#    spendvtax_salience  deregulation  dereg_salience  redistribution  \
# 0                 NaN      8.333333             NaN        7.500000
# 1                 NaN      7.900000             NaN        7.600000
# 2                 NaN      2.214286             NaN        2.642857
#
#    redist_salience  econ_interven  civlib_laworder  civlib_salience  \
# 0              NaN       8.500000         8.857142              NaN
# 1              NaN       7.300000         8.300000              NaN
# 2              NaN       1.714286         6.923077              NaN
#
#    sociallifestyle  social_salience  womens_rights  lgbtq_rights  \
# 0         8.500000              NaN            NaN           NaN
# 1         7.000000              NaN            NaN           NaN
# 2         6.692307              NaN            NaN           NaN
#
#    samesex_marriage  religious_principles  relig_salience  immigrate_policy  \
# 0               NaN              6.800000             NaN         10.000000
# 1               NaN              7.800000             NaN          8.100000
# 2               NaN              4.857143             NaN          6.461538
#
#    immigrate_salience  immigrate_dissent  multiculturalism  \
# 0                 NaN                NaN          9.800000
# 1                 NaN                NaN          8.250000
# 2                 NaN                NaN          6.416666
#
#    multicult_salience  multicult_dissent  nationalism  nationalism_salience  \
# 0                 NaN                NaN     9.833333                   NaN
# 1                 NaN                NaN     7.200000                   NaN
# 2                 NaN                NaN     6.785714                   NaN
#
#    ethnic_minorities  ethnic_salience  urban_rural  urban_salience  \
# 0           8.428572              NaN     5.666667             NaN
# 1           7.444445              NaN     5.500000             NaN
# 2           7.307693              NaN     5.857143             NaN
#
#    environment  enviro_salience  climate_change  climate_change_salience  \
# 0     9.000000              NaN             NaN                      NaN
# 1     7.375000              NaN             NaN                      NaN
# 2     7.153846              NaN             NaN                      NaN
#
#    protectionism  regions  region_salience  international_security  \
# 0            NaN     5.75              NaN                5.000000
# 1            NaN     7.50              NaN                2.444444
# 2            NaN     7.00              NaN                5.000000
#
#    international_salience  us  us_salience  eu_benefit     eu_ep  eu_fiscal  \
# 0                     NaN NaN          NaN         3.0  1.166667        NaN
# 1                     NaN NaN          NaN         1.0  5.666667        NaN
# 2                     NaN NaN          NaN         1.0  5.900000        NaN
#
#    eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  eu_environ  \
# 0    2.571429        NaN    1.142857      NaN     1.285714         NaN
# 1    6.700000        NaN    5.555555      NaN     6.750000         NaN
# 2    5.846154        NaN    5.071429      NaN     6.833333         NaN
#
#    eu_asylum  eu_foreign  eu_turkey  eu_russia  russian_interference  \
# 0        NaN    1.285714   1.000000        NaN                   NaN
# 1        NaN    6.750000   4.555555        NaN                   NaN
# 2        NaN    5.153846   4.600000        NaN                   NaN
#
#    anti_islam_rhetoric  people_vs_elite  antielite_salience  corrupt_salience  \
# 0                  NaN              NaN            9.285714          6.800000
# 1                  NaN              NaN            1.400000          3.400000
# 2                  NaN              NaN            3.714286          3.785714
#
#    members_vs_leadership  executive_power  judicial_independence  mip_one  \
# 0                    NaN              NaN                    NaN      9.0
# 1                    NaN              NaN                    NaN     13.0
# 2                    NaN              NaN                    NaN     14.0
#
#    mip_two  mip_three  chesversion
# 0      8.0        1.0       2025.1
# 1      5.0       12.0       2025.1
# 2     17.0       13.0       2025.1

# %% [markdown]
# Now perform some sanity checks

# %%
# compute match rate (how many left rows found a right row)
match_rate = migration_with_CHES_plain["chesversion"].notna().mean() * 100
print(f"Match rate: {match_rate:.1f}%")
match_rate = migration_with_CHES_plain["eumember"].notna().mean() * 100
print(f"Match rate: {match_rate:.1f}%")
print(migration_with_CHES_plain["eumember"].notna().sum())
# Out:
# Match rate: 6.8%
# Match rate: 6.8%
# 661

# %%
# woah this is quite low, check if this adds up in the migration dataset
ches_years = harmonized_CHES_df["year"].unique()
print(ches_years)
ches_migration_pls_overlap_rate = minim_enriched_migration_df["year"].isin(ches_years).mean() * 100
print(f"(Ches Year) Overlap rate: {ches_migration_pls_overlap_rate:.1f}%")

# only for parties that turn up in our ches dataset now
ches_ids = harmonized_CHES_df["party_id"].unique()
only_ches_ids_overlap = minim_enriched_migration_df.loc[minim_enriched_migration_df["year"].isin(ches_years) & minim_enriched_migration_df["party_id_ches"].isin(ches_ids)]
print(only_ches_ids_overlap.shape[0])
# result: the numbers seem about right (considering we have not checked for exact match between speech date and ches year here)
# Out:
# <StringArray>
# ['1999', '2002', '2006', '2010', '2014', '2019', '2024']
# Length: 7, dtype: string
# (Ches Year) Overlap rate: 7.7%
# 689

# %%
# store the merged data anyways
migration_with_CHES_exact = migration_with_CHES_plain.copy(deep=True).rename(columns={"party_ches": "party_label_ches", "year_mig" : "year", "party_mig" : "party"})
display(migration_with_CHES_exact.head(3))
# Out:
#    Unnamed: 0              speaker  \
# 0      292003         Amjad Bashir
# 1      292004  Miguel Arias Cañete
# 2      292025      Monika Smolková
#
#                                                 text        date  \
# 0  Mr Arias, we have heard about the injustice do...  2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig...  2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ...  2014-07-02
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl  2014
# 1  Yes, indeed, to fight against immigration we m...        machine_pl  2014
# 2  - Italy presented a very ambitious plan for it...        machine_pl  2014
#
#                     block           party  migration_prob person_id_ep  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913       124956
# 1  christian_conservative             PPE        0.494101         1351
# 2       social_democratic         PSE/S&D        0.323411        96655
#
#   party_id_ep party_id_ches party_label_ep party_all_labels_ep  \
# 0        4051          1108           UKIP              [UKIP]
# 1        4024           502             PP                [PP]
# 2        4159          2803        SMER-SD           [SMER-SD]
#
#                     party_all_names_ep  \
# 0  [United Kingdom Independence Party]
# 1                    [Partido Popular]
# 2           [SMER-Sociálna demokracia]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
#
#                                   party_name_en_ches  country  eastwest  \
# 0                [United Kingdom Independence Party]     11.0       1.0
# 1          [People’s Party, People’s Alliance Party]      5.0       1.0
# 2  [Direction–Third Way, Direction–Social Democracy]     28.0       0.0
#
#    eumember party_id party_label_ches   cmp_id  vote       seat  electionyear  \
# 0       1.0     1108             UKIP  51951.0   3.1   0.000000        2010.0
# 1       1.0      502               PP  33610.0  41.9  53.099998        2011.0
# 2       1.0     2803          Smer-SD  96423.0  44.4  55.299999        2012.0
#
#    epvote  family  govt     lrgen    lrecon  lrecon_salience  lrecon_dissent  \
# 0    27.5     1.0   0.0  9.142858  8.571428         5.142857             NaN
# 1    26.1     2.0   1.0  7.300000  7.666667         8.777778             NaN
# 2    24.1     5.0   1.0  3.692308  2.571429         8.642858             NaN
#
#    lrecon_blur    galtan  galtan_salience  galtan_dissent  galtan_blur  \
# 0          NaN  9.285714         8.142858             NaN          NaN
# 1          NaN  8.000000         7.222222             NaN          NaN
# 2          NaN  6.928571         4.846154             NaN          NaN
#
#    eu_position  eu_salience  eu_dissent  eu_blur  spendvtax  \
# 0     1.142857     9.142858    0.714286      NaN   8.833333
# 1     6.800000     6.900000    0.600000      NaN   7.600000
# 2     6.142857     6.571429    1.454546      NaN   2.714286
#
#    spendvtax_salience  deregulation  dereg_salience  redistribution  \
# 0                 NaN      8.333333             NaN        7.500000
# 1                 NaN      7.900000             NaN        7.600000
# 2                 NaN      2.214286             NaN        2.642857
#
#    redist_salience  econ_interven  civlib_laworder  civlib_salience  \
# 0              NaN       8.500000         8.857142              NaN
# 1              NaN       7.300000         8.300000              NaN
# 2              NaN       1.714286         6.923077              NaN
#
#    sociallifestyle  social_salience  womens_rights  lgbtq_rights  \
# 0         8.500000              NaN            NaN           NaN
# 1         7.000000              NaN            NaN           NaN
# 2         6.692307              NaN            NaN           NaN
#
#    samesex_marriage  religious_principles  relig_salience  immigrate_policy  \
# 0               NaN              6.800000             NaN         10.000000
# 1               NaN              7.800000             NaN          8.100000
# 2               NaN              4.857143             NaN          6.461538
#
#    immigrate_salience  immigrate_dissent  multiculturalism  \
# 0                 NaN                NaN          9.800000
# 1                 NaN                NaN          8.250000
# 2                 NaN                NaN          6.416666
#
#    multicult_salience  multicult_dissent  nationalism  nationalism_salience  \
# 0                 NaN                NaN     9.833333                   NaN
# 1                 NaN                NaN     7.200000                   NaN
# 2                 NaN                NaN     6.785714                   NaN
#
#    ethnic_minorities  ethnic_salience  urban_rural  urban_salience  \
# 0           8.428572              NaN     5.666667             NaN
# 1           7.444445              NaN     5.500000             NaN
# 2           7.307693              NaN     5.857143             NaN
#
#    environment  enviro_salience  climate_change  climate_change_salience  \
# 0     9.000000              NaN             NaN                      NaN
# 1     7.375000              NaN             NaN                      NaN
# 2     7.153846              NaN             NaN                      NaN
#
#    protectionism  regions  region_salience  international_security  \
# 0            NaN     5.75              NaN                5.000000
# 1            NaN     7.50              NaN                2.444444
# 2            NaN     7.00              NaN                5.000000
#
#    international_salience  us  us_salience  eu_benefit     eu_ep  eu_fiscal  \
# 0                     NaN NaN          NaN         3.0  1.166667        NaN
# 1                     NaN NaN          NaN         1.0  5.666667        NaN
# 2                     NaN NaN          NaN         1.0  5.900000        NaN
#
#    eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  eu_environ  \
# 0    2.571429        NaN    1.142857      NaN     1.285714         NaN
# 1    6.700000        NaN    5.555555      NaN     6.750000         NaN
# 2    5.846154        NaN    5.071429      NaN     6.833333         NaN
#
#    eu_asylum  eu_foreign  eu_turkey  eu_russia  russian_interference  \
# 0        NaN    1.285714   1.000000        NaN                   NaN
# 1        NaN    6.750000   4.555555        NaN                   NaN
# 2        NaN    5.153846   4.600000        NaN                   NaN
#
#    anti_islam_rhetoric  people_vs_elite  antielite_salience  corrupt_salience  \
# 0                  NaN              NaN            9.285714          6.800000
# 1                  NaN              NaN            1.400000          3.400000
# 2                  NaN              NaN            3.714286          3.785714
#
#    members_vs_leadership  executive_power  judicial_independence  mip_one  \
# 0                    NaN              NaN                    NaN      9.0
# 1                    NaN              NaN                    NaN     13.0
# 2                    NaN              NaN                    NaN     14.0
#
#    mip_two  mip_three  chesversion
# 0      8.0        1.0       2025.1
# 1      5.0       12.0       2025.1
# 2     17.0       13.0       2025.1

# %%
# migration_with_CHES_exact.to_parquet(PATH_MIGRATION_CHES, engine='fastparquet')

# %% [markdown]
# **Intermed Result_01**
#
# Apparently, we only have around 7% of our migration speech dates fall exactly in a year where there exists a corresponding ches score. This is less than expected.
#
# **Consequence**
#
# Lets try to do a fallback merge instead, and see how that changes things (i.e. if there exists no exactly matching ches score for given speech date, take the nearest on in the past)

# %%
# Let's merge such that each speech/row of migration dataset gets the nearest survey row (of CHES data) of the past for the corresponding national party of the MEP giving the speech

# first sanity check that the combination of "year" and "party_id_ches" value is unique such that we don't end up with any ties during merging
if harmonized_CHES_df.duplicated(subset=["party_id", "year"]).any():
    ties = (harmonized_CHES_df[harmonized_CHES_df.duplicated(["party_id", "year"], keep=False)]
            .sort_values(["party_id", "year"]))
    raise ValueError(
        "Right dataframe has ties (multiple rows) for the same (party_id, year). "
        "Resolve before asof-merge.\n"
        f"Example ties:\n{ties.head(20)}"
    )

# %%
# perform a merge_asof (for this the keys need to be sorted)
# work on copies
left = minim_enriched_migration_df.copy(deep=True).reset_index(drop=True)
left["_row_id"] = left.index # keep this to later resort to original order
right = harmonized_CHES_df.copy(deep=True)

# convert year to Int64
left["year"] = left["year"].astype("Int64")
right["year"] = right["year"].astype("Int64")
right["_year"] = right["year"].astype("Int64") # helper column for merge

# %%
# avoid nulls in the on-keys
assert left["year"].notna().all()
assert right["_year"].notna().all()

# %%
# now merge with a merge_asof (after sorting the keys)
left_sorted  = left.sort_values(["year", "party_id_ches"])
right_sorted = right.sort_values(["year", "party_id"])

# backward does what we want: match the nearest key on the right that is <= the left key
migration_with_CHES_fallback = pd.merge_asof(
    left_sorted,
    right_sorted,
    left_on="year",
    right_on="_year",
    left_by="party_id_ches",
    right_by="party_id",
    direction="backward",      # <= date (still before)
    allow_exact_matches=True,
    suffixes=("_mig", "_ches")# year-date equal to date is allowed; False if we want strictly before
).drop(columns=["_year"]) # drop helper column again

# restore the original order
migration_with_CHES_fallback = migration_with_CHES_fallback.sort_values("_row_id").drop(columns="_row_id")

# %%
# add indicator if fallback or exact match
migration_with_CHES_fallback["fallback_used"] = (migration_with_CHES_fallback["year_mig"] > migration_with_CHES_fallback["year_ches"]).astype("boolean")

# %%
display(migration_with_CHES_fallback.head())
# Out:
#      Unnamed: 0                        speaker  \
# 18       292003                   Amjad Bashir
# 150      292004            Miguel Arias Cañete
# 84       292025                Monika Smolková
# 57       291861               Kristina Winberg
# 130      291519  Ελισσάβετ Βόζεμπεργκ-Βρυωνίδη
#
#                                                   text        date  \
# 18   Mr Arias, we have heard about the injustice do...  2014-07-02
# 150  Sí, efectivamente, para luchar contra la inmig...  2014-07-02
# 84   – Taliansko predstavilo veľmi ambiciózny plán ...  2014-07-02
# 57   Fru talman! Schengenavtalet ingicks i en anda ...  2014-07-14
# 130  Αξιότιμε κύριε Juncker, στις προτεραιότητές σα...  2014-07-15
#
#                                                 agenda  speechnumber  \
# 18   12. Programme of activities of the Italian Pre...            41
# 150  12. Programme of activities of the Italian Pre...            42
# 84   12. Programme of activities of the Italian Pre...            63
# 57   13. One-minute speeches on matters of politica...            24
# 130  5. Statement by the candidate for President of...            25
#
#     procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 18                       6404.0       8  False  True       False    False
# 150                      6398.0       8  False  True       False    False
# 84                       6399.0       8  False  True       False     True
# 57                       6404.0       8  False  True       False    False
# 130                      6398.0       8  False  True       False     True
#
#      multispeaker                                               link  \
# 18          False  https://www.europarl.europa.eu/doceo/document/...
# 150         False  https://www.europarl.europa.eu/doceo/document/...
# 84          False  https://www.europarl.europa.eu/doceo/document/...
# 57          False  https://www.europarl.europa.eu/doceo/document/...
# 130         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                         translatedText translationSource  \
# 18   Mr Arias, we have heard about the injustice do...       original_pl
# 150  Yes, indeed, to fight against immigration we m...        machine_pl
# 84   - Italy presented a very ambitious plan for it...        machine_pl
# 57   Fru talman! The Schengen Agreement was conclud...        machine_pl
# 130  Dear Mr Juncker, in your priorities you refer ...        machine_pl
#
#      year_mig                   block       party_mig  migration_prob  \
# 18       2014         (extreme)_right  EDD/INDDEM/EFD        0.257913
# 150      2014  christian_conservative             PPE        0.494101
# 84       2014       social_democratic         PSE/S&D        0.323411
# 57       2014         (extreme)_right  EDD/INDDEM/EFD        0.700463
# 130      2014  christian_conservative             PPE        0.604105
#
#     person_id_ep party_id_ep party_id_ches       party_label_ep  \
# 18        124956        4051          1108                 UKIP
# 150         1351        4024           502                   PP
# 84         96655        4159          2803              SMER-SD
# 57        124995        4253          1610  Sverigedemokraterna
# 130       125065        4055           402                 N.D.
#
#        party_all_labels_ep                   party_all_names_ep  \
# 18                  [UKIP]  [United Kingdom Independence Party]
# 150                   [PP]                    [Partido Popular]
# 84               [SMER-SD]           [SMER-Sociálna demokracia]
# 57   [Sverigedemokraterna]                [Sverigedemokraterna]
# 130           [Ν.Δ., N.D.]     [Νέα Δημοκρατία, Nea Demokratia]
#
#                                        party_name_ches  \
# 18                 [United Kingdom Independence Party]
# 150         [Partido Popular, Alianza-Partido Popular]
# 84   [Strana Smer–Tretia Cesta, Smer–sociálna demok...
# 57                               [Sverigedemokraterna]
# 130                                   [Néa Dimokratía]
#
#                                     party_name_en_ches  year_ches  country  \
# 18                 [United Kingdom Independence Party]       2014     11.0
# 150          [People’s Party, People’s Alliance Party]       2014      5.0
# 84   [Direction–Third Way, Direction–Social Democracy]       2014     28.0
# 57                                  [Sweden Democrats]       2014     16.0
# 130                                    [New Democracy]       2014      4.0
#
#      eastwest  eumember party_id party_ches   cmp_id  vote       seat  \
# 18        1.0       1.0     1108       UKIP  51951.0   3.1   0.000000
# 150       1.0       1.0      502         PP  33610.0  41.9  53.099998
# 84        0.0       1.0     2803    Smer-SD  96423.0  44.4  55.299999
# 57        1.0       1.0     1610         SD  11710.0  12.9  14.000000
# 130       1.0       1.0      402         ND  34511.0  29.7  43.000000
#
#      electionyear  epvote  family  govt     lrgen    lrecon  lrecon_salience  \
# 18         2010.0    27.5     1.0   0.0  9.142858  8.571428         5.142857
# 150        2011.0    26.1     2.0   1.0  7.300000  7.666667         8.777778
# 84         2012.0    24.1     5.0   1.0  3.692308  2.571429         8.642858
# 57         2014.0     9.7     1.0   0.0  7.761905  5.400000         3.476191
# 130        2012.0    22.7     2.0   1.0  7.222222  7.111111         9.444445
#
#      lrecon_dissent  lrecon_blur    galtan  galtan_salience  galtan_dissent  \
# 18              NaN          NaN  9.285714         8.142858             NaN
# 150             NaN          NaN  8.000000         7.222222             NaN
# 84              NaN          NaN  6.928571         4.846154             NaN
# 57              NaN          NaN  9.238095         8.380953             NaN
# 130             NaN          NaN  7.000000         6.333334             NaN
#
#      galtan_blur  eu_position  eu_salience  eu_dissent  eu_blur  spendvtax  \
# 18           NaN     1.142857     9.142858    0.714286      NaN   8.833333
# 150          NaN     6.800000     6.900000    0.600000      NaN   7.600000
# 84           NaN     6.142857     6.571429    1.454546      NaN   2.714286
# 57           NaN     1.272727     6.136363    0.950000      NaN   4.705883
# 130          NaN     6.555555     7.444445    2.555556      NaN   5.500000
#
#      spendvtax_salience  deregulation  dereg_salience  redistribution  \
# 18                  NaN      8.333333             NaN        7.500000
# 150                 NaN      7.900000             NaN        7.600000
# 84                  NaN      2.214286             NaN        2.642857
# 57                  NaN      4.529412             NaN        4.588235
# 130                 NaN      6.333333             NaN        6.555555
#
#      redist_salience  econ_interven  civlib_laworder  civlib_salience  \
# 18               NaN       8.500000         8.857142              NaN
# 150              NaN       7.300000         8.300000              NaN
# 84               NaN       1.714286         6.923077              NaN
# 57               NaN       4.470588         9.277778              NaN
# 130              NaN       6.000000         7.111111              NaN
#
#      sociallifestyle  social_salience  womens_rights  lgbtq_rights  \
# 18          8.500000              NaN            NaN           NaN
# 150         7.000000              NaN            NaN           NaN
# 84          6.692307              NaN            NaN           NaN
# 57          8.157895              NaN            NaN           NaN
# 130         8.111111              NaN            NaN           NaN
#
#      samesex_marriage  religious_principles  relig_salience  immigrate_policy  \
# 18                NaN              6.800000             NaN         10.000000
# 150               NaN              7.800000             NaN          8.100000
# 84                NaN              4.857143             NaN          6.461538
# 57                NaN              5.625000             NaN          9.777778
# 130               NaN              8.444445             NaN          8.000000
#
#      immigrate_salience  immigrate_dissent  multiculturalism  \
# 18                  NaN                NaN          9.800000
# 150                 NaN                NaN          8.250000
# 84                  NaN                NaN          6.416666
# 57                  NaN                NaN          9.842105
# 130                 NaN                NaN          8.222222
#
#      multicult_salience  multicult_dissent  nationalism  nationalism_salience  \
# 18                  NaN                NaN     9.833333                   NaN
# 150                 NaN                NaN     7.200000                   NaN
# 84                  NaN                NaN     6.785714                   NaN
# 57                  NaN                NaN     9.777778                   NaN
# 130                 NaN                NaN     7.444445                   NaN
#
#      ethnic_minorities  ethnic_salience  urban_rural  urban_salience  \
# 18            8.428572              NaN     5.666667             NaN
# 150           7.444445              NaN     5.500000             NaN
# 84            7.307693              NaN     5.857143             NaN
# 57            9.812500              NaN     7.312500             NaN
# 130           8.222222              NaN     6.000000             NaN
#
#      environment  enviro_salience  climate_change  climate_change_salience  \
# 18      9.000000              NaN             NaN                      NaN
# 150     7.375000              NaN             NaN                      NaN
# 84      7.153846              NaN             NaN                      NaN
# 57      7.500000              NaN             NaN                      NaN
# 130     7.666666              NaN             NaN                      NaN
#
#      protectionism   regions  region_salience  international_security  \
# 18             NaN  5.750000              NaN                5.000000
# 150            NaN  7.500000              NaN                2.444444
# 84             NaN  7.000000              NaN                5.000000
# 57             NaN  5.250000              NaN                6.352941
# 130            NaN  5.714286              NaN                4.428571
#
#      international_salience  us  us_salience  eu_benefit     eu_ep  eu_fiscal  \
# 18                      NaN NaN          NaN         3.0  1.166667        NaN
# 150                     NaN NaN          NaN         1.0  5.666667        NaN
# 84                      NaN NaN          NaN         1.0  5.900000        NaN
# 57                      NaN NaN          NaN         3.0  1.833333        NaN
# 130                     NaN NaN          NaN         1.0  6.428571        NaN
#
#      eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  eu_environ  \
# 18     2.571429        NaN    1.142857      NaN     1.285714         NaN
# 150    6.700000        NaN    5.555555      NaN     6.750000         NaN
# 84     5.846154        NaN    5.071429      NaN     6.833333         NaN
# 57     1.277778        NaN    1.062500      NaN     1.785714         NaN
# 130    6.555555        NaN    5.555555      NaN     6.777778         NaN
#
#      eu_asylum  eu_foreign  eu_turkey  eu_russia  russian_interference  \
# 18         NaN    1.285714   1.000000        NaN                   NaN
# 150        NaN    6.750000   4.555555        NaN                   NaN
# 84         NaN    5.153846   4.600000        NaN                   NaN
# 57         NaN    1.235294   1.333333        NaN                   NaN
# 130        NaN    6.111111   3.714286        NaN                   NaN
#
#      anti_islam_rhetoric  people_vs_elite  antielite_salience  \
# 18                   NaN              NaN            9.285714
# 150                  NaN              NaN            1.400000
# 84                   NaN              NaN            3.714286
# 57                   NaN              NaN            8.894737
# 130                  NaN              NaN            2.333333
#
#      corrupt_salience  members_vs_leadership  executive_power  \
# 18           6.800000                    NaN              NaN
# 150          3.400000                    NaN              NaN
# 84           3.785714                    NaN              NaN
# 57           2.944444                    NaN              NaN
# 130          4.555555                    NaN              NaN
#
#      judicial_independence  mip_one  mip_two  mip_three  chesversion  \
# 18                     NaN      9.0      8.0        1.0       2025.1
# 150                    NaN     13.0      5.0       12.0       2025.1
# 84                     NaN     14.0     17.0       13.0       2025.1
# 57                     NaN      9.0     12.0       11.0       2025.1
# 130                    NaN     13.0      8.0       14.0       2025.1
#
#      fallback_used
# 18           False
# 150          False
# 84           False
# 57           False
# 130          False

# %%
# compute match rate (how many left rows found a right row)
match_rate_fallback = migration_with_CHES_fallback["chesversion"].notna().mean() * 100
print(f"Match rate: {match_rate_fallback:.1f}%")
print(migration_with_CHES_fallback["eumember"].notna().mean() * 100)
# Out:
# Match rate: 89.4%
# 89.3560020607934

# %%
# compute fallback rate itself (how many rows only matched thanks to fallback)
fallback_rate = migration_with_CHES_fallback["fallback_used"].mean() * 100
print(fallback_rate)
# Out:
# 92.37776752767527

# %%
# quick sanity checks
# sanity check if fallback did work correctly (left year should always be greater / equal than right year
n_bad = (migration_with_CHES_fallback["year_mig"] < migration_with_CHES_fallback["year_ches"]).sum()
print(n_bad) # should be 0


merged_smell_copy = migration_with_CHES_fallback.copy(deep=True)
# Row count should match left_df
assert len(merged_smell_copy) == len(left), "Unexpected row count change"

# How many left rows found no match?
no_match_rate = merged_smell_copy["year_ches"].isna().mean()
no_match_count = merged_smell_copy["year_ches"].isna().sum()

print(no_match_rate)
print(no_match_count)

# check if each ches year is less/equal to speech date
date_year = pd.to_datetime(merged_smell_copy["date"], errors="coerce").dt.year
year_val  = pd.to_numeric(merged_smell_copy["year_ches"], errors="coerce")

merged_smell_copy["date_after_year"] = ((date_year >= year_val).where(date_year.notna() & year_val.notna(), pd.NA))
all_ok = merged_smell_copy["date_after_year"].dropna().all()
print(all_ok) # should be true
# Out:
# 0
# 0.10643997939206594
# 1033
# True

# %% [markdown]
# Well this is much better now. Briefly check the output and store for later.

# %%
display(migration_with_CHES_fallback.head(5))
# Out:
#      Unnamed: 0                        speaker  \
# 18       292003                   Amjad Bashir
# 150      292004            Miguel Arias Cañete
# 84       292025                Monika Smolková
# 57       291861               Kristina Winberg
# 130      291519  Ελισσάβετ Βόζεμπεργκ-Βρυωνίδη
#
#                                                   text        date  \
# 18   Mr Arias, we have heard about the injustice do...  2014-07-02
# 150  Sí, efectivamente, para luchar contra la inmig...  2014-07-02
# 84   – Taliansko predstavilo veľmi ambiciózny plán ...  2014-07-02
# 57   Fru talman! Schengenavtalet ingicks i en anda ...  2014-07-14
# 130  Αξιότιμε κύριε Juncker, στις προτεραιότητές σα...  2014-07-15
#
#                                                 agenda  speechnumber  \
# 18   12. Programme of activities of the Italian Pre...            41
# 150  12. Programme of activities of the Italian Pre...            42
# 84   12. Programme of activities of the Italian Pre...            63
# 57   13. One-minute speeches on matters of politica...            24
# 130  5. Statement by the candidate for President of...            25
#
#     procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 18                       6404.0       8  False  True       False    False
# 150                      6398.0       8  False  True       False    False
# 84                       6399.0       8  False  True       False     True
# 57                       6404.0       8  False  True       False    False
# 130                      6398.0       8  False  True       False     True
#
#      multispeaker                                               link  \
# 18          False  https://www.europarl.europa.eu/doceo/document/...
# 150         False  https://www.europarl.europa.eu/doceo/document/...
# 84          False  https://www.europarl.europa.eu/doceo/document/...
# 57          False  https://www.europarl.europa.eu/doceo/document/...
# 130         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                         translatedText translationSource  \
# 18   Mr Arias, we have heard about the injustice do...       original_pl
# 150  Yes, indeed, to fight against immigration we m...        machine_pl
# 84   - Italy presented a very ambitious plan for it...        machine_pl
# 57   Fru talman! The Schengen Agreement was conclud...        machine_pl
# 130  Dear Mr Juncker, in your priorities you refer ...        machine_pl
#
#      year_mig                   block       party_mig  migration_prob  \
# 18       2014         (extreme)_right  EDD/INDDEM/EFD        0.257913
# 150      2014  christian_conservative             PPE        0.494101
# 84       2014       social_democratic         PSE/S&D        0.323411
# 57       2014         (extreme)_right  EDD/INDDEM/EFD        0.700463
# 130      2014  christian_conservative             PPE        0.604105
#
#     person_id_ep party_id_ep party_id_ches       party_label_ep  \
# 18        124956        4051          1108                 UKIP
# 150         1351        4024           502                   PP
# 84         96655        4159          2803              SMER-SD
# 57        124995        4253          1610  Sverigedemokraterna
# 130       125065        4055           402                 N.D.
#
#        party_all_labels_ep                   party_all_names_ep  \
# 18                  [UKIP]  [United Kingdom Independence Party]
# 150                   [PP]                    [Partido Popular]
# 84               [SMER-SD]           [SMER-Sociálna demokracia]
# 57   [Sverigedemokraterna]                [Sverigedemokraterna]
# 130           [Ν.Δ., N.D.]     [Νέα Δημοκρατία, Nea Demokratia]
#
#                                        party_name_ches  \
# 18                 [United Kingdom Independence Party]
# 150         [Partido Popular, Alianza-Partido Popular]
# 84   [Strana Smer–Tretia Cesta, Smer–sociálna demok...
# 57                               [Sverigedemokraterna]
# 130                                   [Néa Dimokratía]
#
#                                     party_name_en_ches  year_ches  country  \
# 18                 [United Kingdom Independence Party]       2014     11.0
# 150          [People’s Party, People’s Alliance Party]       2014      5.0
# 84   [Direction–Third Way, Direction–Social Democracy]       2014     28.0
# 57                                  [Sweden Democrats]       2014     16.0
# 130                                    [New Democracy]       2014      4.0
#
#      eastwest  eumember party_id party_ches   cmp_id  vote       seat  \
# 18        1.0       1.0     1108       UKIP  51951.0   3.1   0.000000
# 150       1.0       1.0      502         PP  33610.0  41.9  53.099998
# 84        0.0       1.0     2803    Smer-SD  96423.0  44.4  55.299999
# 57        1.0       1.0     1610         SD  11710.0  12.9  14.000000
# 130       1.0       1.0      402         ND  34511.0  29.7  43.000000
#
#      electionyear  epvote  family  govt     lrgen    lrecon  lrecon_salience  \
# 18         2010.0    27.5     1.0   0.0  9.142858  8.571428         5.142857
# 150        2011.0    26.1     2.0   1.0  7.300000  7.666667         8.777778
# 84         2012.0    24.1     5.0   1.0  3.692308  2.571429         8.642858
# 57         2014.0     9.7     1.0   0.0  7.761905  5.400000         3.476191
# 130        2012.0    22.7     2.0   1.0  7.222222  7.111111         9.444445
#
#      lrecon_dissent  lrecon_blur    galtan  galtan_salience  galtan_dissent  \
# 18              NaN          NaN  9.285714         8.142858             NaN
# 150             NaN          NaN  8.000000         7.222222             NaN
# 84              NaN          NaN  6.928571         4.846154             NaN
# 57              NaN          NaN  9.238095         8.380953             NaN
# 130             NaN          NaN  7.000000         6.333334             NaN
#
#      galtan_blur  eu_position  eu_salience  eu_dissent  eu_blur  spendvtax  \
# 18           NaN     1.142857     9.142858    0.714286      NaN   8.833333
# 150          NaN     6.800000     6.900000    0.600000      NaN   7.600000
# 84           NaN     6.142857     6.571429    1.454546      NaN   2.714286
# 57           NaN     1.272727     6.136363    0.950000      NaN   4.705883
# 130          NaN     6.555555     7.444445    2.555556      NaN   5.500000
#
#      spendvtax_salience  deregulation  dereg_salience  redistribution  \
# 18                  NaN      8.333333             NaN        7.500000
# 150                 NaN      7.900000             NaN        7.600000
# 84                  NaN      2.214286             NaN        2.642857
# 57                  NaN      4.529412             NaN        4.588235
# 130                 NaN      6.333333             NaN        6.555555
#
#      redist_salience  econ_interven  civlib_laworder  civlib_salience  \
# 18               NaN       8.500000         8.857142              NaN
# 150              NaN       7.300000         8.300000              NaN
# 84               NaN       1.714286         6.923077              NaN
# 57               NaN       4.470588         9.277778              NaN
# 130              NaN       6.000000         7.111111              NaN
#
#      sociallifestyle  social_salience  womens_rights  lgbtq_rights  \
# 18          8.500000              NaN            NaN           NaN
# 150         7.000000              NaN            NaN           NaN
# 84          6.692307              NaN            NaN           NaN
# 57          8.157895              NaN            NaN           NaN
# 130         8.111111              NaN            NaN           NaN
#
#      samesex_marriage  religious_principles  relig_salience  immigrate_policy  \
# 18                NaN              6.800000             NaN         10.000000
# 150               NaN              7.800000             NaN          8.100000
# 84                NaN              4.857143             NaN          6.461538
# 57                NaN              5.625000             NaN          9.777778
# 130               NaN              8.444445             NaN          8.000000
#
#      immigrate_salience  immigrate_dissent  multiculturalism  \
# 18                  NaN                NaN          9.800000
# 150                 NaN                NaN          8.250000
# 84                  NaN                NaN          6.416666
# 57                  NaN                NaN          9.842105
# 130                 NaN                NaN          8.222222
#
#      multicult_salience  multicult_dissent  nationalism  nationalism_salience  \
# 18                  NaN                NaN     9.833333                   NaN
# 150                 NaN                NaN     7.200000                   NaN
# 84                  NaN                NaN     6.785714                   NaN
# 57                  NaN                NaN     9.777778                   NaN
# 130                 NaN                NaN     7.444445                   NaN
#
#      ethnic_minorities  ethnic_salience  urban_rural  urban_salience  \
# 18            8.428572              NaN     5.666667             NaN
# 150           7.444445              NaN     5.500000             NaN
# 84            7.307693              NaN     5.857143             NaN
# 57            9.812500              NaN     7.312500             NaN
# 130           8.222222              NaN     6.000000             NaN
#
#      environment  enviro_salience  climate_change  climate_change_salience  \
# 18      9.000000              NaN             NaN                      NaN
# 150     7.375000              NaN             NaN                      NaN
# 84      7.153846              NaN             NaN                      NaN
# 57      7.500000              NaN             NaN                      NaN
# 130     7.666666              NaN             NaN                      NaN
#
#      protectionism   regions  region_salience  international_security  \
# 18             NaN  5.750000              NaN                5.000000
# 150            NaN  7.500000              NaN                2.444444
# 84             NaN  7.000000              NaN                5.000000
# 57             NaN  5.250000              NaN                6.352941
# 130            NaN  5.714286              NaN                4.428571
#
#      international_salience  us  us_salience  eu_benefit     eu_ep  eu_fiscal  \
# 18                      NaN NaN          NaN         3.0  1.166667        NaN
# 150                     NaN NaN          NaN         1.0  5.666667        NaN
# 84                      NaN NaN          NaN         1.0  5.900000        NaN
# 57                      NaN NaN          NaN         3.0  1.833333        NaN
# 130                     NaN NaN          NaN         1.0  6.428571        NaN
#
#      eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  eu_environ  \
# 18     2.571429        NaN    1.142857      NaN     1.285714         NaN
# 150    6.700000        NaN    5.555555      NaN     6.750000         NaN
# 84     5.846154        NaN    5.071429      NaN     6.833333         NaN
# 57     1.277778        NaN    1.062500      NaN     1.785714         NaN
# 130    6.555555        NaN    5.555555      NaN     6.777778         NaN
#
#      eu_asylum  eu_foreign  eu_turkey  eu_russia  russian_interference  \
# 18         NaN    1.285714   1.000000        NaN                   NaN
# 150        NaN    6.750000   4.555555        NaN                   NaN
# 84         NaN    5.153846   4.600000        NaN                   NaN
# 57         NaN    1.235294   1.333333        NaN                   NaN
# 130        NaN    6.111111   3.714286        NaN                   NaN
#
#      anti_islam_rhetoric  people_vs_elite  antielite_salience  \
# 18                   NaN              NaN            9.285714
# 150                  NaN              NaN            1.400000
# 84                   NaN              NaN            3.714286
# 57                   NaN              NaN            8.894737
# 130                  NaN              NaN            2.333333
#
#      corrupt_salience  members_vs_leadership  executive_power  \
# 18           6.800000                    NaN              NaN
# 150          3.400000                    NaN              NaN
# 84           3.785714                    NaN              NaN
# 57           2.944444                    NaN              NaN
# 130          4.555555                    NaN              NaN
#
#      judicial_independence  mip_one  mip_two  mip_three  chesversion  \
# 18                     NaN      9.0      8.0        1.0       2025.1
# 150                    NaN     13.0      5.0       12.0       2025.1
# 84                     NaN     14.0     17.0       13.0       2025.1
# 57                     NaN      9.0     12.0       11.0       2025.1
# 130                    NaN     13.0      8.0       14.0       2025.1
#
#      fallback_used
# 18           False
# 150          False
# 84           False
# 57           False
# 130          False

# %%
# convert types into string where reasonable
# work on copy
final_fallback_output = migration_with_CHES_fallback.copy(deep=True)
print(final_fallback_output["year_ches"].isna().sum()) # we have nan values since not all rows matched! -> we cannot have numpy int as dtype
print(final_fallback_output["year_ches"].dtype)
print(final_fallback_output["year_mig"].dtype)
#final_fallback_output["year_ches"] = final_fallback_output["year_ches"].astype("Int64") # convert to pandas int type
# Out:
# 1033
# Int64
# Int64

# %%
final_fallback_output = final_fallback_output.rename(columns={"party_ches": "party_label_ches", "year_mig" : "year", "party_mig" : "party"})
display(final_fallback_output.head(3))
# Out:
#      Unnamed: 0              speaker  \
# 18       292003         Amjad Bashir
# 150      292004  Miguel Arias Cañete
# 84       292025      Monika Smolková
#
#                                                   text        date  \
# 18   Mr Arias, we have heard about the injustice do...  2014-07-02
# 150  Sí, efectivamente, para luchar contra la inmig...  2014-07-02
# 84   – Taliansko predstavilo veľmi ambiciózny plán ...  2014-07-02
#
#                                                 agenda  speechnumber  \
# 18   12. Programme of activities of the Italian Pre...            41
# 150  12. Programme of activities of the Italian Pre...            42
# 84   12. Programme of activities of the Italian Pre...            63
#
#     procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 18                       6404.0       8  False  True       False    False
# 150                      6398.0       8  False  True       False    False
# 84                       6399.0       8  False  True       False     True
#
#      multispeaker                                               link  \
# 18          False  https://www.europarl.europa.eu/doceo/document/...
# 150         False  https://www.europarl.europa.eu/doceo/document/...
# 84          False  https://www.europarl.europa.eu/doceo/document/...
#
#                                         translatedText translationSource  \
# 18   Mr Arias, we have heard about the injustice do...       original_pl
# 150  Yes, indeed, to fight against immigration we m...        machine_pl
# 84   - Italy presented a very ambitious plan for it...        machine_pl
#
#      year                   block           party  migration_prob  \
# 18   2014         (extreme)_right  EDD/INDDEM/EFD        0.257913
# 150  2014  christian_conservative             PPE        0.494101
# 84   2014       social_democratic         PSE/S&D        0.323411
#
#     person_id_ep party_id_ep party_id_ches party_label_ep party_all_labels_ep  \
# 18        124956        4051          1108           UKIP              [UKIP]
# 150         1351        4024           502             PP                [PP]
# 84         96655        4159          2803        SMER-SD           [SMER-SD]
#
#                       party_all_names_ep  \
# 18   [United Kingdom Independence Party]
# 150                    [Partido Popular]
# 84            [SMER-Sociálna demokracia]
#
#                                        party_name_ches  \
# 18                 [United Kingdom Independence Party]
# 150         [Partido Popular, Alianza-Partido Popular]
# 84   [Strana Smer–Tretia Cesta, Smer–sociálna demok...
#
#                                     party_name_en_ches  year_ches  country  \
# 18                 [United Kingdom Independence Party]       2014     11.0
# 150          [People’s Party, People’s Alliance Party]       2014      5.0
# 84   [Direction–Third Way, Direction–Social Democracy]       2014     28.0
#
#      eastwest  eumember party_id party_label_ches   cmp_id  vote       seat  \
# 18        1.0       1.0     1108             UKIP  51951.0   3.1   0.000000
# 150       1.0       1.0      502               PP  33610.0  41.9  53.099998
# 84        0.0       1.0     2803          Smer-SD  96423.0  44.4  55.299999
#
#      electionyear  epvote  family  govt     lrgen    lrecon  lrecon_salience  \
# 18         2010.0    27.5     1.0   0.0  9.142858  8.571428         5.142857
# 150        2011.0    26.1     2.0   1.0  7.300000  7.666667         8.777778
# 84         2012.0    24.1     5.0   1.0  3.692308  2.571429         8.642858
#
#      lrecon_dissent  lrecon_blur    galtan  galtan_salience  galtan_dissent  \
# 18              NaN          NaN  9.285714         8.142858             NaN
# 150             NaN          NaN  8.000000         7.222222             NaN
# 84              NaN          NaN  6.928571         4.846154             NaN
#
#      galtan_blur  eu_position  eu_salience  eu_dissent  eu_blur  spendvtax  \
# 18           NaN     1.142857     9.142858    0.714286      NaN   8.833333
# 150          NaN     6.800000     6.900000    0.600000      NaN   7.600000
# 84           NaN     6.142857     6.571429    1.454546      NaN   2.714286
#
#      spendvtax_salience  deregulation  dereg_salience  redistribution  \
# 18                  NaN      8.333333             NaN        7.500000
# 150                 NaN      7.900000             NaN        7.600000
# 84                  NaN      2.214286             NaN        2.642857
#
#      redist_salience  econ_interven  civlib_laworder  civlib_salience  \
# 18               NaN       8.500000         8.857142              NaN
# 150              NaN       7.300000         8.300000              NaN
# 84               NaN       1.714286         6.923077              NaN
#
#      sociallifestyle  social_salience  womens_rights  lgbtq_rights  \
# 18          8.500000              NaN            NaN           NaN
# 150         7.000000              NaN            NaN           NaN
# 84          6.692307              NaN            NaN           NaN
#
#      samesex_marriage  religious_principles  relig_salience  immigrate_policy  \
# 18                NaN              6.800000             NaN         10.000000
# 150               NaN              7.800000             NaN          8.100000
# 84                NaN              4.857143             NaN          6.461538
#
#      immigrate_salience  immigrate_dissent  multiculturalism  \
# 18                  NaN                NaN          9.800000
# 150                 NaN                NaN          8.250000
# 84                  NaN                NaN          6.416666
#
#      multicult_salience  multicult_dissent  nationalism  nationalism_salience  \
# 18                  NaN                NaN     9.833333                   NaN
# 150                 NaN                NaN     7.200000                   NaN
# 84                  NaN                NaN     6.785714                   NaN
#
#      ethnic_minorities  ethnic_salience  urban_rural  urban_salience  \
# 18            8.428572              NaN     5.666667             NaN
# 150           7.444445              NaN     5.500000             NaN
# 84            7.307693              NaN     5.857143             NaN
#
#      environment  enviro_salience  climate_change  climate_change_salience  \
# 18      9.000000              NaN             NaN                      NaN
# 150     7.375000              NaN             NaN                      NaN
# 84      7.153846              NaN             NaN                      NaN
#
#      protectionism  regions  region_salience  international_security  \
# 18             NaN     5.75              NaN                5.000000
# 150            NaN     7.50              NaN                2.444444
# 84             NaN     7.00              NaN                5.000000
#
#      international_salience  us  us_salience  eu_benefit     eu_ep  eu_fiscal  \
# 18                      NaN NaN          NaN         3.0  1.166667        NaN
# 150                     NaN NaN          NaN         1.0  5.666667        NaN
# 84                      NaN NaN          NaN         1.0  5.900000        NaN
#
#      eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  eu_environ  \
# 18     2.571429        NaN    1.142857      NaN     1.285714         NaN
# 150    6.700000        NaN    5.555555      NaN     6.750000         NaN
# 84     5.846154        NaN    5.071429      NaN     6.833333         NaN
#
#      eu_asylum  eu_foreign  eu_turkey  eu_russia  russian_interference  \
# 18         NaN    1.285714   1.000000        NaN                   NaN
# 150        NaN    6.750000   4.555555        NaN                   NaN
# 84         NaN    5.153846   4.600000        NaN                   NaN
#
#      anti_islam_rhetoric  people_vs_elite  antielite_salience  \
# 18                   NaN              NaN            9.285714
# 150                  NaN              NaN            1.400000
# 84                   NaN              NaN            3.714286
#
#      corrupt_salience  members_vs_leadership  executive_power  \
# 18           6.800000                    NaN              NaN
# 150          3.400000                    NaN              NaN
# 84           3.785714                    NaN              NaN
#
#      judicial_independence  mip_one  mip_two  mip_three  chesversion  \
# 18                     NaN      9.0      8.0        1.0       2025.1
# 150                    NaN     13.0      5.0       12.0       2025.1
# 84                     NaN     14.0     17.0       13.0       2025.1
#
#      fallback_used
# 18           False
# 150          False
# 84           False

# %% [markdown]
# Wonderful, lets store this for our analysis

# %%
# final_fallback_output.to_parquet(PATH_MIGRATION_CHES_FALLBACK, engine='fastparquet')
