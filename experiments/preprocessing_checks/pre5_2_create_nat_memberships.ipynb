# %%
import os
if not os.environ.get("PREAMBLE_RUN", False): 
    # %run -i "../preamble.py" 2

# %%
import pandas as pd
import requests
import os

from src.constants import PATH_INTERMED_CHES_51_MIG_W_META, PATH_INTERMED_CHES_52_NAT_MEMBER

# set display options for the notebook
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# In order to link the national party memberships of the MEPs in our migration dataset with the corresponding ches party entries, we need to extract all the national parties our MEPs were part of during the legislative periods of 2014-2024 and then map those to their corresponding party ID of the CHES dataset (if possible.) Therefore, in this script we extract the memberships and link them to their corresponding CHES parties.

# %%
# first load enriched migration dataset
original_enriched_migration_df = pd.read_parquet(PATH_INTERMED_CHES_51_MIG_W_META, engine='fastparquet')
enriched_migration_df = original_enriched_migration_df.copy(deep=True)
display(enriched_migration_df.head(5))
# Out:
#    Unnamed: 0            speaker  \
# 0         492     Karen Melchior
# 1         844       Tineke Strik
# 2        1050  Anabela Rodrigues
# 3        1054        Beata Kempa
# 4        1056   Dorien Rookmaker
#
#                                                 text        date  \
# 0  Mr President, thank you very much to the Commi...  2024-04-24
# 1  Mr President, Commissioner. People who flee wa...  2024-04-23
# 2  Senhora Presidente, em 2024, o tráfico de sere...  2024-04-22
# 3  Pani Przewodnicząca! Pani Komisarz! Potrzebuje...  2024-04-22
# 4  Voorzitter, dank u wel, meneer Engerer, want u...  2024-04-22
#
#                                               agenda  speechnumber  \
# 0  22. Advance passenger information: enhancing a...             8
# 1  17. EU-Egypt strategic and comprehensive partn...             9
# 2  20. Amending Directive 2011/36/EU on preventin...            10
# 3  20. Amending Directive 2011/36/EU on preventin...            14
# 4  20. Amending Directive 2011/36/EU on preventin...            16
#
#                                         procedure_ID  partyfacts_ID  period  \
# 0   bill_26075_ID bill_26076_ID  bill_26075_ID bi...         6401.0       9
# 1                                                            6403.0       9
# 2                           bill_241_ID  bill_241_ID         6402.0       9
# 3                           bill_241_ID  bill_241_ID         6400.0       9
# 4                           bill_241_ID  bill_241_ID         6400.0       9
#
#    chair   MEP  commission  written  multispeaker  \
# 0  False  True       False    False         False
# 1  False  True       False    False         False
# 2  False  True       False    False         False
# 3  False  True       False    False         False
# 4  False  True       False    False         False
#
#                                                 link  \
# 0  https://www.europarl.europa.eu/doceo/document/...
# 1  https://www.europarl.europa.eu/doceo/document/...
# 2  https://www.europarl.europa.eu/doceo/document/...
# 3  https://www.europarl.europa.eu/doceo/document/...
# 4  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr President, thank you very much to the Commi...       original_gm  2024
# 1  Mr President, Commissioner. People who flee wa...       original_gm  2024
# 2  Madam President, in 2024, human trafficking co...        machine_gm  2024
# 3  Madam Commissioner! We need very specific, ver...        machine_gm  2024
# 4  Madam President, thank you, Mr Engerer, becaus...        machine_gm  2024
#
#              block            party  migration_prob ep_identifier  \
# 0          liberal  ELDR/ALDE/Renew        0.393282        197567
# 1            green       Greens/EFA        0.423501        197772
# 2             left     NGL/The Left        0.375925        254718
# 3  (extreme)_right              ECR        0.256493        197519
# 4  (extreme)_right              ECR        0.475315        204733
#
#             ep_label ep_citizenship ep_placeOfBirth     ep_bday ep_deathDate  \
# 0     Karen MELCHIOR            DNK        Gentofte  1980-10-15         None
# 1       Tineke STRIK            NLD       Appeltern  1961-09-28         None
# 2  Anabela RODRIGUES            PRT          Lisboa  1976-10-18         None
# 3        Beata KEMPA            POL           Syców  1966-02-11         None
# 4   Dorien ROOKMAKER            NLD           Zijpe  1964-07-30         None
#
#   ep_gender                                   ep_hasMembership
# 0    FEMALE  [{"id":"membership/197567-f-161757","type":"Me...
# 1    FEMALE  [{"id":"membership/197772-f-161044","type":"Me...
# 2    FEMALE  [{"id":"membership/254718-f-169354","type":"Me...
# 3    FEMALE  [{"id":"membership/197519-f-164917","type":"Me...
# 4    FEMALE  [{"id":"membership/204733-f-169018","type":"Me...

# %%
# Now use the MEP's identifier to fetch the relevant metadata
metadata = []
identifiers = list(set(enriched_migration_df['ep_identifier']))
print("Amount of (unique) identifiers in enriched_migration_df:", len(identifiers))
batch_size = 128
idx = 0
while idx < len(identifiers):
    print(f"idx: {idx}")
    batch = identifiers[idx: idx + batch_size]
    response = requests.get(f"https://data.europarl.europa.eu/api/v2/meps/{','.join(batch)}",
                                params={"format": "application/ld+json"})
    
    if response.status_code == 200:
        metadata.extend(response.json()['data'])
    else:
        print(f"An error occurred: {response.status_code}")

    idx += batch_size
print("Finished without error.")
# create dataframe
original_mep_metadata = pd.DataFrame(metadata)
# Out:
# Amount of (unique) identifiers in enriched_migration_df: 889
# idx: 0
# idx: 128
# idx: 256
# idx: 384
# idx: 512
# idx: 640
# idx: 768
# Finished without error.

# %%
mep_metadata = original_mep_metadata.copy(deep=True)
# only keep relevant columns
mep_metadata = mep_metadata[["identifier", "label", "hasMembership"]]
display(mep_metadata.head(3))
# Out:
#   identifier                    label  \
# 0     103246            Auke ZIJLSTRA
# 1     103488  Sergio GUTIÉRREZ PRIETO
# 2     103746           Michal ŠIMEČKA
#
#                                        hasMembership
# 0  [{'id': 'membership/103246-m-14834', 'type': '...
# 1  [{'id': 'membership/103488-f-148559', 'type': ...
# 2  [{'id': 'membership/103746-f-166291', 'type': ...

# %% [markdown]
# Now let's take extract membership and party affiliations (i.e. the "hasMembership" column) of the fetched metadata

# %%
def extract_national_political_group(memberships):
    national_parties = [{"id": membership.get('organization', '')[len("org/"):],
                         "startDate": membership['memberDuring'].get('startDate'),
                         "endDate": membership['memberDuring'].get('endDate'),
                         "role": membership.get('role'),
                         "class": membership.get('membershipClassification', '')[len("def/ep-entities/"):]
                         } for membership in memberships if
                         membership.get('membershipClassification', "") == 'def/ep-entities/NATIONAL_POLITICAL_GROUP']
    return national_parties

# include this for sanity checks
def extract_eu_political_group(memberships):
    european_parties = [{"id": membership.get('organization', '')[len("org/"):],
                         "startDate": membership['memberDuring'].get('startDate'),
                         "endDate": membership['memberDuring'].get('endDate'),
                         "role": membership.get('role'),
                         "class": membership.get('membershipClassification', '')[len("def/ep-entities/"):]
                         } for membership in memberships if
                         membership.get('membershipClassification', "") == 'def/ep-entities/EU_POLITICAL_GROUP']
    return european_parties

# %%
mep_metadata['national_parties'] = mep_metadata['hasMembership'].apply(extract_national_political_group)
# do the same for eu parties (for sanity checks later on)
#mep_metadata['eu_parties'] = mep_metadata['hasMembership'].apply(extract_eu_political_group)
display(mep_metadata.head(3))
# Out:
#   identifier                    label  \
# 0     103246            Auke ZIJLSTRA
# 1     103488  Sergio GUTIÉRREZ PRIETO
# 2     103746           Michal ŠIMEČKA
#
#                                        hasMembership  \
# 0  [{'id': 'membership/103246-m-14834', 'type': '...
# 1  [{'id': 'membership/103488-f-148559', 'type': ...
# 2  [{'id': 'membership/103746-f-166291', 'type': ...
#
#                                     national_parties
# 0  [{'id': '4117', 'startDate': '2015-09-01', 'en...
# 1  [{'id': '4025', 'startDate': '2014-07-01', 'en...
# 2  [{'id': '5587', 'startDate': '2019-07-02', 'en...

# %% [markdown]
# Now fetch the relevant metadata from the EP API on all the national parties, which are occuring in our dataset, as well

# %%
# get all occurring party id's
national_party_ids = set(mep_metadata['national_parties'].explode().apply(lambda org: org['id']))

# fetch the data on national parties
national_parties = []
national_party_ids = list(national_party_ids)
print(f"We have {len(national_party_ids)} occurring national parties.")
batch_size = 128
idx = 0
while idx < len(national_party_ids):
    print(f"idx: {idx}")
    batch = national_party_ids[idx: idx + batch_size]
    response = requests.get(f"https://data.europarl.europa.eu/api/v2/corporate-bodies/{','.join(batch)}",
                                params={"format": "application/ld+json"})

    if response.status_code == 200:
        national_parties.extend(response.json()['data'])
    else:
        print(f"An error occurred: {response.status_code}")

    idx += batch_size
print("Finished without error.")
print(f"Loaded data on {len(national_parties)} national parties.")
# Out:
# We have 878 occurring national parties.
# idx: 0
# idx: 128
# idx: 256
# idx: 384
# idx: 512
# idx: 640
# idx: 768
# Finished without error.
# Loaded data on 878 national parties.

# %%
original_national_parties_df = pd.DataFrame(national_parties)
national_parties_df = original_national_parties_df.copy(deep=True)
national_parties_df.head(3)
# Out:
#          id          type                                         represents  \
# 0  org/1353  Organization  [http://publications.europa.eu/resource/author...
# 1  org/1367  Organization  [http://publications.europa.eu/resource/author...
# 2  org/1384  Organization  [http://publications.europa.eu/resource/author...
#
#   identifier         source  \
# 0       1353  EU_PARLIAMENT
# 1       1367  EU_PARLIAMENT
# 2       1384  EU_PARLIAMENT
#
#                                             temporal label  \
# 0  {'id': 'time-period/20040720-20090713', 'type'...    TS
# 1  {'id': 'time-period/20040720-20090325', 'type'...    IL
# 2  {'id': 'time-period/20040720-20090713', 'type'...     A
#
#                                             altLabel  \
# 0  {'et': 'TS', 'nl': 'TS', 'ro': 'TS', 'da': 'TS...
# 1  {'ga': 'IL', 'sl': 'IL', 'sk': 'IL', 'cs': 'IL...
# 2  {'hu': 'A', 'fr': 'A', 'it': 'A', 'lv': 'A', '...
#
#   notation_providerTemporalBodyId notation_codictBodyId  \
# 0                            1353                  1353
# 1                            1367                  1367
# 2                            1384                  1384
#
#                                            prefLabel  \
# 0  {'el': 'Tėvynės sąjunga', 'mt': 'Tėvynės sąjun...
# 1  {'pt': 'Erakond Isamaaliit (Pro Patria Union)'...
# 2  {'nl': 'Socialdemokratiet', 'lt': 'Socialdemok...
#
#                              classification isVersionOf
# 0  def/ep-entities/NATIONAL_POLITICAL_GROUP         NaN
# 1  def/ep-entities/NATIONAL_POLITICAL_GROUP         NaN
# 2  def/ep-entities/NATIONAL_POLITICAL_GROUP         NaN

# %%
# Now do the same for the european parties (keep for sanity checks later)
## get all occurring party id's
#european_party_ids = set(enriched_migration_df['eu_parties'].explode().apply(lambda org: org['id']))
#
## fetch the data on european parties
#european_parties = []
#european_party_ids = list(european_party_ids)
#print(f"We have {len(european_party_ids)} occurring european parties.")
#batch_size = 128
#idx = 0
#while idx < len(european_party_ids):
#    print(f"idx: {idx}")
#    batch = european_party_ids[idx: idx + batch_size]
#    response = requests.get(f"https://data.europarl.europa.eu/api/v2/corporate-bodies/{','.join(batch)}",
#                                params={"format": "application/ld+json"})
#
#    if response.status_code == 200:
#        european_parties.extend(response.json()['data'])
#    else:
#        print(f"An error occurred: {response.status_code}")
#
#    idx += batch_size
#print("Finished without error.")
#print(f"Loaded data on {len(european_parties)} european parties.")

# %%
#original_european_parties_df = pd.DataFrame(european_parties)
#european_parties_df = original_european_parties_df.copy(deep=True)
#european_parties_df.head(3)

# %% [markdown]
# Clean up the dataframe on national parties a bit

# %%
# replace URI with actual value for column "represents"
national_parties_df['represents'] = national_parties_df['represents'].apply(lambda rep: rep[0][len('http://publications.europa.eu/resource/authority/country/'):] if isinstance(rep, list) else rep)

national_parties_df['classification'] = national_parties_df['classification'].str.removeprefix("def/ep-entities/")

# only keep relevant columns
national_parties_df = national_parties_df[["represents", "identifier", "temporal", "label", "altLabel", "prefLabel", "classification"]]
# rename the columns to avoid ambiguity later on
national_parties_df = national_parties_df.rename(columns={
    "represents" : "party_represents",
    "identifier" : "party_id",
    "temporal" : "party_temporal",
    "label" : "party_label",
    "altLabel" : "party_altLabel",
    "prefLabel" : "party_prefLabel",
    "classification" : "party_classification",
})

# For the national parties, extract all possible labels and party names as lists each
national_parties_df["party_all_labels"] = national_parties_df["party_altLabel"].apply(lambda d: (list(d.values())))
# add the label from column "party_label" to the list (and eliminate duplicates)
national_parties_df["party_all_labels"] = national_parties_df.apply(
    lambda row: list(set(row["party_all_labels"] + [row["party_label"]])),
    axis=1
)
# also extract all possible (and unique) party names
national_parties_df["party_all_names"] = national_parties_df["party_prefLabel"].apply(lambda d: (list(set(d.values()))))

display(national_parties_df.head())
# Out:
#   party_represents party_id  \
# 0              LTU     1353
# 1              EST     1367
# 2              DNK     1384
# 3              SVN     1399
# 4              POL     1410
#
#                                       party_temporal party_label  \
# 0  {'id': 'time-period/20040720-20090713', 'type'...          TS
# 1  {'id': 'time-period/20040720-20090325', 'type'...          IL
# 2  {'id': 'time-period/20040720-20090713', 'type'...           A
# 3  {'id': 'time-period/20040720-20090713', 'type'...         NSi
# 4  {'id': 'time-period/20040720-20090713', 'type'...          SO
#
#                                       party_altLabel  \
# 0  {'et': 'TS', 'nl': 'TS', 'ro': 'TS', 'da': 'TS...
# 1  {'ga': 'IL', 'sl': 'IL', 'sk': 'IL', 'cs': 'IL...
# 2  {'hu': 'A', 'fr': 'A', 'it': 'A', 'lv': 'A', '...
# 3  {'da': 'NSi', 'nl': 'NSi', 'ro': 'NSi', 'pl': ...
# 4  {'nl': 'SO', 'ro': 'SO', 'da': 'SO', 'sk': 'SO...
#
#                                      party_prefLabel  \
# 0  {'el': 'Tėvynės sąjunga', 'mt': 'Tėvynės sąjun...
# 1  {'pt': 'Erakond Isamaaliit (Pro Patria Union)'...
# 2  {'nl': 'Socialdemokratiet', 'lt': 'Socialdemok...
# 3  {'cs': 'Nova Slovenija', 'sk': 'Nova Slovenija...
# 4  {'pt': 'Samoobrona RP', 'bg': 'Samoobrona RP',...
#
#        party_classification party_all_labels  \
# 0  NATIONAL_POLITICAL_GROUP             [TS]
# 1  NATIONAL_POLITICAL_GROUP             [IL]
# 2  NATIONAL_POLITICAL_GROUP              [A]
# 3  NATIONAL_POLITICAL_GROUP            [NSi]
# 4  NATIONAL_POLITICAL_GROUP             [SO]
#
#                            party_all_names
# 0                        [Tėvynės sąjunga]
# 1  [Erakond Isamaaliit (Pro Patria Union)]
# 2                      [Socialdemokratiet]
# 3                         [Nova Slovenija]
# 4                          [Samoobrona RP]

# %% [markdown]
# Now lets merge the meta data of the parties (national and european) with the meta data of the Members of Parliament and create a "Membership" Dataframe

# %%
nat_memberships_df = mep_metadata.explode('national_parties').reset_index()
display(nat_memberships_df.sort_values(by=['identifier']).head(10))
# Out:
#       index identifier              label  \
# 1966    768     101580  Constance LE GRIP
# 1964    768     101580  Constance LE GRIP
# 1965    768     101580  Constance LE GRIP
# 1661    640     102886  Ildikó GÁLL-PELCZ
# 1660    640     102886  Ildikó GÁLL-PELCZ
# 0         0     103246      Auke ZIJLSTRA
# 2         0     103246      Auke ZIJLSTRA
# 1         0     103246      Auke ZIJLSTRA
# 1353    512     103381      Terry REINTKE
# 1354    512     103381      Terry REINTKE
#
#                                           hasMembership  \
# 1966  [{'id': 'membership/101580-f-137779', 'type': ...
# 1964  [{'id': 'membership/101580-f-137779', 'type': ...
# 1965  [{'id': 'membership/101580-f-137779', 'type': ...
# 1661  [{'id': 'membership/102886-f-149915', 'type': ...
# 1660  [{'id': 'membership/102886-f-149915', 'type': ...
# 0     [{'id': 'membership/103246-m-14834', 'type': '...
# 2     [{'id': 'membership/103246-m-14834', 'type': '...
# 1     [{'id': 'membership/103246-m-14834', 'type': '...
# 1353  [{'id': 'membership/103381-f-156375', 'type': ...
# 1354  [{'id': 'membership/103381-f-156375', 'type': ...
#
#                                        national_parties
# 1966  {'id': '2733', 'startDate': '2010-02-10', 'end...
# 1964  {'id': '4907', 'startDate': '2015-05-30', 'end...
# 1965  {'id': '4041', 'startDate': '2014-07-01', 'end...
# 1661  {'id': '2753', 'startDate': '2010-06-02', 'end...
# 1660  {'id': '4068', 'startDate': '2014-07-01', 'end...
# 0     {'id': '4117', 'startDate': '2015-09-01', 'end...
# 2     {'id': '2941', 'startDate': '2011-09-13', 'end...
# 1     {'id': '6696', 'startDate': '2024-07-16', 'end...
# 1353  {'id': '6773', 'startDate': '2024-07-16', 'end...
# 1354  {'id': '4010', 'startDate': '2014-07-01', 'end...

# %%
# extract the key-value pairs of the dictionaries in "national_parties" column as new columns
nat_memberships_unpacked_df = nat_memberships_df.join(pd.json_normalize(nat_memberships_df["national_parties"])).drop(columns="national_parties").reset_index()
# rename the columns for clarification
nat_memberships_unpacked_df = nat_memberships_unpacked_df.rename(columns={
    "identifier" : "person_id",
    "label" : "person_label",
    "id" : "party_id",
    "startDate" : "member_startDate",
    "endDate" : "member_endDate",
    "role" : "member_role",
    "class" : "party_class"
})

# clean up role column
nat_memberships_unpacked_df['member_role'] = nat_memberships_unpacked_df['member_role'].str.removeprefix("def/ep-roles/")

display(nat_memberships_unpacked_df.head())
# Out:
#    level_0  index person_id             person_label  \
# 0        0      0    103246            Auke ZIJLSTRA
# 1        1      0    103246            Auke ZIJLSTRA
# 2        2      0    103246            Auke ZIJLSTRA
# 3        3      1    103488  Sergio GUTIÉRREZ PRIETO
# 4        4      1    103488  Sergio GUTIÉRREZ PRIETO
#
#                                        hasMembership party_id  \
# 0  [{'id': 'membership/103246-m-14834', 'type': '...     4117
# 1  [{'id': 'membership/103246-m-14834', 'type': '...     6696
# 2  [{'id': 'membership/103246-m-14834', 'type': '...     2941
# 3  [{'id': 'membership/103488-f-148559', 'type': ...     4025
# 4  [{'id': 'membership/103488-f-148559', 'type': ...     2714
#
#   member_startDate member_endDate member_role               party_class
# 0       2015-09-01     2019-07-01      MEMBER  NATIONAL_POLITICAL_GROUP
# 1       2024-07-16           None      MEMBER  NATIONAL_POLITICAL_GROUP
# 2       2011-09-13     2014-06-30      MEMBER  NATIONAL_POLITICAL_GROUP
# 3       2014-07-01     2019-05-20      MEMBER  NATIONAL_POLITICAL_GROUP
# 4       2010-07-19     2014-06-30      MEMBER  NATIONAL_POLITICAL_GROUP

# %% [markdown]
# Apply some sanity checks

# %%
# quick sanity check (all memberships should be unique (i.e. the combination of MEP's id, party's id, start and endDate)
duplicates = nat_memberships_unpacked_df.duplicated(subset=["person_id", "party_id", "member_startDate", "member_endDate"], keep=False)
print("Any duplicates in membership (combinations):", duplicates.any()) # should return False for combinations (person_id, party_id, member_startDate, member_endDate)
#display(nat_memberships_unpacked_df.loc[duplicates].head(15))
# Out:
# Any duplicates in membership (combinations): False

# %%
# quick sanity smell test if the time periods of membership do add up per member
def check_desc_start_order_after_desc_end(df):
    d = df.copy()
    d["startDate"] = pd.to_datetime(d["member_startDate"], format="%Y-%m-%d", errors="raise")
    d["endDate"]   = pd.to_datetime(d["member_endDate"],   format="%Y-%m-%d", errors="raise")

    # sort by person then endDate descending
    d = d.sort_values(["person_id", "endDate"], ascending=[True, True], kind="mergesort")

    # for each person, check whether startDate is descending in this order
    # startDate descending means startDate >= next_startDate for all adjacent rows
    d["next_start"] = d.groupby("person_id")["startDate"].shift(-1)
    bad = d["next_start"].notna() & (d["startDate"] > d["next_start"])  # violates descending

    # persons that fail the heuristic
    bad_persons = d.loc[bad, "person_id"].unique()

    return bad_persons, d[d["person_id"].isin(bad_persons)].drop(columns=["next_start"])

# usage:
bad_persons, details = check_desc_start_order_after_desc_end(nat_memberships_unpacked_df)
print(bad_persons) # should return []
display(details.head())
# Out:
# []
# Empty DataFrame
# Columns: [level_0, index, person_id, person_label, hasMembership, party_id, member_startDate, member_endDate, member_role, party_class, startDate, endDate]
# Index: []

# %% [markdown]
# Wonderful, now let's merge with the metadata of the national parties

# %%
enriched_memberships = nat_memberships_unpacked_df.merge(
    national_parties_df,
    left_on="party_id",
    right_on="party_id",
    how="left",   # keep all memberships, even if some parties lack metadata
    validate="many_to_one"  # checks for duplicates of "identifier" in national_parties_df
)

# parties table should usually have unique party_id
assert national_parties_df["party_id"].is_unique

# see if any memberships failed to find metadata
missing_meta = enriched_memberships["party_label"].isna().sum()
print("Memberships without party metadata:", missing_meta) # should return 0

display(enriched_memberships.head(20))
# Out:
# Memberships without party metadata: 0
#     level_0  index person_id             person_label  \
# 0         0      0    103246            Auke ZIJLSTRA
# 1         1      0    103246            Auke ZIJLSTRA
# 2         2      0    103246            Auke ZIJLSTRA
# 3         3      1    103488  Sergio GUTIÉRREZ PRIETO
# 4         4      1    103488  Sergio GUTIÉRREZ PRIETO
# 5         5      2    103746           Michal ŠIMEČKA
# 6         6      3    106202               Julia REID
# 7         7      3    106202               Julia REID
# 8         8      3    106202               Julia REID
# 9         9      4    110977        Florian PHILIPPOT
# 10       10      4    110977        Florian PHILIPPOT
# 11       11      5    111014       Josef WEIDENHOLZER
# 12       12      5    111014       Josef WEIDENHOLZER
# 13       13      6    112788     Birgit COLLIN-LANGEN
# 14       14      6    112788     Birgit COLLIN-LANGEN
# 15       15      7    114279          Isabelle THOMAS
# 16       16      7    114279          Isabelle THOMAS
# 17       17      7    114279          Isabelle THOMAS
# 18       18      8      1179     Michèle ALLIOT-MARIE
# 19       19      8      1179     Michèle ALLIOT-MARIE
#
#                                         hasMembership party_id  \
# 0   [{'id': 'membership/103246-m-14834', 'type': '...     4117
# 1   [{'id': 'membership/103246-m-14834', 'type': '...     6696
# 2   [{'id': 'membership/103246-m-14834', 'type': '...     2941
# 3   [{'id': 'membership/103488-f-148559', 'type': ...     4025
# 4   [{'id': 'membership/103488-f-148559', 'type': ...     2714
# 5   [{'id': 'membership/103746-f-166291', 'type': ...     5587
# 6   [{'id': 'membership/106202-f-148838', 'type': ...     4951
# 7   [{'id': 'membership/106202-f-148838', 'type': ...     5073
# 8   [{'id': 'membership/106202-f-148838', 'type': ...     4051
# 9   [{'id': 'membership/110977-f-148001', 'type': ...     5027
# 10  [{'id': 'membership/110977-f-148001', 'type': ...     4042
# 11  [{'id': 'membership/111014-f-135825', 'type': ...     2659
# 12  [{'id': 'membership/111014-f-135825', 'type': ...     3976
# 13  [{'id': 'membership/112788-f-138302', 'type': ...     2652
# 14  [{'id': 'membership/112788-f-138302', 'type': ...     4008
# 15  [{'id': 'membership/114279-f-149815', 'type': ...     5032
# 16  [{'id': 'membership/114279-f-149815', 'type': ...     4040
# 17  [{'id': 'membership/114279-f-149815', 'type': ...     2731
# 18  [{'id': 'membership/1179-f-140686', 'type': 'M...     4041
# 19  [{'id': 'membership/1179-f-140686', 'type': 'M...     4907
#
#    member_startDate member_endDate member_role               party_class  \
# 0        2015-09-01     2019-07-01      MEMBER  NATIONAL_POLITICAL_GROUP
# 1        2024-07-16           None      MEMBER  NATIONAL_POLITICAL_GROUP
# 2        2011-09-13     2014-06-30      MEMBER  NATIONAL_POLITICAL_GROUP
# 3        2014-07-01     2019-05-20      MEMBER  NATIONAL_POLITICAL_GROUP
# 4        2010-07-19     2014-06-30      MEMBER  NATIONAL_POLITICAL_GROUP
# 5        2019-07-02     2023-10-24      MEMBER  NATIONAL_POLITICAL_GROUP
# 6        2018-12-08     2019-02-11      MEMBER  NATIONAL_POLITICAL_GROUP
# 7        2019-02-12     2019-07-01      MEMBER  NATIONAL_POLITICAL_GROUP
# 8        2014-07-01     2018-12-07      MEMBER  NATIONAL_POLITICAL_GROUP
# 9        2017-10-04     2019-07-01      MEMBER  NATIONAL_POLITICAL_GROUP
# 10       2014-07-01     2017-10-03      MEMBER  NATIONAL_POLITICAL_GROUP
# 11       2011-12-01     2014-06-30      MEMBER  NATIONAL_POLITICAL_GROUP
# 12       2014-07-01     2019-07-01      MEMBER  NATIONAL_POLITICAL_GROUP
# 13       2012-03-17     2014-06-30      MEMBER  NATIONAL_POLITICAL_GROUP
# 14       2014-07-01     2019-07-01      MEMBER  NATIONAL_POLITICAL_GROUP
# 15       2017-12-05     2019-07-01      MEMBER  NATIONAL_POLITICAL_GROUP
# 16       2014-07-01     2017-12-04      MEMBER  NATIONAL_POLITICAL_GROUP
# 17       2012-05-16     2014-06-30      MEMBER  NATIONAL_POLITICAL_GROUP
# 18       2014-07-01     2015-05-29      MEMBER  NATIONAL_POLITICAL_GROUP
# 19       2015-05-30     2019-07-01      MEMBER  NATIONAL_POLITICAL_GROUP
#
#    party_represents                                     party_temporal  \
# 0               NLD  {'id': 'time-period/20140701-20190701', 'type'...
# 1               NLD  {'id': 'time-period/20240716', 'type': 'Period...
# 2               NLD  {'id': 'time-period/20090714-20140630', 'type'...
# 3               ESP  {'id': 'time-period/20140701-20190701', 'type'...
# 4               ESP  {'id': 'time-period/20090714-20140630', 'type'...
# 5               SVK  {'id': 'time-period/20190702-20240715', 'type'...
# 6               GBR  {'id': 'time-period/20151001-20190701', 'type'...
# 7               GBR  {'id': 'time-period/20190205-20190701', 'type'...
# 8               GBR  {'id': 'time-period/20140701-20190701', 'type'...
# 9               FRA  {'id': 'time-period/20171004-20190701', 'type'...
# 10              FRA  {'id': 'time-period/20140701-20190701', 'type'...
# 11              AUT  {'id': 'time-period/20090714-20140630', 'type'...
# 12              AUT  {'id': 'time-period/20140701-20190701', 'type'...
# 13              DEU  {'id': 'time-period/20090714-20140630', 'type'...
# 14              DEU  {'id': 'time-period/20140701-20190701', 'type'...
# 15              FRA  {'id': 'time-period/20171205-20190701', 'type'...
# 16              FRA  {'id': 'time-period/20140701-20190701', 'type'...
# 17              FRA  {'id': 'time-period/20090714-20140630', 'type'...
# 18              FRA  {'id': 'time-period/20140701-20150529', 'type'...
# 19              FRA  {'id': 'time-period/20150530-20190701', 'type'...
#
#          party_label                                     party_altLabel  \
# 0                PVV  {'ga': 'PVV', 'lt': 'PVV', 'nl': 'PVV', 'ro': ...
# 1                PVV  {'sv': 'PVV', 'pt': 'PVV', 'bg': 'PVV', 'el': ...
# 2                PVV  {'lt': 'PVV', 'nl': 'PVV', 'ro': 'PVV', 'da': ...
# 3               PSOE  {'lv': 'PSOE', 'it': 'PSOE', 'fr': 'PSOE', 'hu...
# 4               PSOE  {'bg': 'PSOE', 'pt': 'PSOE', 'sv': 'PSOE', 'fi...
# 5                 PS  {'nl': 'Progresívne Slovensko', 'ro': 'Progres...
# 6        Independent  {'it': 'Independent', 'fr': 'Independent', 'hu...
# 7               BREX  {'nl': 'The Brexit Party', 'ro': 'The Brexit P...
# 8               UKIP  {'pl': 'UKIP', 'ga': 'UKIP', 'sl': 'UKIP', 'sk...
# 9      Les Patriotes  {'mt': 'Patri', 'lt': 'Patri', 'en': 'Patri', ...
# 10                FN  {'ro': 'FN', 'nl': 'FN', 'da': 'FN', 'pl': 'FN...
# 11               SPÖ  {'mt': 'SPÖ', 'nl': 'SPÖ', 'ro': 'SPÖ', 'pl': ...
# 12               SPÖ  {'hu': 'SPÖ', 'fr': 'SPÖ', 'it': 'SPÖ', 'lv': ...
# 13               CDU  {'cs': 'CDU', 'it': 'CDU', 'nl': 'CDU', 'ro': ...
# 14               CDU  {'nl': 'CDU', 'it': 'CDU', 'ro': 'CDU', 'da': ...
# 15           Genmouv  {'bg': 'Genmouv', 'el': 'Genmouv', 'mt': 'Genm...
# 16                PS  {'de': 'PS', 'fi': 'PS', 'sv': 'PS', 'pt': 'PS...
# 17                PS  {'cs': 'PS', 'en': 'PS', 'et': 'PS', 'nl': 'PS...
# 18               UMP  {'sl': 'UMP', 'sk': 'UMP', 'cs': 'UMP', 'et': ...
# 19  Les Républicains  {'et': 'Les Républicains', 'sk': 'Les Républic...
#
#                                       party_prefLabel  \
# 0   {'de': 'Partij voor de Vrijheid', 'lt': 'Parti...
# 1   {'nl': 'Partij voor de Vrijheid', 'ro': 'Parti...
# 2   {'nl': 'Partij voor de Vrijheid', 'ro': 'Parti...
# 3   {'hr': 'Partido Socialista Obrero Español', 'e...
# 4   {'lt': 'Partido Socialista Obrero Español', 'd...
# 5   {'sl': 'Progresívne Slovensko', 'ga': 'Progres...
# 6   {'ro': 'Independent', 'da': 'Independent', 'pl...
# 7   {'es': 'The Brexit Party', 'et': 'The Brexit P...
# 8   {'es': 'United Kingdom Independence Party', 'b...
# 9   {'nl': 'Les Patriotes', 'ro': 'Les Patriotes',...
# 10  {'de': 'Front national', 'fi': 'Front national...
# 11  {'de': 'Sozialdemokratische Partei Österreichs...
# 12  {'en': 'Sozialdemokratische Partei Österreichs...
# 13  {'en': 'Christlich Demokratische Union Deutsch...
# 14  {'en': 'Christlich Demokratische Union Deutsch...
# 15  {'hr': 'Génération.s, le mouvement', 'lt': 'Gé...
# 16  {'sl': 'Parti socialiste', 'sk': 'Parti social...
# 17  {'bg': 'Parti socialiste', 'el': 'Parti social...
# 18  {'de': 'Union pour un Mouvement Populaire', 'f...
# 19  {'sv': 'Les Républicains', 'fi': 'Les Républic...
#
#         party_classification             party_all_labels  \
# 0   NATIONAL_POLITICAL_GROUP                        [PVV]
# 1   NATIONAL_POLITICAL_GROUP                        [PVV]
# 2   NATIONAL_POLITICAL_GROUP                        [PVV]
# 3   NATIONAL_POLITICAL_GROUP                       [PSOE]
# 4   NATIONAL_POLITICAL_GROUP                       [PSOE]
# 5   NATIONAL_POLITICAL_GROUP  [Progresívne Slovensko, PS]
# 6   NATIONAL_POLITICAL_GROUP                [Independent]
# 7   NATIONAL_POLITICAL_GROUP     [The Brexit Party, BREX]
# 8   NATIONAL_POLITICAL_GROUP                       [UKIP]
# 9   NATIONAL_POLITICAL_GROUP       [Patri, Les Patriotes]
# 10  NATIONAL_POLITICAL_GROUP                         [FN]
# 11  NATIONAL_POLITICAL_GROUP                        [SPÖ]
# 12  NATIONAL_POLITICAL_GROUP                        [SPÖ]
# 13  NATIONAL_POLITICAL_GROUP                        [CDU]
# 14  NATIONAL_POLITICAL_GROUP                        [CDU]
# 15  NATIONAL_POLITICAL_GROUP                    [Genmouv]
# 16  NATIONAL_POLITICAL_GROUP                         [PS]
# 17  NATIONAL_POLITICAL_GROUP                         [PS]
# 18  NATIONAL_POLITICAL_GROUP                        [UMP]
# 19  NATIONAL_POLITICAL_GROUP           [Les Républicains]
#
#                                   party_all_names
# 0                       [Partij voor de Vrijheid]
# 1                       [Partij voor de Vrijheid]
# 2                       [Partij voor de Vrijheid]
# 3             [Partido Socialista Obrero Español]
# 4             [Partido Socialista Obrero Español]
# 5                         [Progresívne Slovensko]
# 6                                   [Independent]
# 7                              [The Brexit Party]
# 8             [United Kingdom Independence Party]
# 9                                 [Les Patriotes]
# 10                               [Front national]
# 11       [Sozialdemokratische Partei Österreichs]
# 12       [Sozialdemokratische Partei Österreichs]
# 13  [Christlich Demokratische Union Deutschlands]
# 14  [Christlich Demokratische Union Deutschlands]
# 15                   [Génération.s, le mouvement]
# 16                             [Parti socialiste]
# 17                             [Parti socialiste]
# 18            [Union pour un Mouvement Populaire]
# 19                             [Les Républicains]

# %% [markdown]
# NOTE: It seems that there is no 1-to-1 mapping between a party's label and a party's id, i.e. a party can have multiple ids (this is also reflected in the original national parties dataframe and due to the differences in the temporal description / column "party_temporal"), but for each separate period store in "party_temporal" we should still have a unique combination of party label and party id nonetheless.

# %%
# briefly investigate this on a copy
checker_copy = enriched_memberships.copy(deep=True)
def canonicalize_dict(d):
    if d is None:
        return None
    # tuple of (key, value) sorted by key
    return tuple(sorted(d.items()))

checker_copy["_party_temporal_key"] = checker_copy["party_temporal"].apply(canonicalize_dict)

s = checker_copy.groupby("party_id")["_party_temporal_key"].nunique(dropna=False)
bad_party_ids = s[s != 1]

if bad_party_ids.empty:
    print("Each party_id maps to exactly one party_temporal dict")
else:
    print("Inconsistent party_temporal for these party_id values:")
    print(bad_party_ids)

    conflicts = (
        checker_copy[checker_copy["party_id"].isin(bad_party_ids.index)]
        .loc[:, ["party_id", "party_temporal"]]
        .drop_duplicates()
    )
    display(conflicts)
# Out:
# Each party_id maps to exactly one party_temporal dict

# %% [markdown]
# Wonderful, now let's clean this up a bit and store it for later merging with CHES meta data

# %%
# remove unneeded columns
enriched_memberships = enriched_memberships.drop(columns=["level_0", "index", "party_classification", "party_altLabel", "party_prefLabel"])
display(enriched_memberships.head(5))
# Out:
#   person_id             person_label  \
# 0    103246            Auke ZIJLSTRA
# 1    103246            Auke ZIJLSTRA
# 2    103246            Auke ZIJLSTRA
# 3    103488  Sergio GUTIÉRREZ PRIETO
# 4    103488  Sergio GUTIÉRREZ PRIETO
#
#                                        hasMembership party_id  \
# 0  [{'id': 'membership/103246-m-14834', 'type': '...     4117
# 1  [{'id': 'membership/103246-m-14834', 'type': '...     6696
# 2  [{'id': 'membership/103246-m-14834', 'type': '...     2941
# 3  [{'id': 'membership/103488-f-148559', 'type': ...     4025
# 4  [{'id': 'membership/103488-f-148559', 'type': ...     2714
#
#   member_startDate member_endDate member_role               party_class  \
# 0       2015-09-01     2019-07-01      MEMBER  NATIONAL_POLITICAL_GROUP
# 1       2024-07-16           None      MEMBER  NATIONAL_POLITICAL_GROUP
# 2       2011-09-13     2014-06-30      MEMBER  NATIONAL_POLITICAL_GROUP
# 3       2014-07-01     2019-05-20      MEMBER  NATIONAL_POLITICAL_GROUP
# 4       2010-07-19     2014-06-30      MEMBER  NATIONAL_POLITICAL_GROUP
#
#   party_represents                                     party_temporal  \
# 0              NLD  {'id': 'time-period/20140701-20190701', 'type'...
# 1              NLD  {'id': 'time-period/20240716', 'type': 'Period...
# 2              NLD  {'id': 'time-period/20090714-20140630', 'type'...
# 3              ESP  {'id': 'time-period/20140701-20190701', 'type'...
# 4              ESP  {'id': 'time-period/20090714-20140630', 'type'...
#
#   party_label party_all_labels                      party_all_names
# 0         PVV            [PVV]            [Partij voor de Vrijheid]
# 1         PVV            [PVV]            [Partij voor de Vrijheid]
# 2         PVV            [PVV]            [Partij voor de Vrijheid]
# 3        PSOE           [PSOE]  [Partido Socialista Obrero Español]
# 4        PSOE           [PSOE]  [Partido Socialista Obrero Español]

# %%
# store as parquet file
# enriched_memberships.to_parquet(PATH_INTERMED_CHES_52_NAT_MEMBER, engine='fastparquet')
