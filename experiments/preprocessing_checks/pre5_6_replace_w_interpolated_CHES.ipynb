# %%
import os
if not os.environ.get("PREAMBLE_RUN", False): 
    # %run -i "../preamble.py" 2

# %%
import pandas as pd
import requests
import numpy as np

from src.constants import PATH_INTERMED_CHES_54_MIG_W_CHES_META, PATH_ORIGINAL_CHES_RAW_CSV, PATH_MIGRATION_SPEECHES, PATH_MIGRATION_CHES_INTERPOLATED

# set display options for the notebook
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# Replace CHES meta with 'raw'/actual CHES scores and linearly interpolate scores for speeches not given in 2014/'19/'24:
#
# Let's try to linearly interpolate the CHES scores for speech dates with missing (exact) year match. This was also done in the literature, e.g. by [Adams et al., 2014](https://onlinelibrary.wiley.com/doi/epdf/10.1111/ajps.12115?saml_referrer)

# %% [markdown]
# Load the dataset we want to merge first

# %%
# load the data
# 1) the migration dataset (pls) enriched with meta information about the speaker (i.e. national party affiliation and the corresponding [CHES] party id)
enriched_migration_df = pd.read_parquet(PATH_INTERMED_CHES_54_MIG_W_CHES_META, engine='fastparquet')
# (2) the raw CHES dataset to enrich the migration set with (i.e. replace the CHES meta information with the actual scorings / survey items)
raw_CHES_df = pd.read_parquet(PATH_ORIGINAL_CHES_RAW_CSV, engine='fastparquet')
# 3) the vanilla/plain migration (pls) dataset to get part of the desired output columns (i.e. drop the rest of cols)
plain_migration_df = pd.read_parquet(PATH_MIGRATION_SPEECHES, engine='fastparquet')

# %%
print("enriched migration data:")
print(enriched_migration_df.shape[0])
display(enriched_migration_df.head(3))
print("raw CHES data:")
print(raw_CHES_df.shape[0])
display(raw_CHES_df.head(3))
print("vanilla/plain migration data:")
print(plain_migration_df.shape[0])
display(plain_migration_df.head(3))
# Out:
# enriched migration data:
# 9705
#    Unnamed: 0              speaker  \
# 0      292003         Amjad Bashir
# 1      292004  Miguel Arias Cañete
# 2      292025      Monika Smolková
#
#                                                 text       date  \
# 0  Mr Arias, we have heard about the injustice do... 2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig... 2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ... 2014-07-02
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl  2014
# 1  Yes, indeed, to fight against immigration we m...        machine_pl  2014
# 2  - Italy presented a very ambitious plan for it...        machine_pl  2014
#
#                     block           party  migration_prob ep_identifier  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913        124956
# 1  christian_conservative             PPE        0.494101          1351
# 2       social_democratic         PSE/S&D        0.323411         96655
#
#               ep_label ep_citizenship ep_placeOfBirth     ep_bday  \
# 0         Amjad BASHIR            GBR     Jhelum (PK)  1952-09-17
# 1  Miguel ARIAS CAÑETE            ESP          Madrid  1950-02-24
# 2      Monika SMOLKOVÁ            SVK         Janovík  1956-10-06
#
#   ep_deathDate ep_gender                                   ep_hasMembership  \
# 0         None      MALE  [{'id': 'membership/124956-f-143535', 'type': ...
# 1         None      MALE  [{'id': 'membership/1351-f-105362', 'type': 'M...
# 2         None    FEMALE  [{'id': 'membership/96655-m-15750', 'type': 'M...
#
#   person_id_memb    person_label_memb  \
# 0         124956         Amjad BASHIR
# 1           1351  Miguel ARIAS CAÑETE
# 2          96655      Monika SMOLKOVÁ
#
#                                   hasMembership_memb party_id_memb  \
# 0  [{'id': 'membership/124956-f-143535', 'type': ...          4051
# 1  [{'id': 'membership/1351-f-105362', 'type': 'M...          4024
# 2  [{'id': 'membership/96655-m-15750', 'type': 'M...          4159
#
#   member_startDate_memb member_endDate_memb member_role_memb  \
# 0            2014-07-01          2015-01-28           MEMBER
# 1            2014-07-01          2014-10-31           MEMBER
# 2            2014-07-01          2019-07-01           MEMBER
#
#            party_class_memb country_code_memb  \
# 0  NATIONAL_POLITICAL_GROUP               GBR
# 1  NATIONAL_POLITICAL_GROUP               ESP
# 2  NATIONAL_POLITICAL_GROUP               SVK
#
#                                  party_temporal_memb party_label_memb  \
# 0  {'id': 'time-period/20140701-20190701', 'type'...             UKIP
# 1  {'id': 'time-period/20140701-20190701', 'type'...               PP
# 2  {'id': 'time-period/20140701-20190701', 'type'...          SMER-SD
#
#   party_all_labels_memb                 party_all_names_memb party_id_ches  \
# 0                [UKIP]  [United Kingdom Independence Party]          1108
# 1                  [PP]                    [Partido Popular]           502
# 2             [SMER-SD]           [SMER-Sociálna demokracia]          2803
#
#   country_code_ches party_abbrev_ches  \
# 0               GBR            [UKIP]
# 1               ESP              [PP]
# 2               SVK   [Smer, Smer-SD]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
#
#                                   party_name_en_ches
# 0                [United Kingdom Independence Party]
# 1          [People’s Party, People’s Alliance Party]
# 2  [Direction–Third Way, Direction–Social Democracy]
# raw CHES data:
# 1441
#    year  country  eastwest  eumember  party_id party   cmp_id  vote  \
# 0  1999        1         1         1       102    PS  21322.0  10.2
# 1  2002        1         1         1       102    PS  21322.0  10.2
# 2  2006        1         1         1       102    PS  21322.0  13.0
#
#         seat  electionyear  epvote  family  govt     lrgen  lrecon  \
# 0  12.700000          1999    9.59       5   1.0  3.111111   2.625
# 1  12.700000          1999    9.59       5   1.0  3.350000   2.500
# 2  16.700001          2003   13.50       5   1.0  3.500000   3.170
#
#    lrecon_salience  lrecon_dissent  lrecon_blur  galtan  galtan_salience  \
# 0              NaN             NaN          NaN   3.875              NaN
# 1              NaN             NaN          NaN   4.000              NaN
# 2              NaN             NaN          NaN   2.830              NaN
#
#    galtan_dissent  galtan_blur  eu_position  eu_salience  eu_dissent  eu_blur  \
# 0             NaN          NaN     6.666667     4.722222    1.388889      NaN
# 1             NaN          NaN     6.090000     4.533333    2.111111      NaN
# 2             NaN          NaN     5.710000     4.300000    3.430000      NaN
#
#    spendvtax  spendvtax_salience  deregulation  dereg_salience  \
# 0        NaN                 NaN           NaN             NaN
# 1        NaN                 NaN           NaN             NaN
# 2       2.67                 6.5          2.33            6.83
#
#    redistribution  redist_salience  econ_interven  civlib_laworder  \
# 0             NaN              NaN            NaN              NaN
# 1             NaN              NaN            NaN              NaN
# 2             2.0              8.0            NaN             3.67
#
#    civlib_salience  sociallifestyle  social_salience  womens_rights  \
# 0              NaN              NaN              NaN            NaN
# 1              NaN              NaN              NaN            NaN
# 2              6.5             2.33             5.67            NaN
#
#    lgbtq_rights  samesex_marriage  religious_principles  relig_salience  \
# 0           NaN               NaN                   NaN             NaN
# 1           NaN               NaN                   NaN             NaN
# 2           NaN               NaN                  1.33            5.67
#
#    immigrate_policy  immigrate_salience  immigrate_dissent  multiculturalism  \
# 0               NaN                 NaN                NaN               NaN
# 1               NaN                 NaN                NaN               NaN
# 2               2.5                6.33                NaN               4.2
#
#    multicult_salience  multicult_dissent  nationalism  nationalism_salience  \
# 0                 NaN                NaN          NaN                   NaN
# 1                 NaN                NaN          NaN                   NaN
# 2                 NaN                NaN         3.17                  4.33
#
#    ethnic_minorities  ethnic_salience  urban_rural  urban_salience  \
# 0                NaN              NaN          NaN             NaN
# 1                NaN              NaN          NaN             NaN
# 2               3.17             6.33          4.4             3.0
#
#    environment  enviro_salience  climate_change  climate_change_salience  \
# 0          NaN              NaN             NaN                      NaN
# 1          NaN              NaN             NaN                      NaN
# 2          NaN              NaN             NaN                      NaN
#
#    protectionism  regions  region_salience  international_security  \
# 0            NaN      NaN              NaN                     NaN
# 1            NaN      NaN              NaN                     NaN
# 2            NaN     6.17              7.0                     NaN
#
#    international_salience    us  us_salience  eu_benefit     eu_ep  eu_fiscal  \
# 0                     NaN   NaN          NaN         NaN  6.333333   6.666667
# 1                     NaN   NaN          NaN         NaN  6.000000        NaN
# 2                     NaN  2.67          3.5         NaN  6.500000        NaN
#
#    eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  eu_environ  \
# 0         NaN   6.555555         NaN      NaN        6.625    5.888889
# 1         4.1   6.550000         NaN     4.88        5.850    5.000000
# 2         4.0        NaN         NaN      NaN        6.670         NaN
#
#    eu_asylum  eu_foreign  eu_turkey  eu_russia  russian_interference  \
# 0   5.666667    6.555555        NaN        NaN                   NaN
# 1   6.300000    6.330000        NaN        NaN                   NaN
# 2        NaN    5.830000        6.0        NaN                   NaN
#
#    anti_islam_rhetoric  people_vs_elite  antielite_salience  corrupt_salience  \
# 0                  NaN              NaN                 NaN               NaN
# 1                  NaN              NaN                 NaN               NaN
# 2                  NaN              NaN                 NaN               NaN
#
#    members_vs_leadership  executive_power  judicial_independence  mip_one  \
# 0                    NaN              NaN                    NaN      NaN
# 1                    NaN              NaN                    NaN      NaN
# 2                    NaN              NaN                    NaN      NaN
#
#    mip_two  mip_three  chesversion
# 0      NaN        NaN       2025.1
# 1      NaN        NaN       2025.1
# 2      NaN        NaN       2025.1
# vanilla/plain migration data:
# 9705
#                Unnamed: 0            speaker  \
# 2054628059040         492     Karen Melchior
# 2054601056272         844       Tineke Strik
# 0                    1050  Anabela Rodrigues
#
#                                                             text        date  \
# 2054628059040  Mr President, thank you very much to the Commi...  2024-04-24
# 2054601056272  Mr President, Commissioner. People who flee wa...  2024-04-23
# 0              Senhora Presidente, em 2024, o tráfico de sere...  2024-04-22
#
#                                                           agenda  \
# 2054628059040  22. Advance passenger information: enhancing a...
# 2054601056272  17. EU-Egypt strategic and comprehensive partn...
# 0              20. Amending Directive 2011/36/EU on preventin...
#
#                speechnumber  \
# 2054628059040             8
# 2054601056272             9
# 0                        10
#
#                                                     procedure_ID  \
# 2054628059040   bill_26075_ID bill_26076_ID  bill_26075_ID bi...
# 2054601056272
# 0                                       bill_241_ID  bill_241_ID
#
#                partyfacts_ID  period  chair   MEP  commission  written  \
# 2054628059040         6401.0       9  False  True       False    False
# 2054601056272         6403.0       9  False  True       False    False
# 0                     6402.0       9  False  True       False    False
#
#                multispeaker  \
# 2054628059040         False
# 2054601056272         False
# 0                     False
#
#                                                             link  \
# 2054628059040  https://www.europarl.europa.eu/doceo/document/...
# 2054601056272  https://www.europarl.europa.eu/doceo/document/...
# 0              https://www.europarl.europa.eu/doceo/document/...
#
#                                                   translatedText  \
# 2054628059040  Mr President, thank you very much to the Commi...
# 2054601056272  Mr President, Commissioner. People who flee wa...
# 0              Madam President, in 2024, human trafficking co...
#
#               translationSource  year    block            party  \
# 2054628059040       original_gm  2024  liberal  ELDR/ALDE/Renew
# 2054601056272       original_gm  2024    green       Greens/EFA
# 0                    machine_gm  2024     left     NGL/The Left
#
#                migration_prob
# 2054628059040        0.393282
# 2054601056272        0.423501
# 0                    0.375925

# %% [markdown]
# Now prepare the datasets for merging

# %%
# work on copies
minim_enriched_migration_df = enriched_migration_df.copy(deep=True)
harmonized_CHES_df = raw_CHES_df.copy(deep=True)

# %%
# only keep the relevant columns we also have in the original migration dataset (+ the ones we need for the final merge)
output_cols_migration = plain_migration_df.columns.tolist()
output_cols_merger = ["ep_identifier", "party_id_memb", "party_id_ches", "party_label_memb", "party_all_labels_memb", "party_all_names_memb", "party_name_ches", "party_name_en_ches"]
output_cols_minim_all = output_cols_migration + output_cols_merger
# unify column names throughput the merge process
minim_enriched_migration_df = minim_enriched_migration_df[output_cols_minim_all].rename(columns={"ep_identifier" : "person_id_ep", "party_id_memb" : "party_id_ep", "party_label_memb" : "party_label_ep", "party_all_labels_memb" : "party_all_labels_ep", "party_all_names_memb" : "party_all_names_ep"})
display(minim_enriched_migration_df.head(3))
# Out:
#    Unnamed: 0              speaker  \
# 0      292003         Amjad Bashir
# 1      292004  Miguel Arias Cañete
# 2      292025      Monika Smolková
#
#                                                 text       date  \
# 0  Mr Arias, we have heard about the injustice do... 2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig... 2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ... 2014-07-02
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  year  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl  2014
# 1  Yes, indeed, to fight against immigration we m...        machine_pl  2014
# 2  - Italy presented a very ambitious plan for it...        machine_pl  2014
#
#                     block           party  migration_prob person_id_ep  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913       124956
# 1  christian_conservative             PPE        0.494101         1351
# 2       social_democratic         PSE/S&D        0.323411        96655
#
#   party_id_ep party_id_ches party_label_ep party_all_labels_ep  \
# 0        4051          1108           UKIP              [UKIP]
# 1        4024           502             PP                [PP]
# 2        4159          2803        SMER-SD           [SMER-SD]
#
#                     party_all_names_ep  \
# 0  [United Kingdom Independence Party]
# 1                    [Partido Popular]
# 2           [SMER-Sociálna demokracia]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
#
#                                   party_name_en_ches
# 0                [United Kingdom Independence Party]
# 1          [People’s Party, People’s Alliance Party]
# 2  [Direction–Third Way, Direction–Social Democracy]

# %%
# define all the ches columns we have
ches_cols_match = ["year", "country","eastwest", "eumember", "party_id", "party", "cmp_id"]
# apparently we do not have an "expert" column as stated in the CHES codebook :(
ches_cols_meta = ["vote", "seat", "electionyear", "epvote", "family","govt", "chesversion"]
ches_cols_ideo = ["lrgen", "lrecon", "lrecon_salience", "lrecon_dissent", "lrecon_blur", "galtan", "galtan_salience", "galtan_dissent", "galtan_blur"]
# NOTE: Scores in col "eu_position" is from 1-7 instead of 0-10 !!
ches_cols_eu_integ = ["eu_position", "eu_salience", "eu_dissent", "eu_blur"]
ches_cols_policy_dim = ["spendvtax", "spendvtax_salience", "deregulation", "dereg_salience", "redistribution", "redist_salience", "econ_interven", "civlib_laworder", "civlib_salience", "sociallifestyle", "social_salience", "womens_rights", "lgbtq_rights", "samesex_marriage", "religious_principles", "relig_salience", "immigrate_policy", "immigrate_salience", "immigrate_dissent", "multiculturalism", "multicult_salience", "multicult_dissent", "nationalism", "nationalism_salience", "ethnic_minorities", "ethnic_salience", "urban_rural", "urban_salience", "environment", "enviro_salience", "climate_change", "climate_change_salience", "protectionism", "regions", "region_salience", "international_security", "international_salience", "us", "us_salience"]
# NOTE: col "eu_benefit" is only 3-scale score (!) and apart from col "eu_russia", the rest of the columns are from 1-7 instead of 0-10 !!
ches_cols_eu_policy = ["eu_benefit", "eu_ep", "eu_fiscal", "eu_intmark", "eu_employ", "eu_budgets", "eu_agri", "eu_cohesion", "eu_environ", "eu_asylum", "eu_foreign", "eu_turkey", "eu_russia"]
ches_cols_salience = ["russian_interference", "anti_islam_rhetoric"]
ches_cols_party_char = ["people_vs_elite", "antielite_salience", "corrupt_salience", "members_vs_leadership", "executive_power", "judicial_independence"]
# NOTE: mip is categorical/string value
ches_cols_mip = ["mip_one", "mip_two", "mip_three"]
ches_cols_lists = [ches_cols_match, ches_cols_meta, ches_cols_ideo, ches_cols_eu_integ, ches_cols_policy_dim, ches_cols_eu_policy, ches_cols_salience, ches_cols_party_char, ches_cols_mip]
ches_cols_all = [col for col_list in ches_cols_lists for col in col_list]

# quick sanity check
#display(raw_CHES_df[ches_cols_all].head())
#print(raw_CHES_df.shape)
#print(raw_CHES_df[ches_cols_all].shape)

# %%
ordinal_cols = ["eu_benefit"]
# define the columns with scale 1-7 we need to re-calibrate (according to CHES codebook)
cols_in_1_7_range = ["eu_position"] + ches_cols_eu_policy
cols_in_1_7_range.remove("eu_benefit")
cols_in_1_7_range.remove("eu_russia")

# %%
# harmonize the relevant migration and ches dataset/columns (for merging)
harmonized_CHES_df = harmonized_CHES_df
display(harmonized_CHES_df.info())

# convert "year" and "party_id" col dtype to (pandas) string type
harmonized_CHES_df["party_id"] = harmonized_CHES_df["party_id"].astype("string").str.strip()
harmonized_CHES_df["year"] = harmonized_CHES_df["year"].astype("Int64")
display(harmonized_CHES_df.info())

# do same for migration dataset
#display(minim_enriched_migration_df.info())
minim_enriched_migration_df["party_id_ches"] = minim_enriched_migration_df["party_id_ches"].astype("string").str.strip()
minim_enriched_migration_df["year"] = minim_enriched_migration_df["year"].astype("Int64")
minim_enriched_migration_df["date"] = minim_enriched_migration_df["date"].astype("string").str.strip()
display(minim_enriched_migration_df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1441 entries, 0 to 1440
# Data columns (total 90 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     1441 non-null   int64
#  1   country                  1441 non-null   int64
#  2   eastwest                 1441 non-null   int64
#  3   eumember                 1441 non-null   int64
#  4   party_id                 1441 non-null   int64
#  5   party                    1437 non-null   object
#  6   cmp_id                   1134 non-null   float64
#  7   vote                     1377 non-null   float64
#  8   seat                     1372 non-null   float64
#  9   electionyear             1441 non-null   int64
#  10  epvote                   1221 non-null   float64
#  11  family                   1441 non-null   int64
#  12  govt                     1196 non-null   float64
#  13  lrgen                    1441 non-null   float64
#  14  lrecon                   1441 non-null   float64
#  15  lrecon_salience          737 non-null    float64
#  16  lrecon_dissent           490 non-null    float64
#  17  lrecon_blur              489 non-null    float64
#  18  galtan                   1440 non-null   float64
#  19  galtan_salience          737 non-null    float64
#  20  galtan_dissent           477 non-null    float64
#  21  galtan_blur              489 non-null    float64
#  22  eu_position              1441 non-null   float64
#  23  eu_salience              1437 non-null   float64
#  24  eu_dissent               1434 non-null   float64
#  25  eu_blur                  490 non-null    float64
#  26  spendvtax                1124 non-null   float64
#  27  spendvtax_salience       389 non-null    float64
#  28  deregulation             1125 non-null   float64
#  29  dereg_salience           389 non-null    float64
#  30  redistribution           1125 non-null   float64
#  31  redist_salience          879 non-null    float64
#  32  econ_interven            492 non-null    float64
#  33  civlib_laworder          1123 non-null   float64
#  34  civlib_salience          389 non-null    float64
#  35  sociallifestyle          880 non-null    float64
#  36  social_salience          388 non-null    float64
#  37  womens_rights            244 non-null    float64
#  38  lgbtq_rights             244 non-null    float64
#  39  samesex_marriage         245 non-null    float64
#  40  religious_principles     1123 non-null   float64
#  41  relig_salience           388 non-null    float64
#  42  immigrate_policy         1120 non-null   float64
#  43  immigrate_salience       879 non-null    float64
#  44  immigrate_dissent        491 non-null    float64
#  45  multiculturalism         1118 non-null   float64
#  46  multicult_salience       694 non-null    float64
#  47  multicult_dissent        246 non-null    float64
#  48  nationalism              919 non-null    float64
#  49  nationalism_salience     183 non-null    float64
#  50  ethnic_minorities        1124 non-null   float64
#  51  ethnic_salience          387 non-null    float64
#  52  urban_rural              1110 non-null   float64
#  53  urban_salience           384 non-null    float64
#  54  environment              939 non-null    float64
#  55  enviro_salience          695 non-null    float64
#  56  climate_change           244 non-null    float64
#  57  climate_change_salience  244 non-null    float64
#  58  protectionism            485 non-null    float64
#  59  regions                  1118 non-null   float64
#  60  region_salience          381 non-null    float64
#  61  international_security   448 non-null    float64
#  62  international_salience   203 non-null    float64
#  63  us                       186 non-null    float64
#  64  us_salience              186 non-null    float64
#  65  eu_benefit               448 non-null    float64
#  66  eu_ep                    942 non-null    float64
#  67  eu_fiscal                142 non-null    float64
#  68  eu_intmark               1295 non-null   float64
#  69  eu_employ                309 non-null    float64
#  70  eu_budgets               491 non-null    float64
#  71  eu_agri                  171 non-null    float64
#  72  eu_cohesion              1188 non-null   float64
#  73  eu_environ               312 non-null    float64
#  74  eu_asylum                559 non-null    float64
#  75  eu_foreign               1438 non-null   float64
#  76  eu_turkey                626 non-null    float64
#  77  eu_russia                243 non-null    float64
#  78  russian_interference     247 non-null    float64
#  79  anti_islam_rhetoric      487 non-null    float64
#  80  people_vs_elite          492 non-null    float64
#  81  antielite_salience       737 non-null    float64
#  82  corrupt_salience         727 non-null    float64
#  83  members_vs_leadership    246 non-null    float64
#  84  executive_power          244 non-null    float64
#  85  judicial_independence    240 non-null    float64
#  86  mip_one                  231 non-null    float64
#  87  mip_two                  229 non-null    float64
#  88  mip_three                227 non-null    float64
#  89  chesversion              1441 non-null   float64
# dtypes: float64(82), int64(7), object(1)
# memory usage: 1013.3+ KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 1441 entries, 0 to 1440
# Data columns (total 90 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     1441 non-null   Int64
#  1   country                  1441 non-null   int64
#  2   eastwest                 1441 non-null   int64
#  3   eumember                 1441 non-null   int64
#  4   party_id                 1441 non-null   string
#  5   party                    1437 non-null   object
#  6   cmp_id                   1134 non-null   float64
#  7   vote                     1377 non-null   float64
#  8   seat                     1372 non-null   float64
#  9   electionyear             1441 non-null   int64
#  10  epvote                   1221 non-null   float64
#  11  family                   1441 non-null   int64
#  12  govt                     1196 non-null   float64
#  13  lrgen                    1441 non-null   float64
#  14  lrecon                   1441 non-null   float64
#  15  lrecon_salience          737 non-null    float64
#  16  lrecon_dissent           490 non-null    float64
#  17  lrecon_blur              489 non-null    float64
#  18  galtan                   1440 non-null   float64
#  19  galtan_salience          737 non-null    float64
#  20  galtan_dissent           477 non-null    float64
#  21  galtan_blur              489 non-null    float64
#  22  eu_position              1441 non-null   float64
#  23  eu_salience              1437 non-null   float64
#  24  eu_dissent               1434 non-null   float64
#  25  eu_blur                  490 non-null    float64
#  26  spendvtax                1124 non-null   float64
#  27  spendvtax_salience       389 non-null    float64
#  28  deregulation             1125 non-null   float64
#  29  dereg_salience           389 non-null    float64
#  30  redistribution           1125 non-null   float64
#  31  redist_salience          879 non-null    float64
#  32  econ_interven            492 non-null    float64
#  33  civlib_laworder          1123 non-null   float64
#  34  civlib_salience          389 non-null    float64
#  35  sociallifestyle          880 non-null    float64
#  36  social_salience          388 non-null    float64
#  37  womens_rights            244 non-null    float64
#  38  lgbtq_rights             244 non-null    float64
#  39  samesex_marriage         245 non-null    float64
#  40  religious_principles     1123 non-null   float64
#  41  relig_salience           388 non-null    float64
#  42  immigrate_policy         1120 non-null   float64
#  43  immigrate_salience       879 non-null    float64
#  44  immigrate_dissent        491 non-null    float64
#  45  multiculturalism         1118 non-null   float64
#  46  multicult_salience       694 non-null    float64
#  47  multicult_dissent        246 non-null    float64
#  48  nationalism              919 non-null    float64
#  49  nationalism_salience     183 non-null    float64
#  50  ethnic_minorities        1124 non-null   float64
#  51  ethnic_salience          387 non-null    float64
#  52  urban_rural              1110 non-null   float64
#  53  urban_salience           384 non-null    float64
#  54  environment              939 non-null    float64
#  55  enviro_salience          695 non-null    float64
#  56  climate_change           244 non-null    float64
#  57  climate_change_salience  244 non-null    float64
#  58  protectionism            485 non-null    float64
#  59  regions                  1118 non-null   float64
#  60  region_salience          381 non-null    float64
#  61  international_security   448 non-null    float64
#  62  international_salience   203 non-null    float64
#  63  us                       186 non-null    float64
#  64  us_salience              186 non-null    float64
#  65  eu_benefit               448 non-null    float64
#  66  eu_ep                    942 non-null    float64
#  67  eu_fiscal                142 non-null    float64
#  68  eu_intmark               1295 non-null   float64
#  69  eu_employ                309 non-null    float64
#  70  eu_budgets               491 non-null    float64
#  71  eu_agri                  171 non-null    float64
#  72  eu_cohesion              1188 non-null   float64
#  73  eu_environ               312 non-null    float64
#  74  eu_asylum                559 non-null    float64
#  75  eu_foreign               1438 non-null   float64
#  76  eu_turkey                626 non-null    float64
#  77  eu_russia                243 non-null    float64
#  78  russian_interference     247 non-null    float64
#  79  anti_islam_rhetoric      487 non-null    float64
#  80  people_vs_elite          492 non-null    float64
#  81  antielite_salience       737 non-null    float64
#  82  corrupt_salience         727 non-null    float64
#  83  members_vs_leadership    246 non-null    float64
#  84  executive_power          244 non-null    float64
#  85  judicial_independence    240 non-null    float64
#  86  mip_one                  231 non-null    float64
#  87  mip_two                  229 non-null    float64
#  88  mip_three                227 non-null    float64
#  89  chesversion              1441 non-null   float64
# dtypes: Int64(1), float64(82), int64(5), object(1), string(1)
# memory usage: 1014.7+ KB
# None
# <class 'pandas.DataFrame'>
# RangeIndex: 9705 entries, 0 to 9704
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           9705 non-null   int64
#  1   speaker              9705 non-null   object
#  2   text                 9705 non-null   object
#  3   date                 9705 non-null   string
#  4   agenda               9705 non-null   object
#  5   speechnumber         9705 non-null   int64
#  6   procedure_ID         9705 non-null   object
#  7   partyfacts_ID        8529 non-null   float64
#  8   period               9705 non-null   int64
#  9   chair                9705 non-null   bool
#  10  MEP                  9705 non-null   bool
#  11  commission           9705 non-null   bool
#  12  written              9705 non-null   bool
#  13  multispeaker         9705 non-null   bool
#  14  link                 9705 non-null   object
#  15  translatedText       9705 non-null   object
#  16  translationSource    9705 non-null   object
#  17  year                 9705 non-null   Int64
#  18  block                9705 non-null   object
#  19  party                9705 non-null   object
#  20  migration_prob       9705 non-null   float64
#  21  person_id_ep         9705 non-null   object
#  22  party_id_ep          9705 non-null   object
#  23  party_id_ches        8857 non-null   string
#  24  party_label_ep       9705 non-null   object
#  25  party_all_labels_ep  9705 non-null   object
#  26  party_all_names_ep   9705 non-null   object
#  27  party_name_ches      8857 non-null   object
#  28  party_name_en_ches   8857 non-null   object
# dtypes: Int64(1), bool(5), float64(2), int64(3), object(16), string(2)
# memory usage: 1.8+ MB
# None

# %%
# now re-calibrate the column values with range 1-7 to common range 0-10
harmonized_CHES_df[cols_in_1_7_range] = (
    (harmonized_CHES_df[cols_in_1_7_range] - 1) / (7 - 1) * 10
)

# %% [markdown]
# Lets merge such that each speech/row of migration dataset gets the interpolated ches scores of past and future for the corresponding national party of the MEP giving the speech, (i.e. this assumes
# expect party positions to move meaningfully between waves),
# like so
#
# **Linear interpolation** between adjacent waves (no extrapolation):
#
# For ches surveys at year w1 and w2 and speech at year t with w1 < t < w2,
#
# we do:
#
#
# ![alt text](image.png)
#
#
# Pros:
# - avoids discontinuous jumps at wave boundaries
# - uses future information only to estimate the value between two observed measurements
# conceptually matches “positions evolve gradually”
#
# Cons:
# - we must justify smoothness (and party shifts could be abrupt)
# - CHES is expert perception; movement may partly reflect events near the later wave
#
# BUT plain merging does not leave us with enough datapoints and interpolating is something already done in the literature (see above/report)
# - if we do this, keep it as a secondary specification (?) unless our paper is explicitly about continuous party-position trajectories

# %%
# columns in right_df we want to interpolate (we chose all numeric columns but drop ordinal/categorical ones, i.e. remove "eu_benefit")
value_cols_lists = [ches_cols_ideo, ches_cols_eu_integ, ches_cols_policy_dim, ches_cols_eu_policy, ches_cols_salience, ches_cols_party_char]
value_cols = [col for col_list in value_cols_lists for col in col_list]
value_cols.remove("eu_benefit")

# work on copies and create stable row id so we can restore original order
left = minim_enriched_migration_df.copy(deep=True).reset_index(drop=True)
left["_row_id"] = left.index
right = raw_CHES_df.copy(deep=True)

# %%
# remove potential ambiguity in column names before merging
left.drop("year", inplace=True, axis=1)
left.rename(columns={"party" : "party_mig"}, inplace=True)
right.rename(columns={"year" : "year_ches"}, inplace=True)

display(left.head(2))
display(right.head(2))
# Out:
#    Unnamed: 0              speaker  \
# 0      292003         Amjad Bashir
# 1      292004  Miguel Arias Cañete
#
#                                                 text        date  \
# 0  Mr Arias, we have heard about the injustice do...  2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig...  2014-07-02
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl
# 1  Yes, indeed, to fight against immigration we m...        machine_pl
#
#                     block       party_mig  migration_prob person_id_ep  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913       124956
# 1  christian_conservative             PPE        0.494101         1351
#
#   party_id_ep party_id_ches party_label_ep party_all_labels_ep  \
# 0        4051          1108           UKIP              [UKIP]
# 1        4024           502             PP                [PP]
#
#                     party_all_names_ep  \
# 0  [United Kingdom Independence Party]
# 1                    [Partido Popular]
#
#                               party_name_ches  \
# 0         [United Kingdom Independence Party]
# 1  [Partido Popular, Alianza-Partido Popular]
#
#                           party_name_en_ches  _row_id
# 0        [United Kingdom Independence Party]        0
# 1  [People’s Party, People’s Alliance Party]        1
#    year_ches  country  eastwest  eumember  party_id party   cmp_id  vote  \
# 0       1999        1         1         1       102    PS  21322.0  10.2
# 1       2002        1         1         1       102    PS  21322.0  10.2
#
#    seat  electionyear  epvote  family  govt     lrgen  lrecon  \
# 0  12.7          1999    9.59       5   1.0  3.111111   2.625
# 1  12.7          1999    9.59       5   1.0  3.350000   2.500
#
#    lrecon_salience  lrecon_dissent  lrecon_blur  galtan  galtan_salience  \
# 0              NaN             NaN          NaN   3.875              NaN
# 1              NaN             NaN          NaN   4.000              NaN
#
#    galtan_dissent  galtan_blur  eu_position  eu_salience  eu_dissent  eu_blur  \
# 0             NaN          NaN     6.666667     4.722222    1.388889      NaN
# 1             NaN          NaN     6.090000     4.533333    2.111111      NaN
#
#    spendvtax  spendvtax_salience  deregulation  dereg_salience  \
# 0        NaN                 NaN           NaN             NaN
# 1        NaN                 NaN           NaN             NaN
#
#    redistribution  redist_salience  econ_interven  civlib_laworder  \
# 0             NaN              NaN            NaN              NaN
# 1             NaN              NaN            NaN              NaN
#
#    civlib_salience  sociallifestyle  social_salience  womens_rights  \
# 0              NaN              NaN              NaN            NaN
# 1              NaN              NaN              NaN            NaN
#
#    lgbtq_rights  samesex_marriage  religious_principles  relig_salience  \
# 0           NaN               NaN                   NaN             NaN
# 1           NaN               NaN                   NaN             NaN
#
#    immigrate_policy  immigrate_salience  immigrate_dissent  multiculturalism  \
# 0               NaN                 NaN                NaN               NaN
# 1               NaN                 NaN                NaN               NaN
#
#    multicult_salience  multicult_dissent  nationalism  nationalism_salience  \
# 0                 NaN                NaN          NaN                   NaN
# 1                 NaN                NaN          NaN                   NaN
#
#    ethnic_minorities  ethnic_salience  urban_rural  urban_salience  \
# 0                NaN              NaN          NaN             NaN
# 1                NaN              NaN          NaN             NaN
#
#    environment  enviro_salience  climate_change  climate_change_salience  \
# 0          NaN              NaN             NaN                      NaN
# 1          NaN              NaN             NaN                      NaN
#
#    protectionism  regions  region_salience  international_security  \
# 0            NaN      NaN              NaN                     NaN
# 1            NaN      NaN              NaN                     NaN
#
#    international_salience  us  us_salience  eu_benefit     eu_ep  eu_fiscal  \
# 0                     NaN NaN          NaN         NaN  6.333333   6.666667
# 1                     NaN NaN          NaN         NaN  6.000000        NaN
#
#    eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  eu_environ  \
# 0         NaN   6.555555         NaN      NaN        6.625    5.888889
# 1         4.1   6.550000         NaN     4.88        5.850    5.000000
#
#    eu_asylum  eu_foreign  eu_turkey  eu_russia  russian_interference  \
# 0   5.666667    6.555555        NaN        NaN                   NaN
# 1   6.300000    6.330000        NaN        NaN                   NaN
#
#    anti_islam_rhetoric  people_vs_elite  antielite_salience  corrupt_salience  \
# 0                  NaN              NaN                 NaN               NaN
# 1                  NaN              NaN                 NaN               NaN
#
#    members_vs_leadership  executive_power  judicial_independence  mip_one  \
# 0                    NaN              NaN                    NaN      NaN
# 1                    NaN              NaN                    NaN      NaN
#
#    mip_two  mip_three  chesversion
# 0      NaN        NaN       2025.1
# 1      NaN        NaN       2025.1

# %%
# ensure IDs same dtype (pandas string, handles NaN nicely for us)
left["party_id_ches"] = left["party_id_ches"].astype("string").str.strip()
right["party_id"] = right["party_id"].astype("string").str.strip()

# %%
# Year from left date
left["year_mig"] = pd.to_datetime(left["date"], errors="coerce").dt.year.astype("Int64")
# Right year as Int64
right["year_ches"] = pd.to_numeric(right["year_ches"], errors="coerce").astype("Int64")

# %% [markdown]
# Do the merge in a two step way, first make an exact match and with all unmatched left rows left, check if they have "bracketing" right rows (i.e. for left year 2017, there exist two right rows with year_1 < 2017 < year_2) perform merge with a pair of merge_asof calls (prev/next year within party)

# %%
# exact merge first
# exact merge: keep all left rows, add right columns where exact match exists
exact = left.merge(
    right[["party_id", "year_ches"] + value_cols],
    how="left",
    left_on=["party_id_ches", "year_mig"],
    right_on=["party_id", "year_ches"],
    validate="m:1",
)

# flag exact matches
exact["match_type"] = np.where(exact["party_id"].notna(), "exact", pd.NA)
exact["year_prev"] = pd.NA
exact["year_next"] = pd.NA

# %%
# now split
needs_interp = exact["match_type"].isna()
left_unmatched = exact.loc[needs_interp, ["_row_id", "party_id_ches", "year_mig"]].copy(deep=True)

# %%
# now interpolate only for unmatched rows (year-wise)
# i.e. we find, for each unmatched left row (using merge_asof)
# - prev: right year < year
# - next: right year > year

left_s  = left_unmatched.sort_values(["year_mig", "party_id_ches"]).copy(deep=True)
right_s = right.sort_values(["year_ches", "party_id"]).copy(deep=True)

prev = pd.merge_asof(
    left_s,
    right_s[["party_id", "year_ches"] + value_cols],
    left_on="year_mig",
    right_on="year_ches",
    left_by="party_id_ches",
    right_by="party_id",
    direction="backward",
    allow_exact_matches=False,   # strict < (since exact already handled)
)

nxt = pd.merge_asof(
    left_s,
    right_s[["party_id", "year_ches"] + value_cols],
    left_on="year_mig",
    right_on="year_ches",
    left_by="party_id_ches",
    right_by="party_id",
    direction="forward",
    allow_exact_matches=False,   # strict >
)

# %%
# Now compute interpolation (vectorized, no index alignment headaches with pandas since we use numpy arrays)

y  = left_s["year_mig"].to_numpy(dtype="float64")
y1 = prev["year_ches"].to_numpy(dtype="float64")
y2 = nxt["year_ches"].to_numpy(dtype="float64")

interp_ok = ~np.isnan(y1) & ~np.isnan(y2) & (y1 < y) & (y < y2)

interp_out = left_s[["_row_id", "party_id_ches", "year_mig"]].copy()
interp_out["match_type"] = pd.NA
interp_out.loc[interp_ok, "match_type"] = "interpolated"
interp_out["year_prev"] = pd.Series(prev["year_ches"].to_numpy()).where(interp_ok)
interp_out["year_next"] = pd.Series(nxt["year_ches"].to_numpy()).where(interp_ok)

for c in value_cols:
    v1 = prev[c].to_numpy(dtype="float64")
    v2 = nxt[c].to_numpy(dtype="float64")

    res = np.full(len(interp_out), np.nan, dtype="float64")
    ok = interp_ok & ~np.isnan(v1) & ~np.isnan(v2)
    res[ok] = v1[ok] + ((y[ok] - y1[ok]) / (y2[ok] - y1[ok])) * (v2[ok] - v1[ok])
    interp_out[c] = res

# rows without bracketing years remain NaN and match_type stays NA

# %% [markdown]
# Now combine first exact match and the second interpolated match

# %%
# we update only the rows that were unmatched after exact merge, using _row_id to align.
final = exact.copy()

# set interpolated values into the corresponding rows
final = final.merge(
    interp_out[["_row_id", "match_type", "year_prev", "year_next"] + value_cols],
    on="_row_id",
    how="left",
    suffixes=("", "_interp"),
)

# where exact match missing, fill from interpolation
mask = final["match_type"].isna() & final["match_type_interp"].notna()

final.loc[mask, "match_type"] = final.loc[mask, "match_type_interp"]
final.loc[mask, "year_prev"] = final.loc[mask, "year_prev_interp"]
final.loc[mask, "year_next"] = final.loc[mask, "year_next_interp"]

for c in value_cols:
    final.loc[mask, c] = final.loc[mask, f"{c}_interp"]

# cleanup
drop_cols = ["party_id"] + [f"{c}_interp" for c in value_cols] + ["match_type_interp", "year_prev_interp", "year_next_interp"]
final = final.drop(columns=[c for c in drop_cols if c in final.columns])

final = final.sort_values("_row_id").drop(columns="_row_id")

#At this point, we should have the following:
#   -> exact matches have match_type="exact", years prev/next are NA
#   -> interpolated matches have match_type="interpolated", prev/next filled
#   -> no match remains match_type NA and numeric cols NaN

# %%
display(final.head())
# Out:
#    Unnamed: 0                        speaker  \
# 0      292003                   Amjad Bashir
# 1      292004            Miguel Arias Cañete
# 2      292025                Monika Smolková
# 3      291861               Kristina Winberg
# 4      291519  Ελισσάβετ Βόζεμπεργκ-Βρυωνίδη
#
#                                                 text        date  \
# 0  Mr Arias, we have heard about the injustice do...  2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig...  2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ...  2014-07-02
# 3  Fru talman! Schengenavtalet ingicks i en anda ...  2014-07-14
# 4  Αξιότιμε κύριε Juncker, στις προτεραιότητές σα...  2014-07-15
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
# 3  13. One-minute speeches on matters of politica...            24
# 4  5. Statement by the candidate for President of...            25
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
# 3                      6404.0       8  False  True       False    False
# 4                      6398.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
# 3         False  https://www.europarl.europa.eu/doceo/document/...
# 4         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl
# 1  Yes, indeed, to fight against immigration we m...        machine_pl
# 2  - Italy presented a very ambitious plan for it...        machine_pl
# 3  Fru talman! The Schengen Agreement was conclud...        machine_pl
# 4  Dear Mr Juncker, in your priorities you refer ...        machine_pl
#
#                     block       party_mig  migration_prob person_id_ep  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913       124956
# 1  christian_conservative             PPE        0.494101         1351
# 2       social_democratic         PSE/S&D        0.323411        96655
# 3         (extreme)_right  EDD/INDDEM/EFD        0.700463       124995
# 4  christian_conservative             PPE        0.604105       125065
#
#   party_id_ep party_id_ches       party_label_ep    party_all_labels_ep  \
# 0        4051          1108                 UKIP                 [UKIP]
# 1        4024           502                   PP                   [PP]
# 2        4159          2803              SMER-SD              [SMER-SD]
# 3        4253          1610  Sverigedemokraterna  [Sverigedemokraterna]
# 4        4055           402                 N.D.           [Ν.Δ., N.D.]
#
#                     party_all_names_ep  \
# 0  [United Kingdom Independence Party]
# 1                    [Partido Popular]
# 2           [SMER-Sociálna demokracia]
# 3                [Sverigedemokraterna]
# 4     [Νέα Δημοκρατία, Nea Demokratia]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
# 3                              [Sverigedemokraterna]
# 4                                   [Néa Dimokratía]
#
#                                   party_name_en_ches  year_mig  year_ches  \
# 0                [United Kingdom Independence Party]      2014       2014
# 1          [People’s Party, People’s Alliance Party]      2014       2014
# 2  [Direction–Third Way, Direction–Social Democracy]      2014       2014
# 3                                 [Sweden Democrats]      2014       2014
# 4                                    [New Democracy]      2014       2014
#
#       lrgen    lrecon  lrecon_salience  lrecon_dissent  lrecon_blur    galtan  \
# 0  9.142858  8.571428         5.142857             NaN          NaN  9.285714
# 1  7.300000  7.666667         8.777778             NaN          NaN  8.000000
# 2  3.692308  2.571429         8.642858             NaN          NaN  6.928571
# 3  7.761905  5.400000         3.476191             NaN          NaN  9.238095
# 4  7.222222  7.111111         9.444445             NaN          NaN  7.000000
#
#    galtan_salience  galtan_dissent  galtan_blur  eu_position  eu_salience  \
# 0         8.142858             NaN          NaN     1.142857     9.142858
# 1         7.222222             NaN          NaN     6.800000     6.900000
# 2         4.846154             NaN          NaN     6.142857     6.571429
# 3         8.380953             NaN          NaN     1.272727     6.136363
# 4         6.333334             NaN          NaN     6.555555     7.444445
#
#    eu_dissent  eu_blur  spendvtax  spendvtax_salience  deregulation  \
# 0    0.714286      NaN   8.833333                 NaN      8.333333
# 1    0.600000      NaN   7.600000                 NaN      7.900000
# 2    1.454546      NaN   2.714286                 NaN      2.214286
# 3    0.950000      NaN   4.705883                 NaN      4.529412
# 4    2.555556      NaN   5.500000                 NaN      6.333333
#
#    dereg_salience  redistribution  redist_salience  econ_interven  \
# 0             NaN        7.500000              NaN       8.500000
# 1             NaN        7.600000              NaN       7.300000
# 2             NaN        2.642857              NaN       1.714286
# 3             NaN        4.588235              NaN       4.470588
# 4             NaN        6.555555              NaN       6.000000
#
#    civlib_laworder  civlib_salience  sociallifestyle  social_salience  \
# 0         8.857142              NaN         8.500000              NaN
# 1         8.300000              NaN         7.000000              NaN
# 2         6.923077              NaN         6.692307              NaN
# 3         9.277778              NaN         8.157895              NaN
# 4         7.111111              NaN         8.111111              NaN
#
#    womens_rights  lgbtq_rights  samesex_marriage  religious_principles  \
# 0            NaN           NaN               NaN              6.800000
# 1            NaN           NaN               NaN              7.800000
# 2            NaN           NaN               NaN              4.857143
# 3            NaN           NaN               NaN              5.625000
# 4            NaN           NaN               NaN              8.444445
#
#    relig_salience  immigrate_policy  immigrate_salience  immigrate_dissent  \
# 0             NaN         10.000000                 NaN                NaN
# 1             NaN          8.100000                 NaN                NaN
# 2             NaN          6.461538                 NaN                NaN
# 3             NaN          9.777778                 NaN                NaN
# 4             NaN          8.000000                 NaN                NaN
#
#    multiculturalism  multicult_salience  multicult_dissent  nationalism  \
# 0          9.800000                 NaN                NaN     9.833333
# 1          8.250000                 NaN                NaN     7.200000
# 2          6.416666                 NaN                NaN     6.785714
# 3          9.842105                 NaN                NaN     9.777778
# 4          8.222222                 NaN                NaN     7.444445
#
#    nationalism_salience  ethnic_minorities  ethnic_salience  urban_rural  \
# 0                   NaN           8.428572              NaN     5.666667
# 1                   NaN           7.444445              NaN     5.500000
# 2                   NaN           7.307693              NaN     5.857143
# 3                   NaN           9.812500              NaN     7.312500
# 4                   NaN           8.222222              NaN     6.000000
#
#    urban_salience  environment  enviro_salience  climate_change  \
# 0             NaN     9.000000              NaN             NaN
# 1             NaN     7.375000              NaN             NaN
# 2             NaN     7.153846              NaN             NaN
# 3             NaN     7.500000              NaN             NaN
# 4             NaN     7.666666              NaN             NaN
#
#    climate_change_salience  protectionism   regions  region_salience  \
# 0                      NaN            NaN  5.750000              NaN
# 1                      NaN            NaN  7.500000              NaN
# 2                      NaN            NaN  7.000000              NaN
# 3                      NaN            NaN  5.250000              NaN
# 4                      NaN            NaN  5.714286              NaN
#
#    international_security  international_salience  us  us_salience     eu_ep  \
# 0                5.000000                     NaN NaN          NaN  1.166667
# 1                2.444444                     NaN NaN          NaN  5.666667
# 2                5.000000                     NaN NaN          NaN  5.900000
# 3                6.352941                     NaN NaN          NaN  1.833333
# 4                4.428571                     NaN NaN          NaN  6.428571
#
#    eu_fiscal  eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  \
# 0        NaN    2.571429        NaN    1.142857      NaN     1.285714
# 1        NaN    6.700000        NaN    5.555555      NaN     6.750000
# 2        NaN    5.846154        NaN    5.071429      NaN     6.833333
# 3        NaN    1.277778        NaN    1.062500      NaN     1.785714
# 4        NaN    6.555555        NaN    5.555555      NaN     6.777778
#
#    eu_environ  eu_asylum  eu_foreign  eu_turkey  eu_russia  \
# 0         NaN        NaN    1.285714   1.000000        NaN
# 1         NaN        NaN    6.750000   4.555555        NaN
# 2         NaN        NaN    5.153846   4.600000        NaN
# 3         NaN        NaN    1.235294   1.333333        NaN
# 4         NaN        NaN    6.111111   3.714286        NaN
#
#    russian_interference  anti_islam_rhetoric  people_vs_elite  \
# 0                   NaN                  NaN              NaN
# 1                   NaN                  NaN              NaN
# 2                   NaN                  NaN              NaN
# 3                   NaN                  NaN              NaN
# 4                   NaN                  NaN              NaN
#
#    antielite_salience  corrupt_salience  members_vs_leadership  \
# 0            9.285714          6.800000                    NaN
# 1            1.400000          3.400000                    NaN
# 2            3.714286          3.785714                    NaN
# 3            8.894737          2.944444                    NaN
# 4            2.333333          4.555555                    NaN
#
#    executive_power  judicial_independence match_type year_prev year_next
# 0              NaN                    NaN      exact      <NA>      <NA>
# 1              NaN                    NaN      exact      <NA>      <NA>
# 2              NaN                    NaN      exact      <NA>      <NA>
# 3              NaN                    NaN      exact      <NA>      <NA>
# 4              NaN                    NaN      exact      <NA>      <NA>

# %% [markdown]
# Perform some sanity checks on the final data

# %%
# distribution checks
# how many rows fell into each case?
print(final["match_type"].value_counts(dropna=False))

# coverage per numerical/interpolated column
print(final[value_cols].notna().mean().sort_values())
# Out:
# match_type
# interpolated    7647
# NaN             1397
# exact            661
# Name: count, dtype: int64
# spendvtax_salience         0.000000
# social_salience            0.000000
# civlib_salience            0.000000
# dereg_salience             0.000000
# relig_salience             0.000000
# eu_employ                  0.000000
# eu_environ                 0.000000
# eu_agri                    0.000000
# international_salience     0.000000
# us                         0.000000
# us_salience                0.000000
# eu_fiscal                  0.000000
# urban_salience             0.000000
# region_salience            0.000000
# nationalism_salience       0.000000
# ethnic_salience            0.000000
# eu_russia                  0.008655
# womens_rights              0.008655
# climate_change_salience    0.008655
# climate_change             0.008655
# samesex_marriage           0.008655
# lgbtq_rights               0.008655
# judicial_independence      0.008655
# executive_power            0.008655
# eu_turkey                  0.025142
# eu_ep                      0.025142
# international_security     0.025142
# multicult_dissent          0.034312
# members_vs_leadership      0.034312
# russian_interference       0.034312
# eu_asylum                  0.034312
# protectionism              0.187944
# anti_islam_rhetoric        0.187944
# galtan_dissent             0.188357
# lrecon_dissent             0.188666
# eu_blur                    0.190211
# immigrate_dissent          0.190211
# immigrate_salience         0.190211
# redist_salience            0.190211
# lrecon_blur                0.190211
# enviro_salience            0.190211
# multicult_salience         0.190211
# people_vs_elite            0.190211
# galtan_blur                0.190211
# sociallifestyle            0.698197
# econ_interven              0.698197
# eu_cohesion                0.698197
# eu_budgets                 0.698197
# urban_rural                0.847810
# corrupt_salience           0.852035
# civlib_laworder            0.853787
# religious_principles       0.853787
# environment                0.853993
# eu_dissent                 0.855744
# eu_foreign                 0.855951
# spendvtax                  0.855951
# galtan_salience            0.856054
# redistribution             0.856054
# immigrate_policy           0.856054
# lrecon_salience            0.856054
# lrgen                      0.856054
# eu_position                0.856054
# eu_salience                0.856054
# deregulation               0.856054
# eu_intmark                 0.856054
# nationalism                0.856054
# multiculturalism           0.856054
# regions                    0.856054
# ethnic_minorities          0.856054
# lrecon                     0.856054
# galtan                     0.856054
# antielite_salience         0.856054
# dtype: float64

# %%
# row count preserved
assert len(final) == len(left)

# left keys unchanged
assert final["party_id_ches"].equals(left["party_id_ches"])
assert final["year_mig"].equals(left["year_mig"])

# exact match correctness, i.e. every exact match was really an exact match
exact = final["match_type"] == "exact"
# year_prev / year_next must be NaN
assert final.loc[exact, ["year_prev", "year_next"]].isna().all().all()

# exact match correspond to right data
exact_keys = final.loc[exact, ["party_id_ches", "year_mig"]]
right_keys = right.rename(columns={"party_id": "party_id_ches"})[["party_id_ches", "year_ches"]]

missing = exact_keys.merge(right_keys, how="left", indicator=True)
assert (missing["_merge"] == "both").all()

# %%
# apparently this assertion here fails, because missing rows that have no bracketing years
# still get assigned the match_type = interpolation (overwritten after we combine the results to final result)

# interpolated rows must have both bounds
#interp = final["match_type"] == "interpolated"
#assert final.loc[interp, "year_prev"].notna().all()
#assert final.loc[interp, "year_next"].notna().all()

# -> so lets instead ask it the other way:

bad = (final["match_type"] == "interpolated") & final["year_prev"].isna()

print(bad.sum())
display(final.loc[bad, ["party_id_ches", "year_mig", "year_prev", "year_next", "match_type", "year_ches"]].head(20))

bad_both_prev_next_missing = (final["match_type"] == "interpolated") & final["year_prev"].isna() & final["year_next"].isna()
print(bad_both_prev_next_missing.sum())
# Out:
# 1596
#     party_id_ches  year_mig year_prev year_next    match_type  year_ches
# 396          2203      2015       NaN       NaN  interpolated       <NA>
# 397          2701      2015       NaN       NaN  interpolated       <NA>
# 398          1206      2015       NaN       NaN  interpolated       <NA>
# 399          2601      2015       NaN       NaN  interpolated       <NA>
# 400          2302      2015       NaN       NaN  interpolated       <NA>
# 401          2603      2015       NaN       NaN  interpolated       <NA>
# 402          1205      2015       NaN       NaN  interpolated       <NA>
# 403          2605      2015       NaN       NaN  interpolated       <NA>
# 404           815      2015       NaN       NaN  interpolated       <NA>
# 405           815      2015       NaN       NaN  interpolated       <NA>
# 406          1108      2015       NaN       NaN  interpolated       <NA>
# 407          2004      2015       NaN       NaN  interpolated       <NA>
# 408          2003      2015       NaN       NaN  interpolated       <NA>
# 409          1102      2015       NaN       NaN  interpolated       <NA>
# 410          1102      2015       NaN       NaN  interpolated       <NA>
# 411          1101      2015       NaN       NaN  interpolated       <NA>
# 412           815      2015       NaN       NaN  interpolated       <NA>
# 413          1605      2015       NaN       NaN  interpolated       <NA>
# 414          1604      2015       NaN       NaN  interpolated       <NA>
# 415          1604      2015       NaN       NaN  interpolated       <NA>
# 1596

# %%
# then check instead if all rows that are not exact match and not missing (i.e. year_ches not NaN) have bracketing years -> are interpolated
mask = (final["match_type"] == "interpolated") & final["year_ches"].notna()

assert final.loc[mask, "year_prev"].notna().all()
assert final.loc[mask, "year_next"].notna().all()
# if this assertion does not fail, it means our match_type column is wrongly labeling matches instead

# %%
# NOTE: Apparently the column "match_type" is not correct anymore (see above)
# FIX: in the end, check the match type and if in doubt, derive from actual data
y  = pd.to_numeric(final["year_mig"], errors="coerce").to_numpy(dtype="float64")
y_ches = pd.to_numeric(final["year_ches"], errors="coerce").to_numpy(dtype="float64")
y1 = pd.to_numeric(final["year_prev"], errors="coerce").to_numpy(dtype="float64")
y2 = pd.to_numeric(final["year_next"], errors="coerce").to_numpy(dtype="float64")

exact  = np.isnan(y1) & np.isnan(y2) & (y == y_ches)
interp = ~np.isnan(y1) & ~np.isnan(y2) & (y1 < y) & (y < y2)

final["match_type"] = "none"
final.loc[exact, "match_type"] = "exact"
final.loc[interp, "match_type"] = "interpolated"


interp = final["match_type"] == "interpolated"
assert final.loc[interp, "year_prev"].notna().all()
assert final.loc[interp, "year_next"].notna().all()

# %%
bad = (final["match_type"] == "interpolated") & final["year_prev"].isna()

print(bad.sum())
display(final.loc[bad, ["party_id_ches", "year_mig", "year_prev", "year_next", "match_type", "year_ches"]].head(20))

bad_both_prev_next_missing = (final["match_type"] == "interpolated") & final["year_prev"].isna() & final["year_next"].isna()
print(bad_both_prev_next_missing.sum())
# Out:
# 0
# Empty DataFrame
# Columns: [party_id_ches, year_mig, year_prev, year_next, match_type, year_ches]
# Index: []
# 0

# %%
# bounds must actually bracket the left year
y  = pd.to_numeric(final["year_mig"],  errors="coerce").to_numpy(dtype="float64")
y1 = pd.to_numeric(final["year_prev"], errors="coerce").to_numpy(dtype="float64")
y2 = pd.to_numeric(final["year_next"], errors="coerce").to_numpy(dtype="float64")

interp = final["match_type"] == "interpolated"
brackets = (~np.isnan(y1)) & (~np.isnan(y2)) & (y1 < y) & (y < y2)

bad = interp & ~brackets

print("rows failing bracketing check:", bad.sum())
final.loc[bad, ["party_id_ches", "year_mig", "year_prev", "year_next"]].head(20)

assert bad.sum() == 0
# Out:
# rows failing bracketing check: 0

# %%
# distribution checks
# how many rows fell into each case?
display(final["match_type"].value_counts(dropna=False))

# coverage per numerical/interpolated column
display(final[value_cols].notna().mean().sort_values())
# Out:
# match_type
# interpolated    5910
# none            3134
# exact            661
# Name: count, dtype: int64
# spendvtax_salience         0.000000
# social_salience            0.000000
# civlib_salience            0.000000
# dereg_salience             0.000000
# relig_salience             0.000000
# eu_employ                  0.000000
# eu_environ                 0.000000
# eu_agri                    0.000000
# international_salience     0.000000
# us                         0.000000
# us_salience                0.000000
# eu_fiscal                  0.000000
# urban_salience             0.000000
# region_salience            0.000000
# nationalism_salience       0.000000
# ethnic_salience            0.000000
# eu_russia                  0.008655
# womens_rights              0.008655
# climate_change_salience    0.008655
# climate_change             0.008655
# samesex_marriage           0.008655
# lgbtq_rights               0.008655
# judicial_independence      0.008655
# executive_power            0.008655
# eu_turkey                  0.025142
# eu_ep                      0.025142
# international_security     0.025142
# multicult_dissent          0.034312
# members_vs_leadership      0.034312
# russian_interference       0.034312
# eu_asylum                  0.034312
# protectionism              0.187944
# anti_islam_rhetoric        0.187944
# galtan_dissent             0.188357
# lrecon_dissent             0.188666
# eu_blur                    0.190211
# immigrate_dissent          0.190211
# immigrate_salience         0.190211
# redist_salience            0.190211
# lrecon_blur                0.190211
# enviro_salience            0.190211
# multicult_salience         0.190211
# people_vs_elite            0.190211
# galtan_blur                0.190211
# sociallifestyle            0.698197
# econ_interven              0.698197
# eu_cohesion                0.698197
# eu_budgets                 0.698197
# urban_rural                0.847810
# corrupt_salience           0.852035
# civlib_laworder            0.853787
# religious_principles       0.853787
# environment                0.853993
# eu_dissent                 0.855744
# eu_foreign                 0.855951
# spendvtax                  0.855951
# galtan_salience            0.856054
# redistribution             0.856054
# immigrate_policy           0.856054
# lrecon_salience            0.856054
# lrgen                      0.856054
# eu_position                0.856054
# eu_salience                0.856054
# deregulation               0.856054
# eu_intmark                 0.856054
# nationalism                0.856054
# multiculturalism           0.856054
# regions                    0.856054
# ethnic_minorities          0.856054
# lrecon                     0.856054
# galtan                     0.856054
# antielite_salience         0.856054
# dtype: float64

# %% [markdown]
# Wonderful, now lets clean it up and store for later analysis

# %%
display(final.head())
# Out:
#    Unnamed: 0                        speaker  \
# 0      292003                   Amjad Bashir
# 1      292004            Miguel Arias Cañete
# 2      292025                Monika Smolková
# 3      291861               Kristina Winberg
# 4      291519  Ελισσάβετ Βόζεμπεργκ-Βρυωνίδη
#
#                                                 text        date  \
# 0  Mr Arias, we have heard about the injustice do...  2014-07-02
# 1  Sí, efectivamente, para luchar contra la inmig...  2014-07-02
# 2  – Taliansko predstavilo veľmi ambiciózny plán ...  2014-07-02
# 3  Fru talman! Schengenavtalet ingicks i en anda ...  2014-07-14
# 4  Αξιότιμε κύριε Juncker, στις προτεραιότητές σα...  2014-07-15
#
#                                               agenda  speechnumber  \
# 0  12. Programme of activities of the Italian Pre...            41
# 1  12. Programme of activities of the Italian Pre...            42
# 2  12. Programme of activities of the Italian Pre...            63
# 3  13. One-minute speeches on matters of politica...            24
# 4  5. Statement by the candidate for President of...            25
#
#   procedure_ID  partyfacts_ID  period  chair   MEP  commission  written  \
# 0                      6404.0       8  False  True       False    False
# 1                      6398.0       8  False  True       False    False
# 2                      6399.0       8  False  True       False     True
# 3                      6404.0       8  False  True       False    False
# 4                      6398.0       8  False  True       False     True
#
#    multispeaker                                               link  \
# 0         False  https://www.europarl.europa.eu/doceo/document/...
# 1         False  https://www.europarl.europa.eu/doceo/document/...
# 2         False  https://www.europarl.europa.eu/doceo/document/...
# 3         False  https://www.europarl.europa.eu/doceo/document/...
# 4         False  https://www.europarl.europa.eu/doceo/document/...
#
#                                       translatedText translationSource  \
# 0  Mr Arias, we have heard about the injustice do...       original_pl
# 1  Yes, indeed, to fight against immigration we m...        machine_pl
# 2  - Italy presented a very ambitious plan for it...        machine_pl
# 3  Fru talman! The Schengen Agreement was conclud...        machine_pl
# 4  Dear Mr Juncker, in your priorities you refer ...        machine_pl
#
#                     block       party_mig  migration_prob person_id_ep  \
# 0         (extreme)_right  EDD/INDDEM/EFD        0.257913       124956
# 1  christian_conservative             PPE        0.494101         1351
# 2       social_democratic         PSE/S&D        0.323411        96655
# 3         (extreme)_right  EDD/INDDEM/EFD        0.700463       124995
# 4  christian_conservative             PPE        0.604105       125065
#
#   party_id_ep party_id_ches       party_label_ep    party_all_labels_ep  \
# 0        4051          1108                 UKIP                 [UKIP]
# 1        4024           502                   PP                   [PP]
# 2        4159          2803              SMER-SD              [SMER-SD]
# 3        4253          1610  Sverigedemokraterna  [Sverigedemokraterna]
# 4        4055           402                 N.D.           [Ν.Δ., N.D.]
#
#                     party_all_names_ep  \
# 0  [United Kingdom Independence Party]
# 1                    [Partido Popular]
# 2           [SMER-Sociálna demokracia]
# 3                [Sverigedemokraterna]
# 4     [Νέα Δημοκρατία, Nea Demokratia]
#
#                                      party_name_ches  \
# 0                [United Kingdom Independence Party]
# 1         [Partido Popular, Alianza-Partido Popular]
# 2  [Strana Smer–Tretia Cesta, Smer–sociálna demok...
# 3                              [Sverigedemokraterna]
# 4                                   [Néa Dimokratía]
#
#                                   party_name_en_ches  year_mig  year_ches  \
# 0                [United Kingdom Independence Party]      2014       2014
# 1          [People’s Party, People’s Alliance Party]      2014       2014
# 2  [Direction–Third Way, Direction–Social Democracy]      2014       2014
# 3                                 [Sweden Democrats]      2014       2014
# 4                                    [New Democracy]      2014       2014
#
#       lrgen    lrecon  lrecon_salience  lrecon_dissent  lrecon_blur    galtan  \
# 0  9.142858  8.571428         5.142857             NaN          NaN  9.285714
# 1  7.300000  7.666667         8.777778             NaN          NaN  8.000000
# 2  3.692308  2.571429         8.642858             NaN          NaN  6.928571
# 3  7.761905  5.400000         3.476191             NaN          NaN  9.238095
# 4  7.222222  7.111111         9.444445             NaN          NaN  7.000000
#
#    galtan_salience  galtan_dissent  galtan_blur  eu_position  eu_salience  \
# 0         8.142858             NaN          NaN     1.142857     9.142858
# 1         7.222222             NaN          NaN     6.800000     6.900000
# 2         4.846154             NaN          NaN     6.142857     6.571429
# 3         8.380953             NaN          NaN     1.272727     6.136363
# 4         6.333334             NaN          NaN     6.555555     7.444445
#
#    eu_dissent  eu_blur  spendvtax  spendvtax_salience  deregulation  \
# 0    0.714286      NaN   8.833333                 NaN      8.333333
# 1    0.600000      NaN   7.600000                 NaN      7.900000
# 2    1.454546      NaN   2.714286                 NaN      2.214286
# 3    0.950000      NaN   4.705883                 NaN      4.529412
# 4    2.555556      NaN   5.500000                 NaN      6.333333
#
#    dereg_salience  redistribution  redist_salience  econ_interven  \
# 0             NaN        7.500000              NaN       8.500000
# 1             NaN        7.600000              NaN       7.300000
# 2             NaN        2.642857              NaN       1.714286
# 3             NaN        4.588235              NaN       4.470588
# 4             NaN        6.555555              NaN       6.000000
#
#    civlib_laworder  civlib_salience  sociallifestyle  social_salience  \
# 0         8.857142              NaN         8.500000              NaN
# 1         8.300000              NaN         7.000000              NaN
# 2         6.923077              NaN         6.692307              NaN
# 3         9.277778              NaN         8.157895              NaN
# 4         7.111111              NaN         8.111111              NaN
#
#    womens_rights  lgbtq_rights  samesex_marriage  religious_principles  \
# 0            NaN           NaN               NaN              6.800000
# 1            NaN           NaN               NaN              7.800000
# 2            NaN           NaN               NaN              4.857143
# 3            NaN           NaN               NaN              5.625000
# 4            NaN           NaN               NaN              8.444445
#
#    relig_salience  immigrate_policy  immigrate_salience  immigrate_dissent  \
# 0             NaN         10.000000                 NaN                NaN
# 1             NaN          8.100000                 NaN                NaN
# 2             NaN          6.461538                 NaN                NaN
# 3             NaN          9.777778                 NaN                NaN
# 4             NaN          8.000000                 NaN                NaN
#
#    multiculturalism  multicult_salience  multicult_dissent  nationalism  \
# 0          9.800000                 NaN                NaN     9.833333
# 1          8.250000                 NaN                NaN     7.200000
# 2          6.416666                 NaN                NaN     6.785714
# 3          9.842105                 NaN                NaN     9.777778
# 4          8.222222                 NaN                NaN     7.444445
#
#    nationalism_salience  ethnic_minorities  ethnic_salience  urban_rural  \
# 0                   NaN           8.428572              NaN     5.666667
# 1                   NaN           7.444445              NaN     5.500000
# 2                   NaN           7.307693              NaN     5.857143
# 3                   NaN           9.812500              NaN     7.312500
# 4                   NaN           8.222222              NaN     6.000000
#
#    urban_salience  environment  enviro_salience  climate_change  \
# 0             NaN     9.000000              NaN             NaN
# 1             NaN     7.375000              NaN             NaN
# 2             NaN     7.153846              NaN             NaN
# 3             NaN     7.500000              NaN             NaN
# 4             NaN     7.666666              NaN             NaN
#
#    climate_change_salience  protectionism   regions  region_salience  \
# 0                      NaN            NaN  5.750000              NaN
# 1                      NaN            NaN  7.500000              NaN
# 2                      NaN            NaN  7.000000              NaN
# 3                      NaN            NaN  5.250000              NaN
# 4                      NaN            NaN  5.714286              NaN
#
#    international_security  international_salience  us  us_salience     eu_ep  \
# 0                5.000000                     NaN NaN          NaN  1.166667
# 1                2.444444                     NaN NaN          NaN  5.666667
# 2                5.000000                     NaN NaN          NaN  5.900000
# 3                6.352941                     NaN NaN          NaN  1.833333
# 4                4.428571                     NaN NaN          NaN  6.428571
#
#    eu_fiscal  eu_intmark  eu_employ  eu_budgets  eu_agri  eu_cohesion  \
# 0        NaN    2.571429        NaN    1.142857      NaN     1.285714
# 1        NaN    6.700000        NaN    5.555555      NaN     6.750000
# 2        NaN    5.846154        NaN    5.071429      NaN     6.833333
# 3        NaN    1.277778        NaN    1.062500      NaN     1.785714
# 4        NaN    6.555555        NaN    5.555555      NaN     6.777778
#
#    eu_environ  eu_asylum  eu_foreign  eu_turkey  eu_russia  \
# 0         NaN        NaN    1.285714   1.000000        NaN
# 1         NaN        NaN    6.750000   4.555555        NaN
# 2         NaN        NaN    5.153846   4.600000        NaN
# 3         NaN        NaN    1.235294   1.333333        NaN
# 4         NaN        NaN    6.111111   3.714286        NaN
#
#    russian_interference  anti_islam_rhetoric  people_vs_elite  \
# 0                   NaN                  NaN              NaN
# 1                   NaN                  NaN              NaN
# 2                   NaN                  NaN              NaN
# 3                   NaN                  NaN              NaN
# 4                   NaN                  NaN              NaN
#
#    antielite_salience  corrupt_salience  members_vs_leadership  \
# 0            9.285714          6.800000                    NaN
# 1            1.400000          3.400000                    NaN
# 2            3.714286          3.785714                    NaN
# 3            8.894737          2.944444                    NaN
# 4            2.333333          4.555555                    NaN
#
#    executive_power  judicial_independence match_type year_prev year_next
# 0              NaN                    NaN      exact      <NA>      <NA>
# 1              NaN                    NaN      exact      <NA>      <NA>
# 2              NaN                    NaN      exact      <NA>      <NA>
# 3              NaN                    NaN      exact      <NA>      <NA>
# 4              NaN                    NaN      exact      <NA>      <NA>

# %%
# convert types into string where reasonable
# work on copy
final_output_interpolated = final.copy(deep=True)
print(final_output_interpolated["year_ches"].isna().sum()) # we have nan values since not all rows matched! -> we cannot have numpy int as dtype
print(final_output_interpolated["year_ches"].dtype)
print(final_output_interpolated["year_mig"].dtype)
print(final_output_interpolated["match_type"].dtype)
print(final_output_interpolated["year_prev"].dtype)
print(final_output_interpolated["year_next"].dtype)
#final_fallback_output["year_ches"] = final_fallback_output["year_ches"].astype("Int64") # convert to pandas int type

# since we have NaN values in columns match_type, year_prev and year_next, convert these to string
# ensure IDs same dtype (pandas string, handles NaN nicely for us)
final_output_interpolated["match_type"] = final_output_interpolated["match_type"].astype("string").str.strip()
final_output_interpolated["year_prev"] = final_output_interpolated["year_prev"].astype("string").str.strip()
final_output_interpolated["year_next"] = final_output_interpolated["year_next"].astype("string").str.strip()
print(final_output_interpolated["match_type"].dtype)
print(final_output_interpolated["year_prev"].dtype)
print(final_output_interpolated["year_next"].dtype)
# Out:
# 9044
# Int64
# Int64
# str
# object
# object
# string
# string
# string

# %%
# now store for later analysis
# final_output_interpolated.to_parquet(PATH_MIGRATION_CHES_INTERPOLATED, engine='fastparquet')
